# %%
import sys
from pathlib import Path

ROOT_DIR = Path().resolve().parents[0]
sys.path.append(str(ROOT_DIR))

# %%
import os
import torch
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams["figure.dpi"] = 300
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = ['Times New Roman']

plt.rcParams.update({
    "font.size": 15,       
    "axes.titlesize": 16,  
    "axes.labelsize": 15,  
    "xtick.labelsize": 14, 
    "ytick.labelsize": 14, 
    "legend.fontsize": 12  
})

import numpy as np
import json
import pandas as pd

from src.models.model import PeakPredictorLSTM
from src.data.pmodel_generation import (
    generate_multiple_series,
)


from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
)


def recall_vs_anticipation(
    predictions,
    true_peaks,
    lookahead,
    threshold,
    burn_in=100,
):
    """
    Computes recall as a function of minimum anticipation time,
    discarding early points without valid prediction context.

    Returns:
        ks: minimum anticipation (in time steps)
        recalls: fraction of peaks anticipated at least k steps ahead
    """

    # Positions of real peaks
    peak_positions = np.where(true_peaks == 1)[0]

    # Discard peaks too close to the beginning (no valid anticipation window)
    peak_positions = peak_positions[
        peak_positions >= burn_in + lookahead
    ]

    ks = np.arange(1, lookahead + 1)
    recalls = []

    if len(peak_positions) == 0:
        return ks, np.zeros_like(ks, dtype=float)

    for k in ks:
        detected = 0

        for t_peak in peak_positions:
            t_start = t_peak - lookahead

            window = predictions[t_start:t_peak]

            # Ignore windows with NaNs (extra safety)
            if np.isnan(window).any():
                continue

            alarm_idx = np.where(window >= threshold)[0]

            if len(alarm_idx) > 0:
                t_alarm = t_start + alarm_idx[0]
                if (t_peak - t_alarm) >= k:
                    detected += 1

        recalls.append(detected / len(peak_positions))

    return ks, np.array(recalls)

def build_anticipatory_labels(peaks, lookahead):
    """
    peaks: array binário (0/1) indicando pico instantâneo
    lookahead: horizonte de previsão

    Retorna:
    y_future[t] = 1 se existir pico em [t+1, t+lookahead]
    """
    y_future = np.zeros_like(peaks)

    for t in range(len(peaks)):
        end = min(t + lookahead + 1, len(peaks))
        if np.any(peaks[t + 1 : end]):
            y_future[t] = 1

    return y_future



def evaluate_and_plot_streaming(
    model,
    df,
    device,
    lookahead,
    threshold=0.6,
    plot=True,
    box_cut=None,
    title="P-model time series",
    path_ra=None,
    path_series=None
):
    """
    Evaluates a single time series in a streaming (causal) regime.
    """

    # Select appropriate signal column
    signal_col = (
        "normalized_amplitude"
        if "normalized_amplitude" in df.columns
        else "normalized"
    )

    series = df[signal_col].values
    true_peaks = df["peak"].values.astype(int)
    instant_peaks = df["peak"].values.astype(int)
    true_peaks_classic_metrics = build_anticipatory_labels(instant_peaks, lookahead)


    model.eval()
    hidden = model.init_hidden()
    predictions = []

    with torch.no_grad():
        for value in series:
            x_t = torch.tensor([[[value]]], dtype=torch.float32).to(device)
            y_hat, hidden = model.step(x_t, hidden)
            predictions.append(y_hat.item())

    predictions = np.array(predictions)

    # Apply sigmoid if the model outputs logits
    predictions = 1 / (1 + np.exp(-predictions))

    burn_in = 0  

    # Temporal adjustment (anticipatory prediction)
    predictions[:lookahead] = np.nan

    valid = ~np.isnan(predictions)

    # ignora também os primeiros burn_in pontos
    valid[:burn_in] = False

    y_true = true_peaks_classic_metrics[valid]
    y_score = predictions[valid]
    y_pred = (y_score >= threshold).astype(int)

    metrics = {
        # "AUC-ROC": roc_auc_score(y_true, y_score)
        # if len(np.unique(y_true)) > 1
        # else np.nan,
        "AUC-PR": average_precision_score(y_true, y_score)
        if len(np.unique(y_true)) > 1
        else np.nan,
        # "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred, zero_division=0),
        "Recall": recall_score(y_true, y_pred, zero_division=0),
        "F1": f1_score(y_true, y_pred, zero_division=0),
        "P-value": df["p_value"].iloc[0] if "p_value" in df.columns else np.nan
    }

    if plot:
        # Recall vs Anticipation Plot
        x_ini, x_fim = box_cut
        thresholds = [threshold, 0.7, 0.8, 0.9]

        colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]
        linestyles = ["-", "--", "-.", ":", (0, (3, 1, 1, 1))] 
        markers = ["o", "x", "^", "D"]

        plt.figure(figsize=(8, 3))

        ks = None
        recalls = None

        for th, c, ls, m in zip(thresholds, colors, linestyles, markers):
            ks_sub, recalls_sub = recall_vs_anticipation(
                predictions,
                true_peaks,
                lookahead,
                threshold=th,
            )

            if th == threshold:
                ks = ks_sub
                recalls = recalls_sub

            plt.plot(
                ks_sub,
                recalls_sub,
                color=c,
                linestyle=ls,
                marker=m,
                markersize=6,
                linewidth=1.2,
                label=f"threshold = {th}"
            )

        plt.xlabel("Anticipation (k)")
        plt.ylabel("Recall")
        plt.title("Recall vs Anticipation")
        plt.grid(alpha=0.3)
        plt.legend()

        plt.savefig(path_ra, dpi=300, bbox_inches='tight') 

        plt.show()

        # Full series  plots
        fig, ax = plt.subplots(figsize=(9, 2.5), dpi=300)

        peak_idx = np.where(true_peaks == 1)[0]

        # Full series
        ax.plot(
            series, 
            lw=0.6, 
            label="P-model time series",
            color="royalblue"
        )

        ax.plot(
            range(x_ini, x_fim),
            series[x_ini:x_fim],
            lw=0.9,
            color="blue"
        )

        ax.plot(
            peak_idx,
            series[peak_idx],
            "x",
            markersize=6,
            label="Extreme events (XE)",
            color="red"
        )

        ax.plot(
            predictions,
            "--",
            lw=1.2,
            label=f"Probability",
            color="orange"
        )
        ax.set_title(title)

        ax.axvspan(x_ini, x_fim, color="gray", alpha=0.15)

        # cria o inset (janela de zoom)
        axins = inset_axes(
            ax,
            width="90%",
            height="90%",
            loc="lower center",
            bbox_to_anchor=(0.05, -1.3, 0.9, 0.9),
            bbox_transform=ax.transAxes,
            borderpad=0
        )

        axins.plot(
            range(x_ini, x_fim),
            series[x_ini:x_fim],
            lw=0.9,
            color="blue"
        )

        mask_peaks_zoom = (peak_idx >= x_ini) & (peak_idx < x_fim)
        peak_idx_zoom = peak_idx[mask_peaks_zoom]

        axins.plot(
            peak_idx_zoom,
            series[peak_idx_zoom],
            "x",
            color="red",
            markersize=6,
            label="Extreme events (XE)"
        )

        axins.plot(
            range(x_ini, x_fim),
            predictions[x_ini:x_fim],
            "--",
            color="orange",
            lw=1.2
        )

        axins.set_xlim(x_ini, x_fim)
        # axins.set_ylim(
        #     series[x_ini:x_fim].min(),
        #     series[x_ini:x_fim].max()
        # )

        axins.grid(alpha=0.3)
        axins.tick_params(labelsize=12)

        from matplotlib.patches import ConnectionPatch

        # canto inferior esquerdo da região no gráfico principal
        con1 = ConnectionPatch(
            xyA=(x_ini, series[x_ini]),  # ponto no gráfico principal
            coordsA=ax.transData,
            xyB=(x_ini, axins.get_ylim()[1]),  # topo do inset
            coordsB=axins.transData,
            color="0.5",
            lw=0.8,
            linestyle="--"
        )

        # canto inferior esquerdo da outra borda
        con2 = ConnectionPatch(
            xyA=(x_fim, series[x_fim-1]),
            coordsA=ax.transData,
            xyB=(x_fim, axins.get_ylim()[1]),
            coordsB=axins.transData,
            color="0.5",
            lw=0.8,
            linestyle="--"
        )

        ax.add_artist(con1)
        ax.add_artist(con2)

        ax.legend(
            loc="upper left",
            frameon=True
        )
        ax.grid(alpha=0.3)
        ax.set_xlabel("Time steps")
        ax.set_ylabel("Normalized amplitude\nProbability")

        plt.tight_layout()
        plt.savefig(path_series, dpi=300, bbox_inches='tight') 
        plt.show()
    
    else: 
        ks, recalls = recall_vs_anticipation(
            predictions,
            true_peaks,
            lookahead,
            threshold=threshold,
        )

    return metrics, ks, recalls

def load_and_prepare_csv(file_path, peak_percentile):
    """
    Loads a real CSV time series and generates peak labels using a percentile.
    """
    print(f"\nLoading file: {os.path.basename(file_path)}")

    df = pd.read_csv(file_path)
    df.columns = ["time", "amplitude"]

    amp = df["amplitude"].values
    df["normalized_amplitude"] = (
        (amp - amp.min()) / (amp.max() - amp.min() + 1e-6)
        if amp.max() > amp.min()
        else np.zeros_like(amp)
    )

    threshold = np.percentile(
        df["normalized_amplitude"], peak_percentile
    )
    df["peak"] = (df["normalized_amplitude"] > threshold).astype(int)
    df["peak_threshold"] = threshold

    return df

# %%
np.random.seed(30)

with open("../config/config_exo.json", "r") as f:
    config = json.load(f)

if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
# ---------- Model ----------
model = PeakPredictorLSTM(config["model"]).to(device)
model.load_state_dict(
    torch.load("../results/best_model_exo.pth", map_location=device)
)
# Out:
# <All keys matched successfully>

# %%
test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=config["p_model"]["p_value"],
    num_series=config["data"]["num_series_test"],
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

indices = np.linspace(0, len(test_series) - 1, 500, dtype=int)

for count, i in enumerate(indices):
    df = test_series[i]

    print(
        f"\n Synthetic series {count + 1}/{len(indices)} "
        f"(index {i})"
    )

    metrics, ks, recalls = evaluate_and_plot_streaming(
        model,
        df,
        device,
        lookahead=config["data"]["lookahead"],
        plot=False,
        title="P-model time series with extreme event labels and LSTM prediction"
    )

    print(metrics)

    all_metrics.append(metrics)
    all_recalls.append(recalls)


# ---------- Aggregate recalls ----------
all_recalls = np.array(all_recalls)  

mean_recall = np.nanmean(all_recalls, axis=0)
std_recall = np.nanstd(all_recalls, axis=0)

# Clip to valid recall range
lower = np.clip(mean_recall - std_recall, 0, 1)
upper = np.clip(mean_recall + std_recall, 0, 1)

# ---------- Recall vs Anticipation Plot ----------
plt.figure(figsize=(6, 4))

plt.plot(
    ks,
    mean_recall,
    marker="o",
    markersize=6,
    linewidth=1.2,
    label="threshold = 0.6"
)

plt.fill_between(
    ks,
    lower,
    upper,
    alpha=0.3,
    label="±1 std (threshold = 0.6)"
)

plt.xlabel("Minimum anticipation (time steps before the peak)")
plt.ylabel("Recall")
plt.title("Extreme event anticipation capability (Recall vs Anticipation)")
plt.grid(alpha=0.3)
plt.legend()
plt.ylim(0.4, 1.05)

plt.show()
# Out:
# [0.18, 0.28]
#
#  Synthetic series 1/500 (index 0)
# {'AUC-PR': 0.6934720936274628, 'Precision': 0.4126984126984127, 'Recall': 0.6582278481012658, 'F1': 0.5073170731707317, 'P-value': np.float64(0.18)}
#
#  Synthetic series 2/500 (index 3)
# {'AUC-PR': 0.6282882923755914, 'Precision': 0.5436893203883495, 'Recall': 0.7, 'F1': 0.6120218579234973, 'P-value': np.float64(0.18)}
#
#  Synthetic series 3/500 (index 6)
# {'AUC-PR': 0.7180278322871072, 'Precision': 0.4652777777777778, 'Recall': 0.9436619718309859, 'F1': 0.6232558139534884, 'P-value': np.float64(0.18)}
#
#  Synthetic series 4/500 (index 9)
# {'AUC-PR': 0.742710558845645, 'Precision': 0.5959595959595959, 'Recall': 0.7468354430379747, 'F1': 0.6629213483146067, 'P-value': np.float64(0.18)}
#
#  Synthetic series 5/500 (index 12)
# {'AUC-PR': 0.7437425984392927, 'Precision': 0.6288659793814433, 'Recall': 0.7261904761904762, 'F1': 0.6740331491712708, 'P-value': np.float64(0.18)}
#
#  Synthetic series 6/500 (index 15)
# {'AUC-PR': 0.5503356520834242, 'Precision': 0.5217391304347826, 'Recall': 0.6153846153846154, 'F1': 0.5647058823529412, 'P-value': np.float64(0.18)}
#
#  Synthetic series 7/500 (index 18)
# {'AUC-PR': 0.6631860362152031, 'Precision': 0.6129032258064516, 'Recall': 0.7402597402597403, 'F1': 0.6705882352941176, 'P-value': np.float64(0.18)}
#
#  Synthetic series 8/500 (index 21)
# {'AUC-PR': 0.751060237411616, 'Precision': 0.5894736842105263, 'Recall': 0.7272727272727273, 'F1': 0.6511627906976745, 'P-value': np.float64(0.18)}
#
#  Synthetic series 9/500 (index 24)
# {'AUC-PR': 0.6434853958438261, 'Precision': 0.4146341463414634, 'Recall': 0.7183098591549296, 'F1': 0.5257731958762887, 'P-value': np.float64(0.18)}
#
#  Synthetic series 10/500 (index 27)
# {'AUC-PR': 0.7602620017170348, 'Precision': 0.5858585858585859, 'Recall': 0.7532467532467533, 'F1': 0.6590909090909091, 'P-value': np.float64(0.18)}
#
#  Synthetic series 11/500 (index 30)
# {'AUC-PR': 0.6706443336986158, 'Precision': 0.54, 'Recall': 0.6666666666666666, 'F1': 0.5966850828729282, 'P-value': np.float64(0.18)}
#
#  Synthetic series 12/500 (index 33)
# {'AUC-PR': 0.7550537795078843, 'Precision': 0.5619047619047619, 'Recall': 0.7108433734939759, 'F1': 0.6276595744680851, 'P-value': np.float64(0.18)}
#
#  Synthetic series 13/500 (index 36)
# {'AUC-PR': 0.5617745825983473, 'Precision': 0.47474747474747475, 'Recall': 0.618421052631579, 'F1': 0.5371428571428571, 'P-value': np.float64(0.18)}
#
#  Synthetic series 14/500 (index 39)
# {'AUC-PR': 0.9120456529695363, 'Precision': 0.6880733944954128, 'Recall': 0.974025974025974, 'F1': 0.8064516129032258, 'P-value': np.float64(0.18)}
#
#  Synthetic series 15/500 (index 42)
# {'AUC-PR': 0.7716745415209461, 'Precision': 0.5433070866141733, 'Recall': 0.8846153846153846, 'F1': 0.6731707317073171, 'P-value': np.float64(0.18)}
#
#  Synthetic series 16/500 (index 45)
# {'AUC-PR': 0.6274533077513141, 'Precision': 0.44, 'Recall': 0.6707317073170732, 'F1': 0.5314009661835749, 'P-value': np.float64(0.18)}
#
#  Synthetic series 17/500 (index 48)
# {'AUC-PR': 0.7699430542571276, 'Precision': 0.4666666666666667, 'Recall': 0.8860759493670886, 'F1': 0.611353711790393, 'P-value': np.float64(0.18)}
#
#  Synthetic series 18/500 (index 51)
# {'AUC-PR': 0.6679812088222122, 'Precision': 0.5204081632653061, 'Recall': 0.6891891891891891, 'F1': 0.5930232558139535, 'P-value': np.float64(0.18)}
#
#  Synthetic series 19/500 (index 54)
# {'AUC-PR': 0.838101431627939, 'Precision': 0.46540880503144655, 'Recall': 0.9367088607594937, 'F1': 0.6218487394957983, 'P-value': np.float64(0.18)}
#
#  Synthetic series 20/500 (index 57)
# {'AUC-PR': 0.7535084004208676, 'Precision': 0.5378787878787878, 'Recall': 0.8452380952380952, 'F1': 0.6574074074074074, 'P-value': np.float64(0.18)}
#
#  Synthetic series 21/500 (index 60)
# {'AUC-PR': 0.706078889780077, 'Precision': 0.5544554455445545, 'Recall': 0.7, 'F1': 0.6187845303867403, 'P-value': np.float64(0.18)}
#
#  Synthetic series 22/500 (index 63)
# {'AUC-PR': 0.36790194351040306, 'Precision': 0.3203125, 'Recall': 0.5466666666666666, 'F1': 0.4039408866995074, 'P-value': np.float64(0.18)}
#
#  Synthetic series 23/500 (index 66)
# {'AUC-PR': 0.5437282959668601, 'Precision': 0.33116883116883117, 'Recall': 0.6375, 'F1': 0.4358974358974359, 'P-value': np.float64(0.18)}
#
#  Synthetic series 24/500 (index 69)
# {'AUC-PR': 0.6818757403664989, 'Precision': 0.5056179775280899, 'Recall': 0.5844155844155844, 'F1': 0.5421686746987951, 'P-value': np.float64(0.18)}
#
#  Synthetic series 25/500 (index 72)
# {'AUC-PR': 0.7801418500210169, 'Precision': 0.6261682242990654, 'Recall': 0.7976190476190477, 'F1': 0.7015706806282722, 'P-value': np.float64(0.18)}
#
#  Synthetic series 26/500 (index 75)
# {'AUC-PR': 0.8139771049829326, 'Precision': 0.5725806451612904, 'Recall': 0.8765432098765432, 'F1': 0.6926829268292682, 'P-value': np.float64(0.19)}
#
#  Synthetic series 27/500 (index 78)
# {'AUC-PR': 0.6984982503785121, 'Precision': 0.3684210526315789, 'Recall': 0.8289473684210527, 'F1': 0.5101214574898786, 'P-value': np.float64(0.19)}
#
#  Synthetic series 28/500 (index 81)
# {'AUC-PR': 0.7187073860459344, 'Precision': 0.7761194029850746, 'Recall': 0.6190476190476191, 'F1': 0.6887417218543046, 'P-value': np.float64(0.19)}
#
#  Synthetic series 29/500 (index 84)
# {'AUC-PR': 0.7948566935703272, 'Precision': 0.7469879518072289, 'Recall': 0.7654320987654321, 'F1': 0.7560975609756098, 'P-value': np.float64(0.19)}
#
#  Synthetic series 30/500 (index 87)
# {'AUC-PR': 0.8032275800592453, 'Precision': 0.7111111111111111, 'Recall': 0.7710843373493976, 'F1': 0.7398843930635838, 'P-value': np.float64(0.19)}
#
#  Synthetic series 31/500 (index 90)
# {'AUC-PR': 0.7522649223044614, 'Precision': 0.5546218487394958, 'Recall': 0.8461538461538461, 'F1': 0.6700507614213198, 'P-value': np.float64(0.19)}
#
#  Synthetic series 32/500 (index 93)
# {'AUC-PR': 0.7002848644451546, 'Precision': 0.5568181818181818, 'Recall': 0.5975609756097561, 'F1': 0.5764705882352941, 'P-value': np.float64(0.19)}
#
#  Synthetic series 33/500 (index 96)
# {'AUC-PR': 0.7160916400701306, 'Precision': 0.5714285714285714, 'Recall': 0.8533333333333334, 'F1': 0.6844919786096256, 'P-value': np.float64(0.19)}
#
#  Synthetic series 34/500 (index 99)
# {'AUC-PR': 0.6639792901535722, 'Precision': 0.43703703703703706, 'Recall': 0.7972972972972973, 'F1': 0.5645933014354066, 'P-value': np.float64(0.19)}
#
#  Synthetic series 35/500 (index 102)
# {'AUC-PR': 0.8099678085718396, 'Precision': 0.6126126126126126, 'Recall': 0.8607594936708861, 'F1': 0.7157894736842105, 'P-value': np.float64(0.19)}
#
#  Synthetic series 36/500 (index 105)
# {'AUC-PR': 0.6466222011719792, 'Precision': 0.48214285714285715, 'Recall': 0.675, 'F1': 0.5625, 'P-value': np.float64(0.19)}
#
#  Synthetic series 37/500 (index 108)
# {'AUC-PR': 0.6570076961160274, 'Precision': 0.5922330097087378, 'Recall': 0.7530864197530864, 'F1': 0.6630434782608695, 'P-value': np.float64(0.19)}
#
#  Synthetic series 38/500 (index 111)
# {'AUC-PR': 0.5591472949560964, 'Precision': 0.47, 'Recall': 0.6527777777777778, 'F1': 0.5465116279069767, 'P-value': np.float64(0.19)}
#
#  Synthetic series 39/500 (index 114)
# {'AUC-PR': 0.7279671395909422, 'Precision': 0.61, 'Recall': 0.7625, 'F1': 0.6777777777777778, 'P-value': np.float64(0.19)}
#
#  Synthetic series 40/500 (index 117)
# {'AUC-PR': 0.8175801565255344, 'Precision': 0.5149253731343284, 'Recall': 0.8734177215189873, 'F1': 0.647887323943662, 'P-value': np.float64(0.19)}
#
#  Synthetic series 41/500 (index 120)
# {'AUC-PR': 0.6027922091075788, 'Precision': 0.5882352941176471, 'Recall': 0.5333333333333333, 'F1': 0.5594405594405595, 'P-value': np.float64(0.19)}
#
#  Synthetic series 42/500 (index 123)
# {'AUC-PR': 0.7446434056600599, 'Precision': 0.5271317829457365, 'Recall': 0.9066666666666666, 'F1': 0.6666666666666666, 'P-value': np.float64(0.19)}
#
#  Synthetic series 43/500 (index 126)
# {'AUC-PR': 0.5376858993013922, 'Precision': 0.475, 'Recall': 0.4810126582278481, 'F1': 0.4779874213836478, 'P-value': np.float64(0.19)}
#
#  Synthetic series 44/500 (index 129)
# {'AUC-PR': 0.6729443021988425, 'Precision': 0.574468085106383, 'Recall': 0.7397260273972602, 'F1': 0.6467065868263473, 'P-value': np.float64(0.19)}
#
#  Synthetic series 45/500 (index 132)
# {'AUC-PR': 0.6564847711084595, 'Precision': 0.5514018691588785, 'Recall': 0.7108433734939759, 'F1': 0.6210526315789474, 'P-value': np.float64(0.19)}
#
#  Synthetic series 46/500 (index 135)
# {'AUC-PR': 0.6027857695906592, 'Precision': 0.38345864661654133, 'Recall': 0.6071428571428571, 'F1': 0.4700460829493088, 'P-value': np.float64(0.19)}
#
#  Synthetic series 47/500 (index 138)
# {'AUC-PR': 0.5794655993148237, 'Precision': 0.3670886075949367, 'Recall': 0.7532467532467533, 'F1': 0.49361702127659574, 'P-value': np.float64(0.19)}
#
#  Synthetic series 48/500 (index 141)
# {'AUC-PR': 0.810334770380138, 'Precision': 0.4716981132075472, 'Recall': 0.9615384615384616, 'F1': 0.6329113924050633, 'P-value': np.float64(0.19)}
#
#  Synthetic series 49/500 (index 144)
# {'AUC-PR': 0.7512891414884668, 'Precision': 0.4444444444444444, 'Recall': 0.8888888888888888, 'F1': 0.5925925925925926, 'P-value': np.float64(0.19)}
#
#  Synthetic series 50/500 (index 147)
# {'AUC-PR': 0.8522608618776483, 'Precision': 0.5426356589147286, 'Recall': 0.8433734939759037, 'F1': 0.660377358490566, 'P-value': np.float64(0.19)}
#
#  Synthetic series 51/500 (index 150)
# {'AUC-PR': 0.7479420921331763, 'Precision': 0.5, 'Recall': 0.85, 'F1': 0.6296296296296297, 'P-value': np.float64(0.19)}
#
#  Synthetic series 52/500 (index 153)
# {'AUC-PR': 0.5887098784440258, 'Precision': 0.782608695652174, 'Recall': 0.46153846153846156, 'F1': 0.5806451612903226, 'P-value': np.float64(0.19)}
#
#  Synthetic series 53/500 (index 156)
# {'AUC-PR': 0.7628972204820175, 'Precision': 0.5078125, 'Recall': 0.8441558441558441, 'F1': 0.6341463414634146, 'P-value': np.float64(0.19)}
#
#  Synthetic series 54/500 (index 159)
# {'AUC-PR': 0.6434551804482026, 'Precision': 0.424, 'Recall': 0.6794871794871795, 'F1': 0.5221674876847291, 'P-value': np.float64(0.19)}
#
#  Synthetic series 55/500 (index 162)
# {'AUC-PR': 0.6576927588850241, 'Precision': 0.38571428571428573, 'Recall': 0.6923076923076923, 'F1': 0.4954128440366973, 'P-value': np.float64(0.19)}
#
#  Synthetic series 56/500 (index 165)
# {'AUC-PR': 0.6675153583981629, 'Precision': 0.6545454545454545, 'Recall': 0.4864864864864865, 'F1': 0.5581395348837209, 'P-value': np.float64(0.19)}
#
#  Synthetic series 57/500 (index 168)
# {'AUC-PR': 0.7641932493207316, 'Precision': 0.4676258992805755, 'Recall': 0.8783783783783784, 'F1': 0.6103286384976526, 'P-value': np.float64(0.19)}
#
#  Synthetic series 58/500 (index 171)
# {'AUC-PR': 0.7285340582978809, 'Precision': 0.6022727272727273, 'Recall': 0.7066666666666667, 'F1': 0.6503067484662577, 'P-value': np.float64(0.19)}
#
#  Synthetic series 59/500 (index 174)
# {'AUC-PR': 0.8094928361189168, 'Precision': 0.686046511627907, 'Recall': 0.7564102564102564, 'F1': 0.7195121951219512, 'P-value': np.float64(0.19)}
#
#  Synthetic series 60/500 (index 177)
# {'AUC-PR': 0.7190781473519956, 'Precision': 0.4576271186440678, 'Recall': 0.7397260273972602, 'F1': 0.5654450261780105, 'P-value': np.float64(0.19)}
#
#  Synthetic series 61/500 (index 180)
# {'AUC-PR': 0.7135616778751244, 'Precision': 0.5142857142857142, 'Recall': 0.6835443037974683, 'F1': 0.5869565217391305, 'P-value': np.float64(0.19)}
#
#  Synthetic series 62/500 (index 183)
# {'AUC-PR': 0.6989006003909441, 'Precision': 0.423841059602649, 'Recall': 0.927536231884058, 'F1': 0.5818181818181818, 'P-value': np.float64(0.19)}
#
#  Synthetic series 63/500 (index 186)
# {'AUC-PR': 0.5444160831178365, 'Precision': 0.35766423357664234, 'Recall': 0.620253164556962, 'F1': 0.4537037037037037, 'P-value': np.float64(0.19)}
#
#  Synthetic series 64/500 (index 189)
# {'AUC-PR': 0.693246970115609, 'Precision': 0.375, 'Recall': 0.825, 'F1': 0.515625, 'P-value': np.float64(0.19)}
#
#  Synthetic series 65/500 (index 192)
# {'AUC-PR': 0.7160695805476274, 'Precision': 0.6111111111111112, 'Recall': 0.7142857142857143, 'F1': 0.6586826347305389, 'P-value': np.float64(0.19)}
#
#  Synthetic series 66/500 (index 195)
# {'AUC-PR': 0.7601632456833978, 'Precision': 0.6132075471698113, 'Recall': 0.7738095238095238, 'F1': 0.6842105263157895, 'P-value': np.float64(0.19)}
#
#  Synthetic series 67/500 (index 198)
# {'AUC-PR': 0.8058945605341153, 'Precision': 0.38271604938271603, 'Recall': 0.8611111111111112, 'F1': 0.5299145299145299, 'P-value': np.float64(0.19)}
#
#  Synthetic series 68/500 (index 201)
# {'AUC-PR': 0.8236813851493984, 'Precision': 0.6435643564356436, 'Recall': 0.8227848101265823, 'F1': 0.7222222222222222, 'P-value': np.float64(0.19)}
#
#  Synthetic series 69/500 (index 204)
# {'AUC-PR': 0.6696014467336542, 'Precision': 0.6020408163265306, 'Recall': 0.7023809523809523, 'F1': 0.6483516483516484, 'P-value': np.float64(0.19)}
#
#  Synthetic series 70/500 (index 207)
# {'AUC-PR': 0.6584979212792589, 'Precision': 0.48, 'Recall': 0.631578947368421, 'F1': 0.5454545454545454, 'P-value': np.float64(0.19)}
#
#  Synthetic series 71/500 (index 210)
# {'AUC-PR': 0.8284398271680627, 'Precision': 0.6330275229357798, 'Recall': 0.8734177215189873, 'F1': 0.7340425531914894, 'P-value': np.float64(0.19)}
#
#  Synthetic series 72/500 (index 213)
# {'AUC-PR': 0.7018163628252458, 'Precision': 0.4956521739130435, 'Recall': 0.7307692307692307, 'F1': 0.5906735751295337, 'P-value': np.float64(0.19)}
#
#  Synthetic series 73/500 (index 216)
# {'AUC-PR': 0.6891631751424107, 'Precision': 0.3235294117647059, 'Recall': 0.8461538461538461, 'F1': 0.46808510638297873, 'P-value': np.float64(0.19)}
#
#  Synthetic series 74/500 (index 219)
# {'AUC-PR': 0.7004639978403776, 'Precision': 0.6301369863013698, 'Recall': 0.575, 'F1': 0.6013071895424836, 'P-value': np.float64(0.19)}
#
#  Synthetic series 75/500 (index 222)
# {'AUC-PR': 0.6608861448009118, 'Precision': 0.48717948717948717, 'Recall': 0.7808219178082192, 'F1': 0.6, 'P-value': np.float64(0.19)}
#
#  Synthetic series 76/500 (index 225)
# {'AUC-PR': 0.7348385270987071, 'Precision': 0.7567567567567568, 'Recall': 0.6746987951807228, 'F1': 0.7133757961783439, 'P-value': np.float64(0.2)}
#
#  Synthetic series 77/500 (index 228)
# {'AUC-PR': 0.7701835893110566, 'Precision': 0.6708860759493671, 'Recall': 0.7464788732394366, 'F1': 0.7066666666666667, 'P-value': np.float64(0.2)}
#
#  Synthetic series 78/500 (index 231)
# {'AUC-PR': 0.6011819986120109, 'Precision': 0.32941176470588235, 'Recall': 0.717948717948718, 'F1': 0.45161290322580644, 'P-value': np.float64(0.2)}
#
#  Synthetic series 79/500 (index 234)
# {'AUC-PR': 0.7166584628905922, 'Precision': 0.5853658536585366, 'Recall': 0.6575342465753424, 'F1': 0.6193548387096774, 'P-value': np.float64(0.2)}
#
#  Synthetic series 80/500 (index 237)
# {'AUC-PR': 0.7402302195959324, 'Precision': 0.4036144578313253, 'Recall': 0.881578947368421, 'F1': 0.5537190082644629, 'P-value': np.float64(0.2)}
#
#  Synthetic series 81/500 (index 240)
# {'AUC-PR': 0.6765014573875566, 'Precision': 0.3918918918918919, 'Recall': 0.7435897435897436, 'F1': 0.5132743362831859, 'P-value': np.float64(0.2)}
#
#  Synthetic series 82/500 (index 243)
# {'AUC-PR': 0.7391068286930887, 'Precision': 0.56, 'Recall': 0.8536585365853658, 'F1': 0.6763285024154589, 'P-value': np.float64(0.2)}
#
#  Synthetic series 83/500 (index 246)
# {'AUC-PR': 0.7367300997267463, 'Precision': 0.48031496062992124, 'Recall': 0.7922077922077922, 'F1': 0.5980392156862745, 'P-value': np.float64(0.2)}
#
#  Synthetic series 84/500 (index 249)
# {'AUC-PR': 0.676771050603209, 'Precision': 0.40993788819875776, 'Recall': 0.7857142857142857, 'F1': 0.5387755102040817, 'P-value': np.float64(0.2)}
#
#  Synthetic series 85/500 (index 252)
# {'AUC-PR': 0.807174815264559, 'Precision': 0.6494845360824743, 'Recall': 0.7682926829268293, 'F1': 0.7039106145251397, 'P-value': np.float64(0.2)}
#
#  Synthetic series 86/500 (index 255)
# {'AUC-PR': 0.5290281191642092, 'Precision': 0.3353658536585366, 'Recall': 0.6875, 'F1': 0.45081967213114754, 'P-value': np.float64(0.2)}
#
#  Synthetic series 87/500 (index 258)
# {'AUC-PR': 0.753591781932725, 'Precision': 0.5398230088495575, 'Recall': 0.782051282051282, 'F1': 0.6387434554973822, 'P-value': np.float64(0.2)}
#
#  Synthetic series 88/500 (index 261)
# {'AUC-PR': 0.586462908178029, 'Precision': 0.37777777777777777, 'Recall': 0.7183098591549296, 'F1': 0.49514563106796117, 'P-value': np.float64(0.2)}
#
#  Synthetic series 89/500 (index 264)
# {'AUC-PR': 0.8969248318336429, 'Precision': 0.4342105263157895, 'Recall': 0.9295774647887324, 'F1': 0.5919282511210763, 'P-value': np.float64(0.2)}
#
#  Synthetic series 90/500 (index 267)
# {'AUC-PR': 0.5642239969176434, 'Precision': 0.44871794871794873, 'Recall': 0.4666666666666667, 'F1': 0.45751633986928103, 'P-value': np.float64(0.2)}
#
#  Synthetic series 91/500 (index 270)
# {'AUC-PR': 0.7281316413547482, 'Precision': 0.5315315315315315, 'Recall': 0.7866666666666666, 'F1': 0.6344086021505376, 'P-value': np.float64(0.2)}
#
#  Synthetic series 92/500 (index 273)
# {'AUC-PR': 0.7760228369712633, 'Precision': 0.5433070866141733, 'Recall': 0.8734177215189873, 'F1': 0.6699029126213593, 'P-value': np.float64(0.2)}
#
#  Synthetic series 93/500 (index 276)
# {'AUC-PR': 0.5370543435131018, 'Precision': 0.35251798561151076, 'Recall': 0.6533333333333333, 'F1': 0.45794392523364486, 'P-value': np.float64(0.2)}
#
#  Synthetic series 94/500 (index 279)
# {'AUC-PR': 0.6628745019722204, 'Precision': 0.5294117647058824, 'Recall': 0.6666666666666666, 'F1': 0.5901639344262295, 'P-value': np.float64(0.2)}
#
#  Synthetic series 95/500 (index 282)
# {'AUC-PR': 0.6199986426058962, 'Precision': 0.421875, 'Recall': 0.6835443037974683, 'F1': 0.5217391304347826, 'P-value': np.float64(0.2)}
#
#  Synthetic series 96/500 (index 285)
# {'AUC-PR': 0.7499592376177127, 'Precision': 0.45, 'Recall': 0.7397260273972602, 'F1': 0.5595854922279793, 'P-value': np.float64(0.2)}
#
#  Synthetic series 97/500 (index 288)
# {'AUC-PR': 0.6896230362087997, 'Precision': 0.53125, 'Recall': 0.6623376623376623, 'F1': 0.5895953757225434, 'P-value': np.float64(0.2)}
#
#  Synthetic series 98/500 (index 291)
# {'AUC-PR': 0.8286325810853996, 'Precision': 0.4675324675324675, 'Recall': 0.9113924050632911, 'F1': 0.6180257510729614, 'P-value': np.float64(0.2)}
#
#  Synthetic series 99/500 (index 294)
# {'AUC-PR': 0.781987790338109, 'Precision': 0.5036496350364964, 'Recall': 0.8846153846153846, 'F1': 0.641860465116279, 'P-value': np.float64(0.2)}
#
#  Synthetic series 100/500 (index 297)
# {'AUC-PR': 0.7233821468884445, 'Precision': 0.38, 'Recall': 0.7808219178082192, 'F1': 0.5112107623318386, 'P-value': np.float64(0.2)}
#
#  Synthetic series 101/500 (index 300)
# {'AUC-PR': 0.7097738962443721, 'Precision': 0.460431654676259, 'Recall': 0.7710843373493976, 'F1': 0.5765765765765766, 'P-value': np.float64(0.2)}
#
#  Synthetic series 102/500 (index 303)
# {'AUC-PR': 0.4958839543548823, 'Precision': 0.3963963963963964, 'Recall': 0.5945945945945946, 'F1': 0.4756756756756757, 'P-value': np.float64(0.2)}
#
#  Synthetic series 103/500 (index 306)
# {'AUC-PR': 0.5356865308033485, 'Precision': 0.5, 'Recall': 0.4473684210526316, 'F1': 0.4722222222222222, 'P-value': np.float64(0.2)}
#
#  Synthetic series 104/500 (index 309)
# {'AUC-PR': 0.7238265188377846, 'Precision': 0.5175438596491229, 'Recall': 0.7972972972972973, 'F1': 0.6276595744680851, 'P-value': np.float64(0.2)}
#
#  Synthetic series 105/500 (index 312)
# {'AUC-PR': 0.8089500600792902, 'Precision': 0.6190476190476191, 'Recall': 0.7738095238095238, 'F1': 0.6878306878306878, 'P-value': np.float64(0.2)}
#
#  Synthetic series 106/500 (index 315)
# {'AUC-PR': 0.6586449443554497, 'Precision': 0.4745762711864407, 'Recall': 0.7272727272727273, 'F1': 0.5743589743589743, 'P-value': np.float64(0.2)}
#
#  Synthetic series 107/500 (index 318)
# {'AUC-PR': 0.8312424520451116, 'Precision': 0.6052631578947368, 'Recall': 0.9078947368421053, 'F1': 0.7263157894736842, 'P-value': np.float64(0.2)}
#
#  Synthetic series 108/500 (index 321)
# {'AUC-PR': 0.8203704916915656, 'Precision': 0.48175182481751827, 'Recall': 0.88, 'F1': 0.6226415094339622, 'P-value': np.float64(0.2)}
#
#  Synthetic series 109/500 (index 324)
# {'AUC-PR': 0.6159356759554764, 'Precision': 0.3884297520661157, 'Recall': 0.6266666666666667, 'F1': 0.47959183673469385, 'P-value': np.float64(0.2)}
#
#  Synthetic series 110/500 (index 327)
# {'AUC-PR': 0.7274272887637312, 'Precision': 0.44, 'Recall': 0.7051282051282052, 'F1': 0.541871921182266, 'P-value': np.float64(0.2)}
#
#  Synthetic series 111/500 (index 330)
# {'AUC-PR': 0.6712705989412155, 'Precision': 0.4233576642335766, 'Recall': 0.7733333333333333, 'F1': 0.5471698113207547, 'P-value': np.float64(0.2)}
#
#  Synthetic series 112/500 (index 333)
# {'AUC-PR': 0.520572705560069, 'Precision': 0.45454545454545453, 'Recall': 0.5, 'F1': 0.47619047619047616, 'P-value': np.float64(0.2)}
#
#  Synthetic series 113/500 (index 336)
# {'AUC-PR': 0.8325903334821044, 'Precision': 0.55, 'Recall': 0.8461538461538461, 'F1': 0.6666666666666666, 'P-value': np.float64(0.2)}
#
#  Synthetic series 114/500 (index 339)
# {'AUC-PR': 0.5738354343866614, 'Precision': 0.494949494949495, 'Recall': 0.6049382716049383, 'F1': 0.5444444444444444, 'P-value': np.float64(0.2)}
#
#  Synthetic series 115/500 (index 342)
# {'AUC-PR': 0.7172396570397083, 'Precision': 0.6891891891891891, 'Recall': 0.6219512195121951, 'F1': 0.6538461538461539, 'P-value': np.float64(0.2)}
#
#  Synthetic series 116/500 (index 345)
# {'AUC-PR': 0.6746262316460643, 'Precision': 0.4420289855072464, 'Recall': 0.7721518987341772, 'F1': 0.5622119815668203, 'P-value': np.float64(0.2)}
#
#  Synthetic series 117/500 (index 348)
# {'AUC-PR': 0.7229020625730141, 'Precision': 0.5072463768115942, 'Recall': 0.9090909090909091, 'F1': 0.6511627906976745, 'P-value': np.float64(0.2)}
#
#  Synthetic series 118/500 (index 351)
# {'AUC-PR': 0.6748136990764071, 'Precision': 0.5454545454545454, 'Recall': 0.6835443037974683, 'F1': 0.6067415730337079, 'P-value': np.float64(0.2)}
#
#  Synthetic series 119/500 (index 354)
# {'AUC-PR': 0.6260015707443328, 'Precision': 0.5, 'Recall': 0.5375, 'F1': 0.5180722891566265, 'P-value': np.float64(0.2)}
#
#  Synthetic series 120/500 (index 357)
# {'AUC-PR': 0.7493843639298047, 'Precision': 0.6238532110091743, 'Recall': 0.8607594936708861, 'F1': 0.723404255319149, 'P-value': np.float64(0.2)}
#
#  Synthetic series 121/500 (index 360)
# {'AUC-PR': 0.6234348740746939, 'Precision': 0.3559322033898305, 'Recall': 0.863013698630137, 'F1': 0.504, 'P-value': np.float64(0.2)}
#
#  Synthetic series 122/500 (index 363)
# {'AUC-PR': 0.7686939047446698, 'Precision': 0.6666666666666666, 'Recall': 0.7435897435897436, 'F1': 0.703030303030303, 'P-value': np.float64(0.2)}
#
#  Synthetic series 123/500 (index 366)
# {'AUC-PR': 0.725699105554121, 'Precision': 0.44666666666666666, 'Recall': 0.788235294117647, 'F1': 0.5702127659574469, 'P-value': np.float64(0.2)}
#
#  Synthetic series 124/500 (index 369)
# {'AUC-PR': 0.5863880341623142, 'Precision': 0.46511627906976744, 'Recall': 0.7692307692307693, 'F1': 0.5797101449275363, 'P-value': np.float64(0.2)}
#
#  Synthetic series 125/500 (index 372)
# {'AUC-PR': 0.7028494005987969, 'Precision': 0.38323353293413176, 'Recall': 0.8421052631578947, 'F1': 0.5267489711934157, 'P-value': np.float64(0.2)}
#
#  Synthetic series 126/500 (index 375)
# {'AUC-PR': 0.5705628346004188, 'Precision': 0.4067796610169492, 'Recall': 0.6153846153846154, 'F1': 0.4897959183673469, 'P-value': np.float64(0.21)}
#
#  Synthetic series 127/500 (index 378)
# {'AUC-PR': 0.7313465002103505, 'Precision': 0.4861111111111111, 'Recall': 0.875, 'F1': 0.625, 'P-value': np.float64(0.21)}
#
#  Synthetic series 128/500 (index 381)
# {'AUC-PR': 0.8078049276405229, 'Precision': 0.6153846153846154, 'Recall': 0.8205128205128205, 'F1': 0.7032967032967034, 'P-value': np.float64(0.21)}
#
#  Synthetic series 129/500 (index 384)
# {'AUC-PR': 0.6846589399369778, 'Precision': 0.5978260869565217, 'Recall': 0.6547619047619048, 'F1': 0.625, 'P-value': np.float64(0.21)}
#
#  Synthetic series 130/500 (index 387)
# {'AUC-PR': 0.6970166457156703, 'Precision': 0.4144736842105263, 'Recall': 0.8873239436619719, 'F1': 0.5650224215246636, 'P-value': np.float64(0.21)}
#
#  Synthetic series 131/500 (index 390)
# {'AUC-PR': 0.774386489510164, 'Precision': 0.6306306306306306, 'Recall': 0.8536585365853658, 'F1': 0.7253886010362695, 'P-value': np.float64(0.21)}
#
#  Synthetic series 132/500 (index 393)
# {'AUC-PR': 0.807574443538481, 'Precision': 0.6568627450980392, 'Recall': 0.9305555555555556, 'F1': 0.7701149425287356, 'P-value': np.float64(0.21)}
#
#  Synthetic series 133/500 (index 396)
# {'AUC-PR': 0.8305456600479846, 'Precision': 0.7397260273972602, 'Recall': 0.675, 'F1': 0.7058823529411765, 'P-value': np.float64(0.21)}
#
#  Synthetic series 134/500 (index 399)
# {'AUC-PR': 0.7038387471540347, 'Precision': 0.49166666666666664, 'Recall': 0.7866666666666666, 'F1': 0.6051282051282051, 'P-value': np.float64(0.21)}
#
#  Synthetic series 135/500 (index 402)
# {'AUC-PR': 0.6458958734666995, 'Precision': 0.5476190476190477, 'Recall': 0.8846153846153846, 'F1': 0.6764705882352942, 'P-value': np.float64(0.21)}
#
#  Synthetic series 136/500 (index 405)
# {'AUC-PR': 0.4771637032974553, 'Precision': 0.4148936170212766, 'Recall': 0.4875, 'F1': 0.4482758620689655, 'P-value': np.float64(0.21)}
#
#  Synthetic series 137/500 (index 408)
# {'AUC-PR': 0.7559215448979332, 'Precision': 0.5258620689655172, 'Recall': 0.7625, 'F1': 0.6224489795918368, 'P-value': np.float64(0.21)}
#
#  Synthetic series 138/500 (index 411)
# {'AUC-PR': 0.7653919202967668, 'Precision': 0.5371900826446281, 'Recall': 0.8666666666666667, 'F1': 0.6632653061224489, 'P-value': np.float64(0.21)}
#
#  Synthetic series 139/500 (index 414)
# {'AUC-PR': 0.7132641257686587, 'Precision': 0.5730337078651685, 'Recall': 0.6623376623376623, 'F1': 0.6144578313253012, 'P-value': np.float64(0.21)}
#
#  Synthetic series 140/500 (index 417)
# {'AUC-PR': 0.7898417178554412, 'Precision': 0.6605504587155964, 'Recall': 0.8780487804878049, 'F1': 0.7539267015706806, 'P-value': np.float64(0.21)}
#
#  Synthetic series 141/500 (index 420)
# {'AUC-PR': 0.6890395765198948, 'Precision': 0.4909090909090909, 'Recall': 0.72, 'F1': 0.5837837837837838, 'P-value': np.float64(0.21)}
#
#  Synthetic series 142/500 (index 423)
# {'AUC-PR': 0.6765138592656226, 'Precision': 0.5315315315315315, 'Recall': 0.7564102564102564, 'F1': 0.6243386243386243, 'P-value': np.float64(0.21)}
#
#  Synthetic series 143/500 (index 426)
# {'AUC-PR': 0.7214968136743086, 'Precision': 0.5, 'Recall': 0.7468354430379747, 'F1': 0.5989847715736041, 'P-value': np.float64(0.21)}
#
#  Synthetic series 144/500 (index 429)
# {'AUC-PR': 0.6642382966361365, 'Precision': 0.5217391304347826, 'Recall': 0.5925925925925926, 'F1': 0.5549132947976878, 'P-value': np.float64(0.21)}
#
#  Synthetic series 145/500 (index 432)
# {'AUC-PR': 0.6935920024776986, 'Precision': 0.315, 'Recall': 0.8181818181818182, 'F1': 0.4548736462093863, 'P-value': np.float64(0.21)}
#
#  Synthetic series 146/500 (index 435)
# {'AUC-PR': 0.719990191888483, 'Precision': 0.5531914893617021, 'Recall': 0.6842105263157895, 'F1': 0.611764705882353, 'P-value': np.float64(0.21)}
#
#  Synthetic series 147/500 (index 438)
# {'AUC-PR': 0.5677324699064714, 'Precision': 0.35, 'Recall': 0.6621621621621622, 'F1': 0.45794392523364486, 'P-value': np.float64(0.21)}
#
#  Synthetic series 148/500 (index 441)
# {'AUC-PR': 0.7232631908473245, 'Precision': 0.42857142857142855, 'Recall': 0.7875, 'F1': 0.5550660792951542, 'P-value': np.float64(0.21)}
#
#  Synthetic series 149/500 (index 444)
# {'AUC-PR': 0.7252585127892008, 'Precision': 0.6136363636363636, 'Recall': 0.6506024096385542, 'F1': 0.631578947368421, 'P-value': np.float64(0.21)}
#
#  Synthetic series 150/500 (index 447)
# {'AUC-PR': 0.8121150965137518, 'Precision': 0.43558282208588955, 'Recall': 0.8875, 'F1': 0.5843621399176955, 'P-value': np.float64(0.21)}
#
#  Synthetic series 151/500 (index 450)
# {'AUC-PR': 0.7198130793408813, 'Precision': 0.45652173913043476, 'Recall': 0.8181818181818182, 'F1': 0.586046511627907, 'P-value': np.float64(0.21)}
#
#  Synthetic series 152/500 (index 453)
# {'AUC-PR': 0.7274541761547086, 'Precision': 0.39664804469273746, 'Recall': 0.8875, 'F1': 0.5482625482625483, 'P-value': np.float64(0.21)}
#
#  Synthetic series 153/500 (index 456)
# {'AUC-PR': 0.7675114758441053, 'Precision': 0.6210526315789474, 'Recall': 0.7468354430379747, 'F1': 0.6781609195402298, 'P-value': np.float64(0.21)}
#
#  Synthetic series 154/500 (index 459)
# {'AUC-PR': 0.6836225535346753, 'Precision': 0.4315068493150685, 'Recall': 0.8181818181818182, 'F1': 0.5650224215246636, 'P-value': np.float64(0.21)}
#
#  Synthetic series 155/500 (index 462)
# {'AUC-PR': 0.7511370668450645, 'Precision': 0.5686274509803921, 'Recall': 0.7435897435897436, 'F1': 0.6444444444444445, 'P-value': np.float64(0.21)}
#
#  Synthetic series 156/500 (index 465)
# {'AUC-PR': 0.6416487592965958, 'Precision': 0.35195530726256985, 'Recall': 0.7974683544303798, 'F1': 0.4883720930232558, 'P-value': np.float64(0.21)}
#
#  Synthetic series 157/500 (index 468)
# {'AUC-PR': 0.65412051315732, 'Precision': 0.36024844720496896, 'Recall': 0.8055555555555556, 'F1': 0.4978540772532189, 'P-value': np.float64(0.21)}
#
#  Synthetic series 158/500 (index 471)
# {'AUC-PR': 0.7132960808538437, 'Precision': 0.4473684210526316, 'Recall': 0.8947368421052632, 'F1': 0.5964912280701754, 'P-value': np.float64(0.21)}
#
#  Synthetic series 159/500 (index 474)
# {'AUC-PR': 0.6723984560999857, 'Precision': 0.6022727272727273, 'Recall': 0.6883116883116883, 'F1': 0.6424242424242425, 'P-value': np.float64(0.21)}
#
#  Synthetic series 160/500 (index 477)
# {'AUC-PR': 0.6347624810394321, 'Precision': 0.6621621621621622, 'Recall': 0.6712328767123288, 'F1': 0.6666666666666666, 'P-value': np.float64(0.21)}
#
#  Synthetic series 161/500 (index 480)
# {'AUC-PR': 0.8159018335717885, 'Precision': 0.4859154929577465, 'Recall': 0.8414634146341463, 'F1': 0.6160714285714286, 'P-value': np.float64(0.21)}
#
#  Synthetic series 162/500 (index 483)
# {'AUC-PR': 0.6882935334274132, 'Precision': 0.46715328467153283, 'Recall': 0.8311688311688312, 'F1': 0.5981308411214953, 'P-value': np.float64(0.21)}
#
#  Synthetic series 163/500 (index 486)
# {'AUC-PR': 0.637304494863634, 'Precision': 0.6052631578947368, 'Recall': 0.575, 'F1': 0.5897435897435898, 'P-value': np.float64(0.21)}
#
#  Synthetic series 164/500 (index 489)
# {'AUC-PR': 0.5639725805017248, 'Precision': 0.30120481927710846, 'Recall': 0.7352941176470589, 'F1': 0.42735042735042733, 'P-value': np.float64(0.21)}
#
#  Synthetic series 165/500 (index 492)
# {'AUC-PR': 0.7833930743532004, 'Precision': 0.422360248447205, 'Recall': 0.918918918918919, 'F1': 0.5787234042553191, 'P-value': np.float64(0.21)}
#
#  Synthetic series 166/500 (index 495)
# {'AUC-PR': 0.7911033657061209, 'Precision': 0.352112676056338, 'Recall': 0.8928571428571429, 'F1': 0.5050505050505051, 'P-value': np.float64(0.21)}
#
#  Synthetic series 167/500 (index 498)
# {'AUC-PR': 0.6953839316366411, 'Precision': 0.35403726708074534, 'Recall': 0.7037037037037037, 'F1': 0.47107438016528924, 'P-value': np.float64(0.21)}
#
#  Synthetic series 168/500 (index 501)
# {'AUC-PR': 0.6241420673753157, 'Precision': 0.48214285714285715, 'Recall': 0.7105263157894737, 'F1': 0.574468085106383, 'P-value': np.float64(0.21)}
#
#  Synthetic series 169/500 (index 504)
# {'AUC-PR': 0.5605299696893414, 'Precision': 0.49523809523809526, 'Recall': 0.7323943661971831, 'F1': 0.5909090909090909, 'P-value': np.float64(0.21)}
#
#  Synthetic series 170/500 (index 507)
# {'AUC-PR': 0.8597138811671017, 'Precision': 0.37222222222222223, 'Recall': 0.9436619718309859, 'F1': 0.5338645418326693, 'P-value': np.float64(0.21)}
#
#  Synthetic series 171/500 (index 510)
# {'AUC-PR': 0.7720644664034407, 'Precision': 0.5673076923076923, 'Recall': 0.7468354430379747, 'F1': 0.644808743169399, 'P-value': np.float64(0.21)}
#
#  Synthetic series 172/500 (index 513)
# {'AUC-PR': 0.6568749260436894, 'Precision': 0.4117647058823529, 'Recall': 0.7671232876712328, 'F1': 0.5358851674641149, 'P-value': np.float64(0.21)}
#
#  Synthetic series 173/500 (index 516)
# {'AUC-PR': 0.7049192866018437, 'Precision': 0.46715328467153283, 'Recall': 0.7529411764705882, 'F1': 0.5765765765765766, 'P-value': np.float64(0.21)}
#
#  Synthetic series 174/500 (index 519)
# {'AUC-PR': 0.6966506485384949, 'Precision': 0.40310077519379844, 'Recall': 0.6753246753246753, 'F1': 0.5048543689320388, 'P-value': np.float64(0.21)}
#
#  Synthetic series 175/500 (index 522)
# {'AUC-PR': 0.6656111503932837, 'Precision': 0.5368421052631579, 'Recall': 0.6219512195121951, 'F1': 0.576271186440678, 'P-value': np.float64(0.21)}
#
#  Synthetic series 176/500 (index 525)
# {'AUC-PR': 0.8045554951434746, 'Precision': 0.5338983050847458, 'Recall': 0.7682926829268293, 'F1': 0.63, 'P-value': np.float64(0.22)}
#
#  Synthetic series 177/500 (index 528)
# {'AUC-PR': 0.7837220315946113, 'Precision': 0.5959595959595959, 'Recall': 0.8194444444444444, 'F1': 0.6900584795321637, 'P-value': np.float64(0.22)}
#
#  Synthetic series 178/500 (index 531)
# {'AUC-PR': 0.8210137359417373, 'Precision': 0.4864864864864865, 'Recall': 0.8571428571428571, 'F1': 0.6206896551724138, 'P-value': np.float64(0.22)}
#
#  Synthetic series 179/500 (index 534)
# {'AUC-PR': 0.6077180346151614, 'Precision': 0.4953271028037383, 'Recall': 0.654320987654321, 'F1': 0.5638297872340425, 'P-value': np.float64(0.22)}
#
#  Synthetic series 180/500 (index 537)
# {'AUC-PR': 0.7040987006122311, 'Precision': 0.3386243386243386, 'Recall': 0.8311688311688312, 'F1': 0.48120300751879697, 'P-value': np.float64(0.22)}
#
#  Synthetic series 181/500 (index 540)
# {'AUC-PR': 0.7109974139824963, 'Precision': 0.568, 'Recall': 0.8658536585365854, 'F1': 0.6859903381642513, 'P-value': np.float64(0.22)}
#
#  Synthetic series 182/500 (index 543)
# {'AUC-PR': 0.8069487938192453, 'Precision': 0.5245901639344263, 'Recall': 0.810126582278481, 'F1': 0.6368159203980099, 'P-value': np.float64(0.22)}
#
#  Synthetic series 183/500 (index 546)
# {'AUC-PR': 0.7454970262594794, 'Precision': 0.5225225225225225, 'Recall': 0.7733333333333333, 'F1': 0.6236559139784946, 'P-value': np.float64(0.22)}
#
#  Synthetic series 184/500 (index 549)
# {'AUC-PR': 0.6825978525106933, 'Precision': 0.6043956043956044, 'Recall': 0.7236842105263158, 'F1': 0.6586826347305389, 'P-value': np.float64(0.22)}
#
#  Synthetic series 185/500 (index 552)
# {'AUC-PR': 0.6536871067836616, 'Precision': 0.46774193548387094, 'Recall': 0.7631578947368421, 'F1': 0.58, 'P-value': np.float64(0.22)}
#
#  Synthetic series 186/500 (index 555)
# {'AUC-PR': 0.7505726536120982, 'Precision': 0.3850267379679144, 'Recall': 0.9230769230769231, 'F1': 0.5433962264150943, 'P-value': np.float64(0.22)}
#
#  Synthetic series 187/500 (index 558)
# {'AUC-PR': 0.6580106805350951, 'Precision': 0.5609756097560976, 'Recall': 0.6052631578947368, 'F1': 0.5822784810126582, 'P-value': np.float64(0.22)}
#
#  Synthetic series 188/500 (index 561)
# {'AUC-PR': 0.6753118210739396, 'Precision': 0.4067796610169492, 'Recall': 0.64, 'F1': 0.49740932642487046, 'P-value': np.float64(0.22)}
#
#  Synthetic series 189/500 (index 564)
# {'AUC-PR': 0.8337777330903651, 'Precision': 0.5967741935483871, 'Recall': 0.891566265060241, 'F1': 0.714975845410628, 'P-value': np.float64(0.22)}
#
#  Synthetic series 190/500 (index 567)
# {'AUC-PR': 0.8993074205218916, 'Precision': 0.7659574468085106, 'Recall': 0.8888888888888888, 'F1': 0.8228571428571428, 'P-value': np.float64(0.22)}
#
#  Synthetic series 191/500 (index 570)
# {'AUC-PR': 0.7390048640281549, 'Precision': 0.3961038961038961, 'Recall': 0.7922077922077922, 'F1': 0.5281385281385281, 'P-value': np.float64(0.22)}
#
#  Synthetic series 192/500 (index 573)
# {'AUC-PR': 0.8110583990984023, 'Precision': 0.5669291338582677, 'Recall': 0.8780487804878049, 'F1': 0.6889952153110048, 'P-value': np.float64(0.22)}
#
#  Synthetic series 193/500 (index 576)
# {'AUC-PR': 0.7202181930422153, 'Precision': 0.6060606060606061, 'Recall': 0.7792207792207793, 'F1': 0.6818181818181818, 'P-value': np.float64(0.22)}
#
#  Synthetic series 194/500 (index 579)
# {'AUC-PR': 0.8990282300588986, 'Precision': 0.5413533834586466, 'Recall': 0.935064935064935, 'F1': 0.6857142857142857, 'P-value': np.float64(0.22)}
#
#  Synthetic series 195/500 (index 582)
# {'AUC-PR': 0.7200413867796841, 'Precision': 0.4827586206896552, 'Recall': 0.6666666666666666, 'F1': 0.56, 'P-value': np.float64(0.22)}
#
#  Synthetic series 196/500 (index 585)
# {'AUC-PR': 0.7800332621067431, 'Precision': 0.41818181818181815, 'Recall': 0.9078947368421053, 'F1': 0.5726141078838174, 'P-value': np.float64(0.22)}
#
#  Synthetic series 197/500 (index 588)
# {'AUC-PR': 0.8113828768320868, 'Precision': 0.48091603053435117, 'Recall': 0.8513513513513513, 'F1': 0.6146341463414634, 'P-value': np.float64(0.22)}
#
#  Synthetic series 198/500 (index 591)
# {'AUC-PR': 0.8386502559817961, 'Precision': 0.4482758620689655, 'Recall': 0.8783783783783784, 'F1': 0.593607305936073, 'P-value': np.float64(0.22)}
#
#  Synthetic series 199/500 (index 594)
# {'AUC-PR': 0.719403637164768, 'Precision': 0.5833333333333334, 'Recall': 0.7411764705882353, 'F1': 0.6528497409326425, 'P-value': np.float64(0.22)}
#
#  Synthetic series 200/500 (index 597)
# {'AUC-PR': 0.6204098477636629, 'Precision': 0.5882352941176471, 'Recall': 0.6578947368421053, 'F1': 0.6211180124223602, 'P-value': np.float64(0.22)}
#
#  Synthetic series 201/500 (index 600)
# {'AUC-PR': 0.8029229757016595, 'Precision': 0.6741573033707865, 'Recall': 0.7792207792207793, 'F1': 0.7228915662650602, 'P-value': np.float64(0.22)}
#
#  Synthetic series 202/500 (index 603)
# {'AUC-PR': 0.7645410376046303, 'Precision': 0.6060606060606061, 'Recall': 0.8, 'F1': 0.6896551724137931, 'P-value': np.float64(0.22)}
#
#  Synthetic series 203/500 (index 606)
# {'AUC-PR': 0.6033320951879628, 'Precision': 0.5360824742268041, 'Recall': 0.6753246753246753, 'F1': 0.5977011494252874, 'P-value': np.float64(0.22)}
#
#  Synthetic series 204/500 (index 609)
# {'AUC-PR': 0.6989997019715402, 'Precision': 0.3273809523809524, 'Recall': 0.7333333333333333, 'F1': 0.45267489711934156, 'P-value': np.float64(0.22)}
#
#  Synthetic series 205/500 (index 612)
# {'AUC-PR': 0.7197884858638975, 'Precision': 0.3974358974358974, 'Recall': 0.8493150684931506, 'F1': 0.5414847161572053, 'P-value': np.float64(0.22)}
#
#  Synthetic series 206/500 (index 615)
# {'AUC-PR': 0.5473720789045392, 'Precision': 0.4094488188976378, 'Recall': 0.7536231884057971, 'F1': 0.5306122448979592, 'P-value': np.float64(0.22)}
#
#  Synthetic series 207/500 (index 618)
# {'AUC-PR': 0.6999337509321732, 'Precision': 0.4460431654676259, 'Recall': 0.7560975609756098, 'F1': 0.5610859728506787, 'P-value': np.float64(0.22)}
#
#  Synthetic series 208/500 (index 621)
# {'AUC-PR': 0.7802567941529227, 'Precision': 0.5476190476190477, 'Recall': 0.8625, 'F1': 0.6699029126213593, 'P-value': np.float64(0.22)}
#
#  Synthetic series 209/500 (index 624)
# {'AUC-PR': 0.6971373249116612, 'Precision': 0.5523809523809524, 'Recall': 0.725, 'F1': 0.6270270270270271, 'P-value': np.float64(0.22)}
#
#  Synthetic series 210/500 (index 627)
# {'AUC-PR': 0.612116701716327, 'Precision': 0.5822784810126582, 'Recall': 0.575, 'F1': 0.5786163522012578, 'P-value': np.float64(0.22)}
#
#  Synthetic series 211/500 (index 630)
# {'AUC-PR': 0.8267877906263228, 'Precision': 0.46621621621621623, 'Recall': 0.8625, 'F1': 0.6052631578947368, 'P-value': np.float64(0.22)}
#
#  Synthetic series 212/500 (index 633)
# {'AUC-PR': 0.7467147433973516, 'Precision': 0.4375, 'Recall': 0.9058823529411765, 'F1': 0.5900383141762452, 'P-value': np.float64(0.22)}
#
#  Synthetic series 213/500 (index 636)
# {'AUC-PR': 0.5640472271574541, 'Precision': 0.40298507462686567, 'Recall': 0.6923076923076923, 'F1': 0.5094339622641509, 'P-value': np.float64(0.22)}
#
#  Synthetic series 214/500 (index 639)
# {'AUC-PR': 0.6997442540928585, 'Precision': 0.5972222222222222, 'Recall': 0.5443037974683544, 'F1': 0.5695364238410596, 'P-value': np.float64(0.22)}
#
#  Synthetic series 215/500 (index 642)
# {'AUC-PR': 0.5745547555237558, 'Precision': 0.5232558139534884, 'Recall': 0.5769230769230769, 'F1': 0.5487804878048781, 'P-value': np.float64(0.22)}
#
#  Synthetic series 216/500 (index 645)
# {'AUC-PR': 0.6778395751450121, 'Precision': 0.4011299435028249, 'Recall': 0.8987341772151899, 'F1': 0.5546875, 'P-value': np.float64(0.22)}
#
#  Synthetic series 217/500 (index 648)
# {'AUC-PR': 0.8078537473609915, 'Precision': 0.4305555555555556, 'Recall': 0.8051948051948052, 'F1': 0.5610859728506787, 'P-value': np.float64(0.22)}
#
#  Synthetic series 218/500 (index 651)
# {'AUC-PR': 0.740321495038109, 'Precision': 0.48905109489051096, 'Recall': 0.9054054054054054, 'F1': 0.6350710900473934, 'P-value': np.float64(0.22)}
#
#  Synthetic series 219/500 (index 654)
# {'AUC-PR': 0.7825479496384421, 'Precision': 0.44525547445255476, 'Recall': 0.8472222222222222, 'F1': 0.583732057416268, 'P-value': np.float64(0.22)}
#
#  Synthetic series 220/500 (index 657)
# {'AUC-PR': 0.7915358028484288, 'Precision': 0.5431034482758621, 'Recall': 0.7682926829268293, 'F1': 0.6363636363636364, 'P-value': np.float64(0.22)}
#
#  Synthetic series 221/500 (index 660)
# {'AUC-PR': 0.8029712111281393, 'Precision': 0.4896551724137931, 'Recall': 0.8554216867469879, 'F1': 0.6228070175438597, 'P-value': np.float64(0.22)}
#
#  Synthetic series 222/500 (index 663)
# {'AUC-PR': 0.8328446372303362, 'Precision': 0.512, 'Recall': 0.8, 'F1': 0.624390243902439, 'P-value': np.float64(0.22)}
#
#  Synthetic series 223/500 (index 666)
# {'AUC-PR': 0.6323689933188591, 'Precision': 0.494949494949495, 'Recall': 0.6125, 'F1': 0.547486033519553, 'P-value': np.float64(0.22)}
#
#  Synthetic series 224/500 (index 669)
# {'AUC-PR': 0.7910352489862049, 'Precision': 0.6017699115044248, 'Recall': 0.8192771084337349, 'F1': 0.6938775510204082, 'P-value': np.float64(0.22)}
#
#  Synthetic series 225/500 (index 672)
# {'AUC-PR': 0.6882388517823991, 'Precision': 0.7073170731707317, 'Recall': 0.6987951807228916, 'F1': 0.703030303030303, 'P-value': np.float64(0.22)}
#
#  Synthetic series 226/500 (index 675)
# {'AUC-PR': 0.5897060543535346, 'Precision': 0.29518072289156627, 'Recall': 0.7101449275362319, 'F1': 0.41702127659574467, 'P-value': np.float64(0.23)}
#
#  Synthetic series 227/500 (index 678)
# {'AUC-PR': 0.7807289030872123, 'Precision': 0.6853932584269663, 'Recall': 0.7721518987341772, 'F1': 0.7261904761904762, 'P-value': np.float64(0.23)}
#
#  Synthetic series 228/500 (index 681)
# {'AUC-PR': 0.6965449138290846, 'Precision': 0.746268656716418, 'Recall': 0.6410256410256411, 'F1': 0.6896551724137931, 'P-value': np.float64(0.23)}
#
#  Synthetic series 229/500 (index 684)
# {'AUC-PR': 0.6752818810240124, 'Precision': 0.575, 'Recall': 0.5679012345679012, 'F1': 0.5714285714285714, 'P-value': np.float64(0.23)}
#
#  Synthetic series 230/500 (index 687)
# {'AUC-PR': 0.619334149691814, 'Precision': 0.44329896907216493, 'Recall': 0.5584415584415584, 'F1': 0.4942528735632184, 'P-value': np.float64(0.23)}
#
#  Synthetic series 231/500 (index 690)
# {'AUC-PR': 0.6197515668644049, 'Precision': 0.45098039215686275, 'Recall': 0.5609756097560976, 'F1': 0.5, 'P-value': np.float64(0.23)}
#
#  Synthetic series 232/500 (index 693)
# {'AUC-PR': 0.6681102979834382, 'Precision': 0.5188679245283019, 'Recall': 0.7051282051282052, 'F1': 0.5978260869565217, 'P-value': np.float64(0.23)}
#
#  Synthetic series 233/500 (index 696)
# {'AUC-PR': 0.6009486565544897, 'Precision': 0.432, 'Recall': 0.6835443037974683, 'F1': 0.5294117647058824, 'P-value': np.float64(0.23)}
#
#  Synthetic series 234/500 (index 699)
# {'AUC-PR': 0.5316272965128133, 'Precision': 0.373134328358209, 'Recall': 0.6666666666666666, 'F1': 0.4784688995215311, 'P-value': np.float64(0.23)}
#
#  Synthetic series 235/500 (index 702)
# {'AUC-PR': 0.784119253445828, 'Precision': 0.5789473684210527, 'Recall': 0.8048780487804879, 'F1': 0.673469387755102, 'P-value': np.float64(0.23)}
#
#  Synthetic series 236/500 (index 705)
# {'AUC-PR': 0.7409041187526331, 'Precision': 0.43609022556390975, 'Recall': 0.7631578947368421, 'F1': 0.5550239234449761, 'P-value': np.float64(0.23)}
#
#  Synthetic series 237/500 (index 708)
# {'AUC-PR': 0.7008552630612563, 'Precision': 0.6630434782608695, 'Recall': 0.7261904761904762, 'F1': 0.6931818181818182, 'P-value': np.float64(0.23)}
#
#  Synthetic series 238/500 (index 711)
# {'AUC-PR': 0.7419446977181344, 'Precision': 0.49206349206349204, 'Recall': 0.7654320987654321, 'F1': 0.5990338164251208, 'P-value': np.float64(0.23)}
#
#  Synthetic series 239/500 (index 714)
# {'AUC-PR': 0.7469046233722345, 'Precision': 0.35751295336787564, 'Recall': 0.92, 'F1': 0.5149253731343284, 'P-value': np.float64(0.23)}
#
#  Synthetic series 240/500 (index 717)
# {'AUC-PR': 0.7315294802993344, 'Precision': 0.5462962962962963, 'Recall': 0.7763157894736842, 'F1': 0.6413043478260869, 'P-value': np.float64(0.23)}
#
#  Synthetic series 241/500 (index 720)
# {'AUC-PR': 0.5478606848934517, 'Precision': 0.5161290322580645, 'Recall': 0.5783132530120482, 'F1': 0.5454545454545454, 'P-value': np.float64(0.23)}
#
#  Synthetic series 242/500 (index 723)
# {'AUC-PR': 0.7218488109904249, 'Precision': 0.6021505376344086, 'Recall': 0.6666666666666666, 'F1': 0.632768361581921, 'P-value': np.float64(0.23)}
#
#  Synthetic series 243/500 (index 726)
# {'AUC-PR': 0.761793443791378, 'Precision': 0.46564885496183206, 'Recall': 0.7530864197530864, 'F1': 0.5754716981132075, 'P-value': np.float64(0.23)}
#
#  Synthetic series 244/500 (index 729)
# {'AUC-PR': 0.7517928625119613, 'Precision': 0.5121951219512195, 'Recall': 0.7777777777777778, 'F1': 0.6176470588235294, 'P-value': np.float64(0.23)}
#
#  Synthetic series 245/500 (index 732)
# {'AUC-PR': 0.6238968326270049, 'Precision': 0.5157894736842106, 'Recall': 0.5764705882352941, 'F1': 0.5444444444444444, 'P-value': np.float64(0.23)}
#
#  Synthetic series 246/500 (index 735)
# {'AUC-PR': 0.7913231736312619, 'Precision': 0.859375, 'Recall': 0.6707317073170732, 'F1': 0.7534246575342466, 'P-value': np.float64(0.23)}
#
#  Synthetic series 247/500 (index 738)
# {'AUC-PR': 0.6724004497273353, 'Precision': 0.4727272727272727, 'Recall': 0.6666666666666666, 'F1': 0.5531914893617021, 'P-value': np.float64(0.23)}
#
#  Synthetic series 248/500 (index 741)
# {'AUC-PR': 0.7022435106547211, 'Precision': 0.3793103448275862, 'Recall': 0.7638888888888888, 'F1': 0.5069124423963134, 'P-value': np.float64(0.23)}
#
#  Synthetic series 249/500 (index 744)
# {'AUC-PR': 0.7473244141264912, 'Precision': 0.7027027027027027, 'Recall': 0.6341463414634146, 'F1': 0.6666666666666666, 'P-value': np.float64(0.23)}
#
#  Synthetic series 250/500 (index 747)
# {'AUC-PR': 0.775786726772264, 'Precision': 0.5943396226415094, 'Recall': 0.8076923076923077, 'F1': 0.6847826086956522, 'P-value': np.float64(0.23)}
#
#  Synthetic series 251/500 (index 751)
# {'AUC-PR': 0.6790322167659908, 'Precision': 0.6282051282051282, 'Recall': 0.6282051282051282, 'F1': 0.6282051282051282, 'P-value': np.float64(0.23)}
#
#  Synthetic series 252/500 (index 754)
# {'AUC-PR': 0.6697265269556899, 'Precision': 0.4172661870503597, 'Recall': 0.7341772151898734, 'F1': 0.5321100917431193, 'P-value': np.float64(0.23)}
#
#  Synthetic series 253/500 (index 757)
# {'AUC-PR': 0.751791264249335, 'Precision': 0.4852941176470588, 'Recall': 0.8461538461538461, 'F1': 0.616822429906542, 'P-value': np.float64(0.23)}
#
#  Synthetic series 254/500 (index 760)
# {'AUC-PR': 0.806881306972225, 'Precision': 0.5609756097560976, 'Recall': 0.8414634146341463, 'F1': 0.6731707317073171, 'P-value': np.float64(0.23)}
#
#  Synthetic series 255/500 (index 763)
# {'AUC-PR': 0.808311342131966, 'Precision': 0.6987951807228916, 'Recall': 0.7160493827160493, 'F1': 0.7073170731707317, 'P-value': np.float64(0.23)}
#
#  Synthetic series 256/500 (index 766)
# {'AUC-PR': 0.8902423986817203, 'Precision': 0.609375, 'Recall': 0.9512195121951219, 'F1': 0.7428571428571429, 'P-value': np.float64(0.23)}
#
#  Synthetic series 257/500 (index 769)
# {'AUC-PR': 0.706631382809264, 'Precision': 0.6263736263736264, 'Recall': 0.7037037037037037, 'F1': 0.6627906976744186, 'P-value': np.float64(0.23)}
#
#  Synthetic series 258/500 (index 772)
# {'AUC-PR': 0.7078841139616361, 'Precision': 0.5517241379310345, 'Recall': 0.6075949367088608, 'F1': 0.5783132530120482, 'P-value': np.float64(0.23)}
#
#  Synthetic series 259/500 (index 775)
# {'AUC-PR': 0.6444360901017648, 'Precision': 0.4519230769230769, 'Recall': 0.5875, 'F1': 0.5108695652173914, 'P-value': np.float64(0.23)}
#
#  Synthetic series 260/500 (index 778)
# {'AUC-PR': 0.6867529012820737, 'Precision': 0.5533980582524272, 'Recall': 0.75, 'F1': 0.6368715083798883, 'P-value': np.float64(0.23)}
#
#  Synthetic series 261/500 (index 781)
# {'AUC-PR': 0.8403951377263166, 'Precision': 0.6186440677966102, 'Recall': 0.8902439024390244, 'F1': 0.73, 'P-value': np.float64(0.23)}
#
#  Synthetic series 262/500 (index 784)
# ...
# {'AUC-PR': 0.6651822805907154, 'Precision': 0.5142857142857142, 'Recall': 0.7105263157894737, 'F1': 0.5966850828729282, 'P-value': np.float64(0.26)}
#
#  Synthetic series 416/500 (index 1246)
# {'AUC-PR': 0.6642943329605585, 'Precision': 0.45535714285714285, 'Recall': 0.6710526315789473, 'F1': 0.5425531914893617, 'P-value': np.float64(0.26)}
#
#  Synthetic series 417/500 (index 1249)
# {'AUC-PR': 0.6268893528098521, 'Precision': 0.43356643356643354, 'Recall': 0.8051948051948052, 'F1': 0.5636363636363636, 'P-value': np.float64(0.26)}
#
#  Synthetic series 418/500 (index 1252)
# {'AUC-PR': 0.7487843548675555, 'Precision': 0.7428571428571429, 'Recall': 0.6419753086419753, 'F1': 0.6887417218543046, 'P-value': np.float64(0.26)}
#
#  Synthetic series 419/500 (index 1255)
# {'AUC-PR': 0.7447375812436248, 'Precision': 0.49572649572649574, 'Recall': 0.7945205479452054, 'F1': 0.6105263157894737, 'P-value': np.float64(0.26)}
#
#  Synthetic series 420/500 (index 1258)
# {'AUC-PR': 0.7661501549231738, 'Precision': 0.5955056179775281, 'Recall': 0.7361111111111112, 'F1': 0.6583850931677019, 'P-value': np.float64(0.26)}
#
#  Synthetic series 421/500 (index 1261)
# {'AUC-PR': 0.735882885235801, 'Precision': 0.5180722891566265, 'Recall': 0.6142857142857143, 'F1': 0.5620915032679739, 'P-value': np.float64(0.26)}
#
#  Synthetic series 422/500 (index 1264)
# {'AUC-PR': 0.8180390033596936, 'Precision': 0.5179856115107914, 'Recall': 0.972972972972973, 'F1': 0.676056338028169, 'P-value': np.float64(0.26)}
#
#  Synthetic series 423/500 (index 1267)
# {'AUC-PR': 0.7076764218978226, 'Precision': 0.5903614457831325, 'Recall': 0.620253164556962, 'F1': 0.6049382716049383, 'P-value': np.float64(0.26)}
#
#  Synthetic series 424/500 (index 1270)
# {'AUC-PR': 0.6817985217393066, 'Precision': 0.47107438016528924, 'Recall': 0.7307692307692307, 'F1': 0.5728643216080402, 'P-value': np.float64(0.26)}
#
#  Synthetic series 425/500 (index 1273)
# {'AUC-PR': 0.8469272649860177, 'Precision': 0.6666666666666666, 'Recall': 0.8108108108108109, 'F1': 0.7317073170731707, 'P-value': np.float64(0.26)}
#
#  Synthetic series 426/500 (index 1276)
# {'AUC-PR': 0.9213004124936957, 'Precision': 0.8433734939759037, 'Recall': 0.8433734939759037, 'F1': 0.8433734939759037, 'P-value': np.float64(0.27)}
#
#  Synthetic series 427/500 (index 1279)
# {'AUC-PR': 0.6979983441448315, 'Precision': 0.5169491525423728, 'Recall': 0.8026315789473685, 'F1': 0.6288659793814433, 'P-value': np.float64(0.27)}
#
#  Synthetic series 428/500 (index 1282)
# {'AUC-PR': 0.6620560921787445, 'Precision': 0.5344827586206896, 'Recall': 0.7294117647058823, 'F1': 0.6169154228855721, 'P-value': np.float64(0.27)}
#
#  Synthetic series 429/500 (index 1285)
# {'AUC-PR': 0.5616750758149791, 'Precision': 0.41721854304635764, 'Recall': 0.8181818181818182, 'F1': 0.5526315789473685, 'P-value': np.float64(0.27)}
#
#  Synthetic series 430/500 (index 1288)
# {'AUC-PR': 0.4511973969846308, 'Precision': 0.33727810650887574, 'Recall': 0.7307692307692307, 'F1': 0.46153846153846156, 'P-value': np.float64(0.27)}
#
#  Synthetic series 431/500 (index 1291)
# {'AUC-PR': 0.7248655613803101, 'Precision': 0.5283018867924528, 'Recall': 0.7, 'F1': 0.6021505376344086, 'P-value': np.float64(0.27)}
#
#  Synthetic series 432/500 (index 1294)
# {'AUC-PR': 0.6716673783760574, 'Precision': 0.5277777777777778, 'Recall': 0.75, 'F1': 0.6195652173913043, 'P-value': np.float64(0.27)}
#
#  Synthetic series 433/500 (index 1297)
# {'AUC-PR': 0.7262677246625064, 'Precision': 0.5742574257425742, 'Recall': 0.7532467532467533, 'F1': 0.651685393258427, 'P-value': np.float64(0.27)}
#
#  Synthetic series 434/500 (index 1300)
# {'AUC-PR': 0.6730370342689252, 'Precision': 0.4523809523809524, 'Recall': 0.75, 'F1': 0.5643564356435643, 'P-value': np.float64(0.27)}
#
#  Synthetic series 435/500 (index 1303)
# {'AUC-PR': 0.6471316602660742, 'Precision': 0.48623853211009177, 'Recall': 0.6794871794871795, 'F1': 0.5668449197860963, 'P-value': np.float64(0.27)}
#
#  Synthetic series 436/500 (index 1306)
# {'AUC-PR': 0.8110000273034009, 'Precision': 0.592, 'Recall': 0.8809523809523809, 'F1': 0.7081339712918661, 'P-value': np.float64(0.27)}
#
#  Synthetic series 437/500 (index 1309)
# {'AUC-PR': 0.6973582657382549, 'Precision': 0.6835443037974683, 'Recall': 0.6352941176470588, 'F1': 0.6585365853658537, 'P-value': np.float64(0.27)}
#
#  Synthetic series 438/500 (index 1312)
# {'AUC-PR': 0.6205586988669489, 'Precision': 0.4090909090909091, 'Recall': 0.7974683544303798, 'F1': 0.5407725321888412, 'P-value': np.float64(0.27)}
#
#  Synthetic series 439/500 (index 1315)
# {'AUC-PR': 0.7255532512850433, 'Precision': 0.38513513513513514, 'Recall': 0.7402597402597403, 'F1': 0.5066666666666667, 'P-value': np.float64(0.27)}
#
#  Synthetic series 440/500 (index 1318)
# {'AUC-PR': 0.8731569076809599, 'Precision': 0.6019417475728155, 'Recall': 0.8732394366197183, 'F1': 0.7126436781609196, 'P-value': np.float64(0.27)}
#
#  Synthetic series 441/500 (index 1321)
# {'AUC-PR': 0.7562901942238189, 'Precision': 0.6263736263736264, 'Recall': 0.7037037037037037, 'F1': 0.6627906976744186, 'P-value': np.float64(0.27)}
#
#  Synthetic series 442/500 (index 1324)
# {'AUC-PR': 0.690323467562055, 'Precision': 0.49074074074074076, 'Recall': 0.6883116883116883, 'F1': 0.572972972972973, 'P-value': np.float64(0.27)}
#
#  Synthetic series 443/500 (index 1327)
# {'AUC-PR': 0.7693487788817361, 'Precision': 0.5405405405405406, 'Recall': 0.7228915662650602, 'F1': 0.6185567010309279, 'P-value': np.float64(0.27)}
#
#  Synthetic series 444/500 (index 1330)
# {'AUC-PR': 0.7573600271080707, 'Precision': 0.7164179104477612, 'Recall': 0.5925925925925926, 'F1': 0.6486486486486487, 'P-value': np.float64(0.27)}
#
#  Synthetic series 445/500 (index 1333)
# {'AUC-PR': 0.7051806734857126, 'Precision': 0.5083333333333333, 'Recall': 0.7349397590361446, 'F1': 0.6009852216748769, 'P-value': np.float64(0.27)}
#
#  Synthetic series 446/500 (index 1336)
# {'AUC-PR': 0.816737775415446, 'Precision': 0.6285714285714286, 'Recall': 0.8148148148148148, 'F1': 0.7096774193548387, 'P-value': np.float64(0.27)}
#
#  Synthetic series 447/500 (index 1339)
# {'AUC-PR': 0.6877284928159559, 'Precision': 0.5670103092783505, 'Recall': 0.6875, 'F1': 0.6214689265536724, 'P-value': np.float64(0.27)}
#
#  Synthetic series 448/500 (index 1342)
# {'AUC-PR': 0.798939167446531, 'Precision': 0.4585987261146497, 'Recall': 0.9, 'F1': 0.6075949367088608, 'P-value': np.float64(0.27)}
#
#  Synthetic series 449/500 (index 1345)
# {'AUC-PR': 0.6787027820783863, 'Precision': 0.4351145038167939, 'Recall': 0.7307692307692307, 'F1': 0.5454545454545454, 'P-value': np.float64(0.27)}
#
#  Synthetic series 450/500 (index 1348)
# {'AUC-PR': 0.7377957176069845, 'Precision': 0.6071428571428571, 'Recall': 0.6071428571428571, 'F1': 0.6071428571428571, 'P-value': np.float64(0.27)}
#
#  Synthetic series 451/500 (index 1351)
# {'AUC-PR': 0.6367877388633485, 'Precision': 0.37142857142857144, 'Recall': 0.8333333333333334, 'F1': 0.5138339920948617, 'P-value': np.float64(0.27)}
#
#  Synthetic series 452/500 (index 1354)
# {'AUC-PR': 0.8826872318637201, 'Precision': 0.7608695652173914, 'Recall': 0.8641975308641975, 'F1': 0.8092485549132948, 'P-value': np.float64(0.27)}
#
#  Synthetic series 453/500 (index 1357)
# {'AUC-PR': 0.7211462978469404, 'Precision': 0.4146341463414634, 'Recall': 0.7611940298507462, 'F1': 0.5368421052631579, 'P-value': np.float64(0.27)}
#
#  Synthetic series 454/500 (index 1360)
# {'AUC-PR': 0.7155347750524006, 'Precision': 0.4603174603174603, 'Recall': 0.7160493827160493, 'F1': 0.5603864734299517, 'P-value': np.float64(0.27)}
#
#  Synthetic series 455/500 (index 1363)
# {'AUC-PR': 0.838185143880192, 'Precision': 0.5267175572519084, 'Recall': 0.8846153846153846, 'F1': 0.6602870813397129, 'P-value': np.float64(0.27)}
#
#  Synthetic series 456/500 (index 1366)
# {'AUC-PR': 0.6556526661803581, 'Precision': 0.631578947368421, 'Recall': 0.6857142857142857, 'F1': 0.6575342465753424, 'P-value': np.float64(0.27)}
#
#  Synthetic series 457/500 (index 1369)
# {'AUC-PR': 0.7818581580760509, 'Precision': 0.5396825396825397, 'Recall': 0.8831168831168831, 'F1': 0.6699507389162561, 'P-value': np.float64(0.27)}
#
#  Synthetic series 458/500 (index 1372)
# {'AUC-PR': 0.715345297643073, 'Precision': 0.40425531914893614, 'Recall': 0.76, 'F1': 0.5277777777777778, 'P-value': np.float64(0.27)}
#
#  Synthetic series 459/500 (index 1375)
# {'AUC-PR': 0.8668675105787912, 'Precision': 0.7093023255813954, 'Recall': 0.8026315789473685, 'F1': 0.7530864197530864, 'P-value': np.float64(0.27)}
#
#  Synthetic series 460/500 (index 1378)
# {'AUC-PR': 0.678675907299006, 'Precision': 0.4881889763779528, 'Recall': 0.7848101265822784, 'F1': 0.6019417475728155, 'P-value': np.float64(0.27)}
#
#  Synthetic series 461/500 (index 1381)
# {'AUC-PR': 0.7731552153877121, 'Precision': 0.5042016806722689, 'Recall': 0.8108108108108109, 'F1': 0.6217616580310881, 'P-value': np.float64(0.27)}
#
#  Synthetic series 462/500 (index 1384)
# {'AUC-PR': 0.7948736591471709, 'Precision': 0.6213592233009708, 'Recall': 0.8421052631578947, 'F1': 0.7150837988826816, 'P-value': np.float64(0.27)}
#
#  Synthetic series 463/500 (index 1387)
# {'AUC-PR': 0.787610966072569, 'Precision': 0.6, 'Recall': 0.7307692307692307, 'F1': 0.6589595375722543, 'P-value': np.float64(0.27)}
#
#  Synthetic series 464/500 (index 1390)
# {'AUC-PR': 0.7290506891152352, 'Precision': 0.5588235294117647, 'Recall': 0.76, 'F1': 0.6440677966101694, 'P-value': np.float64(0.27)}
#
#  Synthetic series 465/500 (index 1393)
# {'AUC-PR': 0.7427296109190176, 'Precision': 0.45588235294117646, 'Recall': 0.8985507246376812, 'F1': 0.6048780487804878, 'P-value': np.float64(0.27)}
#
#  Synthetic series 466/500 (index 1396)
# {'AUC-PR': 0.638731471248205, 'Precision': 0.44166666666666665, 'Recall': 0.7464788732394366, 'F1': 0.5549738219895288, 'P-value': np.float64(0.27)}
#
#  Synthetic series 467/500 (index 1399)
# {'AUC-PR': 0.7060134032625128, 'Precision': 0.5740740740740741, 'Recall': 0.775, 'F1': 0.6595744680851063, 'P-value': np.float64(0.27)}
#
#  Synthetic series 468/500 (index 1402)
# {'AUC-PR': 0.8664074879984764, 'Precision': 0.5934959349593496, 'Recall': 0.9240506329113924, 'F1': 0.7227722772277227, 'P-value': np.float64(0.27)}
#
#  Synthetic series 469/500 (index 1405)
# {'AUC-PR': 0.6005733178074881, 'Precision': 0.47959183673469385, 'Recall': 0.5802469135802469, 'F1': 0.5251396648044693, 'P-value': np.float64(0.27)}
#
#  Synthetic series 470/500 (index 1408)
# {'AUC-PR': 0.63740319975432, 'Precision': 0.4032258064516129, 'Recall': 0.6329113924050633, 'F1': 0.49261083743842365, 'P-value': np.float64(0.27)}
#
#  Synthetic series 471/500 (index 1411)
# {'AUC-PR': 0.6743521078059672, 'Precision': 0.42028985507246375, 'Recall': 0.8285714285714286, 'F1': 0.5576923076923077, 'P-value': np.float64(0.27)}
#
#  Synthetic series 472/500 (index 1414)
# {'AUC-PR': 0.7789441615782803, 'Precision': 0.4573643410852713, 'Recall': 0.7564102564102564, 'F1': 0.5700483091787439, 'P-value': np.float64(0.27)}
#
#  Synthetic series 473/500 (index 1417)
# {'AUC-PR': 0.6874634605851591, 'Precision': 0.4552238805970149, 'Recall': 0.7625, 'F1': 0.5700934579439252, 'P-value': np.float64(0.27)}
#
#  Synthetic series 474/500 (index 1420)
# {'AUC-PR': 0.6006107954217768, 'Precision': 0.5, 'Recall': 0.7215189873417721, 'F1': 0.5906735751295337, 'P-value': np.float64(0.27)}
#
#  Synthetic series 475/500 (index 1423)
# {'AUC-PR': 0.8306848637381357, 'Precision': 0.5177304964539007, 'Recall': 0.9358974358974359, 'F1': 0.6666666666666666, 'P-value': np.float64(0.27)}
#
#  Synthetic series 476/500 (index 1426)
# {'AUC-PR': 0.7420223515726572, 'Precision': 0.48854961832061067, 'Recall': 0.8311688311688312, 'F1': 0.6153846153846154, 'P-value': np.float64(0.28)}
#
#  Synthetic series 477/500 (index 1429)
# {'AUC-PR': 0.6141286737307915, 'Precision': 0.4392523364485981, 'Recall': 0.5875, 'F1': 0.5026737967914439, 'P-value': np.float64(0.28)}
#
#  Synthetic series 478/500 (index 1432)
# {'AUC-PR': 0.7712619171439911, 'Precision': 0.4430379746835443, 'Recall': 0.8860759493670886, 'F1': 0.5907172995780591, 'P-value': np.float64(0.28)}
#
#  Synthetic series 479/500 (index 1435)
# {'AUC-PR': 0.7839497914091151, 'Precision': 0.3793103448275862, 'Recall': 0.8571428571428571, 'F1': 0.5258964143426295, 'P-value': np.float64(0.28)}
#
#  Synthetic series 480/500 (index 1438)
# {'AUC-PR': 0.6120560672139153, 'Precision': 0.5584415584415584, 'Recall': 0.524390243902439, 'F1': 0.5408805031446541, 'P-value': np.float64(0.28)}
#
#  Synthetic series 481/500 (index 1441)
# {'AUC-PR': 0.6568537994519213, 'Precision': 0.6022727272727273, 'Recall': 0.654320987654321, 'F1': 0.6272189349112426, 'P-value': np.float64(0.28)}
#
#  Synthetic series 482/500 (index 1444)
# {'AUC-PR': 0.7524148495296011, 'Precision': 0.525, 'Recall': 0.8076923076923077, 'F1': 0.6363636363636364, 'P-value': np.float64(0.28)}
#
#  Synthetic series 483/500 (index 1447)
# {'AUC-PR': 0.7733371941815392, 'Precision': 0.5182481751824818, 'Recall': 0.8658536585365854, 'F1': 0.6484018264840182, 'P-value': np.float64(0.28)}
#
#  Synthetic series 484/500 (index 1450)
# {'AUC-PR': 0.8380477394608608, 'Precision': 0.48412698412698413, 'Recall': 0.8840579710144928, 'F1': 0.6256410256410256, 'P-value': np.float64(0.28)}
#
#  Synthetic series 485/500 (index 1453)
# {'AUC-PR': 0.5881131236479683, 'Precision': 0.30857142857142855, 'Recall': 0.6923076923076923, 'F1': 0.4268774703557312, 'P-value': np.float64(0.28)}
#
#  Synthetic series 486/500 (index 1456)
# {'AUC-PR': 0.5871353071426183, 'Precision': 0.35454545454545455, 'Recall': 0.5416666666666666, 'F1': 0.42857142857142855, 'P-value': np.float64(0.28)}
#
#  Synthetic series 487/500 (index 1459)
# {'AUC-PR': 0.5548071085361278, 'Precision': 0.4, 'Recall': 0.631578947368421, 'F1': 0.4897959183673469, 'P-value': np.float64(0.28)}
#
#  Synthetic series 488/500 (index 1462)
# {'AUC-PR': 0.7674262463449989, 'Precision': 0.6770833333333334, 'Recall': 0.7831325301204819, 'F1': 0.7262569832402235, 'P-value': np.float64(0.28)}
#
#  Synthetic series 489/500 (index 1465)
# {'AUC-PR': 0.8787875251506997, 'Precision': 0.43859649122807015, 'Recall': 0.974025974025974, 'F1': 0.6048387096774194, 'P-value': np.float64(0.28)}
#
#  Synthetic series 490/500 (index 1468)
# {'AUC-PR': 0.7277265886842003, 'Precision': 0.5315315315315315, 'Recall': 0.7468354430379747, 'F1': 0.6210526315789474, 'P-value': np.float64(0.28)}
#
#  Synthetic series 491/500 (index 1471)
# {'AUC-PR': 0.7695361122134389, 'Precision': 0.6626506024096386, 'Recall': 0.6707317073170732, 'F1': 0.6666666666666666, 'P-value': np.float64(0.28)}
#
#  Synthetic series 492/500 (index 1474)
# {'AUC-PR': 0.7804945781262641, 'Precision': 0.6262626262626263, 'Recall': 0.7848101265822784, 'F1': 0.6966292134831461, 'P-value': np.float64(0.28)}
#
#  Synthetic series 493/500 (index 1477)
# {'AUC-PR': 0.791481148655191, 'Precision': 0.6436781609195402, 'Recall': 0.7088607594936709, 'F1': 0.6746987951807228, 'P-value': np.float64(0.28)}
#
#  Synthetic series 494/500 (index 1480)
# {'AUC-PR': 0.6492647017224674, 'Precision': 0.6086956521739131, 'Recall': 0.7, 'F1': 0.6511627906976745, 'P-value': np.float64(0.28)}
#
#  Synthetic series 495/500 (index 1483)
# {'AUC-PR': 0.8132784097011405, 'Precision': 0.5, 'Recall': 0.8227848101265823, 'F1': 0.6220095693779905, 'P-value': np.float64(0.28)}
#
#  Synthetic series 496/500 (index 1486)
# {'AUC-PR': 0.4922729470937693, 'Precision': 0.30994152046783624, 'Recall': 0.6973684210526315, 'F1': 0.4291497975708502, 'P-value': np.float64(0.28)}
#
#  Synthetic series 497/500 (index 1489)
# {'AUC-PR': 0.7336652856709149, 'Precision': 0.5588235294117647, 'Recall': 0.7037037037037037, 'F1': 0.6229508196721312, 'P-value': np.float64(0.28)}
#
#  Synthetic series 498/500 (index 1492)
# {'AUC-PR': 0.7771437530836929, 'Precision': 0.6041666666666666, 'Recall': 0.7341772151898734, 'F1': 0.6628571428571428, 'P-value': np.float64(0.28)}
#
#  Synthetic series 499/500 (index 1495)
# {'AUC-PR': 0.597639947669912, 'Precision': 0.5428571428571428, 'Recall': 0.4691358024691358, 'F1': 0.5033112582781457, 'P-value': np.float64(0.28)}
#
#  Synthetic series 500/500 (index 1499)
# {'AUC-PR': 0.7410800773018045, 'Precision': 0.6483516483516484, 'Recall': 0.7283950617283951, 'F1': 0.686046511627907, 'P-value': np.float64(0.28)}

# %%
plt.figure(figsize=(7, 3))

plt.plot(
    ks,
    mean_recall,
    marker="o",
    markersize=6,
    linewidth=1.2,
    label="threshold = 0.6"
)

plt.fill_between(
    ks,
    lower,
    upper,
    alpha=0.3,
    label="±1 std (threshold = 0.6)"
)

plt.ylabel("Recall")
plt.title(
    "Recall vs Anticipation\n"
    "(a) LSTM trained on exogenous data"
)
plt.grid(alpha=0.3)
plt.legend()
plt.tick_params(axis='x', labelbottom=False)
plt.ylim(0.45, 1.05)

plt.show()

# %%
plt.figure(figsize=(5, 3))

plt.plot(
    ks,
    mean_recall,
    marker="o",
    markersize=5,
    label="threshold = 0.6"
)

plt.fill_between(
    ks,
    lower,
    upper,
    alpha=0.3,
    label="±1 std (threshold = 0.6)"
)

plt.ylabel("Recall")
plt.title(
    "(a) LSTM trained on exogenous data"
)
plt.grid(alpha=0.3)
plt.legend()
plt.xlabel("Anticipation (k)")
# plt.tick_params(axis='x', labelbottom=False)
plt.ylim(0.45, 1.05)

plt.savefig("../paper/images/recall_vs_anticipation_exogenous_data_h.png", dpi=300, bbox_inches='tight')  

plt.show()

# %%
test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=[0.18, 0.42],
    num_series=config["data"]["num_series_test"],
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

indices = np.linspace(0, len(test_series) - 1, 500, dtype=int)

for count, i in enumerate(indices):
    df = test_series[i]

    print(
        f"\n Synthetic series {count + 1}/{len(indices)} "
        f"(index {i})"
    )

    metrics, ks, recalls = evaluate_and_plot_streaming(
        model,
        df,
        device,
        lookahead=config["data"]["lookahead"],
        plot=False,
        title="P-model time series with extreme event labels and LSTM prediction"
    )

    print(metrics)

    all_metrics.append(metrics)
    all_recalls.append(recalls)


# ---------- Aggregate recalls ----------
all_recalls = np.array(all_recalls)  

mean_recall = np.nanmean(all_recalls, axis=0)
std_recall = np.nanstd(all_recalls, axis=0)

# Clip to valid recall range
lower = np.clip(mean_recall - std_recall, 0, 1)
upper = np.clip(mean_recall + std_recall, 0, 1)
# Out:
# [0.18, 0.42]
#  Synthetic series 1/500 (index 0)
# {'AUC-PR': 0.7889979806185733, 'Precision': 0.5963302752293578, 'Recall': 0.8227848101265823, 'F1': 0.6914893617021277, 'P-value': np.float64(0.18)}
#
#  Synthetic series 2/500 (index 3)
# {'AUC-PR': 0.6184040180513102, 'Precision': 0.3984375, 'Recall': 0.68, 'F1': 0.5024630541871922, 'P-value': np.float64(0.18)}
#
#  Synthetic series 3/500 (index 6)
# {'AUC-PR': 0.6608610780035719, 'Precision': 0.46956521739130436, 'Recall': 0.6835443037974683, 'F1': 0.5567010309278351, 'P-value': np.float64(0.18)}
#
#  Synthetic series 4/500 (index 9)
# {'AUC-PR': 0.5474084149618331, 'Precision': 0.4485981308411215, 'Recall': 0.6153846153846154, 'F1': 0.518918918918919, 'P-value': np.float64(0.18)}
#
#  Synthetic series 5/500 (index 12)
# {'AUC-PR': 0.8143864188813964, 'Precision': 0.5182481751824818, 'Recall': 0.8658536585365854, 'F1': 0.6484018264840182, 'P-value': np.float64(0.18)}
#
#  Synthetic series 6/500 (index 15)
# {'AUC-PR': 0.7031874074379266, 'Precision': 0.5284552845528455, 'Recall': 0.8125, 'F1': 0.6403940886699507, 'P-value': np.float64(0.18)}
#
#  Synthetic series 7/500 (index 18)
# {'AUC-PR': 0.6061442650348541, 'Precision': 0.3732394366197183, 'Recall': 0.6794871794871795, 'F1': 0.4818181818181818, 'P-value': np.float64(0.18)}
#
#  Synthetic series 8/500 (index 21)
# {'AUC-PR': 0.7722808018460986, 'Precision': 0.5289855072463768, 'Recall': 0.9240506329113924, 'F1': 0.6728110599078341, 'P-value': np.float64(0.18)}
#
#  Synthetic series 9/500 (index 24)
# {'AUC-PR': 0.7070740320936848, 'Precision': 0.4818181818181818, 'Recall': 0.7162162162162162, 'F1': 0.5760869565217391, 'P-value': np.float64(0.18)}
#
#  Synthetic series 10/500 (index 27)
# {'AUC-PR': 0.6699700035960475, 'Precision': 0.4649122807017544, 'Recall': 0.6794871794871795, 'F1': 0.5520833333333334, 'P-value': np.float64(0.18)}
#
#  Synthetic series 11/500 (index 30)
# {'AUC-PR': 0.46277236822409046, 'Precision': 0.4406779661016949, 'Recall': 0.6933333333333334, 'F1': 0.538860103626943, 'P-value': np.float64(0.18)}
#
#  Synthetic series 12/500 (index 33)
# {'AUC-PR': 0.8716340013878837, 'Precision': 0.4962962962962963, 'Recall': 0.881578947368421, 'F1': 0.6350710900473934, 'P-value': np.float64(0.19)}
#
#  Synthetic series 13/500 (index 36)
# {'AUC-PR': 0.7379681681764637, 'Precision': 0.7959183673469388, 'Recall': 0.52, 'F1': 0.6290322580645161, 'P-value': np.float64(0.19)}
#
#  Synthetic series 14/500 (index 39)
# {'AUC-PR': 0.566643724036824, 'Precision': 0.5154639175257731, 'Recall': 0.6172839506172839, 'F1': 0.5617977528089888, 'P-value': np.float64(0.19)}
#
#  Synthetic series 15/500 (index 42)
# {'AUC-PR': 0.7829997479545217, 'Precision': 0.4689655172413793, 'Recall': 0.9315068493150684, 'F1': 0.6238532110091743, 'P-value': np.float64(0.19)}
#
#  Synthetic series 16/500 (index 45)
# {'AUC-PR': 0.7188272655587841, 'Precision': 0.3872832369942196, 'Recall': 0.8375, 'F1': 0.5296442687747036, 'P-value': np.float64(0.19)}
#
#  Synthetic series 17/500 (index 48)
# {'AUC-PR': 0.6372583213748174, 'Precision': 0.6875, 'Recall': 0.55, 'F1': 0.6111111111111112, 'P-value': np.float64(0.19)}
#
#  Synthetic series 18/500 (index 51)
# {'AUC-PR': 0.653261027395747, 'Precision': 0.49514563106796117, 'Recall': 0.6144578313253012, 'F1': 0.5483870967741935, 'P-value': np.float64(0.19)}
#
#  Synthetic series 19/500 (index 54)
# {'AUC-PR': 0.5437882099185634, 'Precision': 0.5789473684210527, 'Recall': 0.4230769230769231, 'F1': 0.4888888888888889, 'P-value': np.float64(0.19)}
#
#  Synthetic series 20/500 (index 57)
# {'AUC-PR': 0.7360132202155458, 'Precision': 0.43137254901960786, 'Recall': 0.825, 'F1': 0.5665236051502146, 'P-value': np.float64(0.19)}
#
#  Synthetic series 21/500 (index 60)
# {'AUC-PR': 0.6271049925494991, 'Precision': 0.711864406779661, 'Recall': 0.525, 'F1': 0.60431654676259, 'P-value': np.float64(0.19)}
#
#  Synthetic series 22/500 (index 63)
# {'AUC-PR': 0.7176804776488392, 'Precision': 0.5897435897435898, 'Recall': 0.6133333333333333, 'F1': 0.6013071895424836, 'P-value': np.float64(0.19)}
#
#  Synthetic series 23/500 (index 66)
# {'AUC-PR': 0.8315309130218598, 'Precision': 0.7263157894736842, 'Recall': 0.9078947368421053, 'F1': 0.8070175438596491, 'P-value': np.float64(0.19)}
#
#  Synthetic series 24/500 (index 69)
# {'AUC-PR': 0.7228862869077698, 'Precision': 0.5546218487394958, 'Recall': 0.7857142857142857, 'F1': 0.6502463054187192, 'P-value': np.float64(0.19)}
#
#  Synthetic series 25/500 (index 72)
# {'AUC-PR': 0.7612660411153891, 'Precision': 0.5193798449612403, 'Recall': 0.7976190476190477, 'F1': 0.6291079812206573, 'P-value': np.float64(0.19)}
#
#  Synthetic series 26/500 (index 75)
# {'AUC-PR': 0.6407539834063118, 'Precision': 0.45038167938931295, 'Recall': 0.8805970149253731, 'F1': 0.5959595959595959, 'P-value': np.float64(0.19)}
#
#  Synthetic series 27/500 (index 78)
# {'AUC-PR': 0.7448581835083172, 'Precision': 0.4634146341463415, 'Recall': 0.76, 'F1': 0.5757575757575758, 'P-value': np.float64(0.19)}
#
#  Synthetic series 28/500 (index 81)
# {'AUC-PR': 0.6917815035666941, 'Precision': 0.5086206896551724, 'Recall': 0.7375, 'F1': 0.6020408163265306, 'P-value': np.float64(0.19)}
#
#  Synthetic series 29/500 (index 84)
# {'AUC-PR': 0.7352568171853361, 'Precision': 0.6263736263736264, 'Recall': 0.7307692307692307, 'F1': 0.6745562130177515, 'P-value': np.float64(0.19)}
#
#  Synthetic series 30/500 (index 87)
# {'AUC-PR': 0.6730268097815608, 'Precision': 0.5350877192982456, 'Recall': 0.7261904761904762, 'F1': 0.6161616161616161, 'P-value': np.float64(0.19)}
#
#  Synthetic series 31/500 (index 90)
# {'AUC-PR': 0.6409469383372742, 'Precision': 0.4413793103448276, 'Recall': 0.8, 'F1': 0.5688888888888889, 'P-value': np.float64(0.19)}
#
#  Synthetic series 32/500 (index 93)
# {'AUC-PR': 0.4717070864073106, 'Precision': 0.2926829268292683, 'Recall': 0.6, 'F1': 0.39344262295081966, 'P-value': np.float64(0.19)}
#
#  Synthetic series 33/500 (index 96)
# {'AUC-PR': 0.7026254480879629, 'Precision': 0.6144578313253012, 'Recall': 0.6144578313253012, 'F1': 0.6144578313253012, 'P-value': np.float64(0.2)}
#
#  Synthetic series 34/500 (index 99)
# {'AUC-PR': 0.6727245985147475, 'Precision': 0.6428571428571429, 'Recall': 0.5769230769230769, 'F1': 0.6081081081081081, 'P-value': np.float64(0.2)}
#
#  Synthetic series 35/500 (index 102)
# {'AUC-PR': 0.6218613808851688, 'Precision': 0.5454545454545454, 'Recall': 0.5384615384615384, 'F1': 0.5419354838709678, 'P-value': np.float64(0.2)}
#
#  Synthetic series 36/500 (index 105)
# {'AUC-PR': 0.5586726413573498, 'Precision': 0.44715447154471544, 'Recall': 0.6875, 'F1': 0.541871921182266, 'P-value': np.float64(0.2)}
#
#  Synthetic series 37/500 (index 108)
# {'AUC-PR': 0.563489108353733, 'Precision': 0.46236559139784944, 'Recall': 0.5512820512820513, 'F1': 0.5029239766081871, 'P-value': np.float64(0.2)}
#
#  Synthetic series 38/500 (index 111)
# {'AUC-PR': 0.8112445961045448, 'Precision': 0.48936170212765956, 'Recall': 0.8734177215189873, 'F1': 0.6272727272727273, 'P-value': np.float64(0.2)}
#
#  Synthetic series 39/500 (index 114)
# {'AUC-PR': 0.816618496655021, 'Precision': 0.56, 'Recall': 0.9090909090909091, 'F1': 0.693069306930693, 'P-value': np.float64(0.2)}
#
#  Synthetic series 40/500 (index 117)
# {'AUC-PR': 0.7412992293781665, 'Precision': 0.49107142857142855, 'Recall': 0.6707317073170732, 'F1': 0.5670103092783505, 'P-value': np.float64(0.2)}
#
#  Synthetic series 41/500 (index 120)
# {'AUC-PR': 0.4965160356702298, 'Precision': 0.4111111111111111, 'Recall': 0.5285714285714286, 'F1': 0.4625, 'P-value': np.float64(0.2)}
#
#  Synthetic series 42/500 (index 123)
# {'AUC-PR': 0.6638198108571687, 'Precision': 0.49624060150375937, 'Recall': 0.825, 'F1': 0.6197183098591549, 'P-value': np.float64(0.2)}
#
#  Synthetic series 43/500 (index 126)
# {'AUC-PR': 0.62542014694218, 'Precision': 0.45652173913043476, 'Recall': 0.7974683544303798, 'F1': 0.5806451612903226, 'P-value': np.float64(0.2)}
#
#  Synthetic series 44/500 (index 129)
# {'AUC-PR': 0.6271679663662842, 'Precision': 0.6307692307692307, 'Recall': 0.5061728395061729, 'F1': 0.5616438356164384, 'P-value': np.float64(0.2)}
#
#  Synthetic series 45/500 (index 132)
# {'AUC-PR': 0.8233592698480623, 'Precision': 0.5241935483870968, 'Recall': 0.8125, 'F1': 0.6372549019607843, 'P-value': np.float64(0.2)}
#
#  Synthetic series 46/500 (index 135)
# {'AUC-PR': 0.6530588446189098, 'Precision': 0.4444444444444444, 'Recall': 0.7123287671232876, 'F1': 0.5473684210526316, 'P-value': np.float64(0.2)}
#
#  Synthetic series 47/500 (index 138)
# {'AUC-PR': 0.8047867981609594, 'Precision': 0.625, 'Recall': 0.8, 'F1': 0.7017543859649122, 'P-value': np.float64(0.2)}
#
#  Synthetic series 48/500 (index 141)
# {'AUC-PR': 0.7053332508218817, 'Precision': 0.4153846153846154, 'Recall': 0.7012987012987013, 'F1': 0.5217391304347826, 'P-value': np.float64(0.2)}
#
#  Synthetic series 49/500 (index 144)
# {'AUC-PR': 0.5177349023870962, 'Precision': 0.3709677419354839, 'Recall': 0.5974025974025974, 'F1': 0.4577114427860697, 'P-value': np.float64(0.2)}
#
#  Synthetic series 50/500 (index 147)
# {'AUC-PR': 0.631363820552901, 'Precision': 0.49107142857142855, 'Recall': 0.6626506024096386, 'F1': 0.5641025641025641, 'P-value': np.float64(0.2)}
#
#  Synthetic series 51/500 (index 150)
# {'AUC-PR': 0.7438565696995477, 'Precision': 0.5619834710743802, 'Recall': 0.85, 'F1': 0.6766169154228856, 'P-value': np.float64(0.2)}
#
#  Synthetic series 52/500 (index 153)
# {'AUC-PR': 0.656900099044934, 'Precision': 0.4444444444444444, 'Recall': 0.6582278481012658, 'F1': 0.5306122448979592, 'P-value': np.float64(0.2)}
#
#  Synthetic series 53/500 (index 156)
# {'AUC-PR': 0.7762263064596316, 'Precision': 0.48, 'Recall': 0.8780487804878049, 'F1': 0.6206896551724138, 'P-value': np.float64(0.2)}
#
#  Synthetic series 54/500 (index 159)
# {'AUC-PR': 0.7295314256310056, 'Precision': 0.6043956043956044, 'Recall': 0.6707317073170732, 'F1': 0.6358381502890174, 'P-value': np.float64(0.21)}
#
#  Synthetic series 55/500 (index 162)
# {'AUC-PR': 0.6824931101219868, 'Precision': 0.4142857142857143, 'Recall': 0.7733333333333333, 'F1': 0.5395348837209303, 'P-value': np.float64(0.21)}
#
#  Synthetic series 56/500 (index 165)
# {'AUC-PR': 0.6707845327279354, 'Precision': 0.5, 'Recall': 0.7037037037037037, 'F1': 0.5846153846153846, 'P-value': np.float64(0.21)}
#
#  Synthetic series 57/500 (index 168)
# {'AUC-PR': 0.4490988717289676, 'Precision': 0.3548387096774194, 'Recall': 0.55, 'F1': 0.43137254901960786, 'P-value': np.float64(0.21)}
#
#  Synthetic series 58/500 (index 171)
# {'AUC-PR': 0.7916623823075399, 'Precision': 0.7833333333333333, 'Recall': 0.6025641025641025, 'F1': 0.6811594202898551, 'P-value': np.float64(0.21)}
#
#  Synthetic series 59/500 (index 174)
# {'AUC-PR': 0.7383086915319564, 'Precision': 0.4523809523809524, 'Recall': 0.8260869565217391, 'F1': 0.5846153846153846, 'P-value': np.float64(0.21)}
#
#  Synthetic series 60/500 (index 177)
# {'AUC-PR': 0.6745497273803847, 'Precision': 0.472, 'Recall': 0.7195121951219512, 'F1': 0.5700483091787439, 'P-value': np.float64(0.21)}
#
#  Synthetic series 61/500 (index 180)
# {'AUC-PR': 0.689515989175844, 'Precision': 0.68, 'Recall': 0.6455696202531646, 'F1': 0.6623376623376623, 'P-value': np.float64(0.21)}
#
#  Synthetic series 62/500 (index 183)
# {'AUC-PR': 0.5969585575662699, 'Precision': 0.4329896907216495, 'Recall': 0.5753424657534246, 'F1': 0.49411764705882355, 'P-value': np.float64(0.21)}
#
#  Synthetic series 63/500 (index 186)
# {'AUC-PR': 0.5379066520367327, 'Precision': 0.4013605442176871, 'Recall': 0.7375, 'F1': 0.5198237885462555, 'P-value': np.float64(0.21)}
#
#  Synthetic series 64/500 (index 189)
# {'AUC-PR': 0.6603052136884311, 'Precision': 0.4383561643835616, 'Recall': 0.8311688311688312, 'F1': 0.5739910313901345, 'P-value': np.float64(0.21)}
#
#  Synthetic series 65/500 (index 192)
# {'AUC-PR': 0.7806385556899402, 'Precision': 0.6407766990291263, 'Recall': 0.8354430379746836, 'F1': 0.7252747252747253, 'P-value': np.float64(0.21)}
#
#  Synthetic series 66/500 (index 195)
# {'AUC-PR': 0.6690419892089788, 'Precision': 0.4732142857142857, 'Recall': 0.6708860759493671, 'F1': 0.5549738219895288, 'P-value': np.float64(0.21)}
#
#  Synthetic series 67/500 (index 198)
# {'AUC-PR': 0.7449121689113388, 'Precision': 0.5203252032520326, 'Recall': 0.7619047619047619, 'F1': 0.6183574879227053, 'P-value': np.float64(0.21)}
#
#  Synthetic series 68/500 (index 201)
# {'AUC-PR': 0.8056931262078483, 'Precision': 0.5169491525423728, 'Recall': 0.8026315789473685, 'F1': 0.6288659793814433, 'P-value': np.float64(0.21)}
#
#  Synthetic series 69/500 (index 204)
# {'AUC-PR': 0.6441328237355994, 'Precision': 0.5409836065573771, 'Recall': 0.8148148148148148, 'F1': 0.6502463054187192, 'P-value': np.float64(0.21)}
#
#  Synthetic series 70/500 (index 207)
# {'AUC-PR': 0.752477590859302, 'Precision': 0.7543859649122807, 'Recall': 0.5119047619047619, 'F1': 0.6099290780141844, 'P-value': np.float64(0.21)}
#
#  Synthetic series 71/500 (index 210)
# {'AUC-PR': 0.6600210343870122, 'Precision': 0.5151515151515151, 'Recall': 0.6071428571428571, 'F1': 0.5573770491803278, 'P-value': np.float64(0.21)}
#
#  Synthetic series 72/500 (index 213)
# {'AUC-PR': 0.45102994774607286, 'Precision': 0.312, 'Recall': 0.5652173913043478, 'F1': 0.4020618556701031, 'P-value': np.float64(0.21)}
#
#  Synthetic series 73/500 (index 216)
# {'AUC-PR': 0.8219531912871478, 'Precision': 0.49193548387096775, 'Recall': 0.8840579710144928, 'F1': 0.6321243523316062, 'P-value': np.float64(0.21)}
#
#  Synthetic series 74/500 (index 219)
# {'AUC-PR': 0.6248477986722425, 'Precision': 0.4462809917355372, 'Recall': 0.6835443037974683, 'F1': 0.54, 'P-value': np.float64(0.22)}
#
#  Synthetic series 75/500 (index 222)
# {'AUC-PR': 0.685207558337434, 'Precision': 0.45925925925925926, 'Recall': 0.7848101265822784, 'F1': 0.5794392523364486, 'P-value': np.float64(0.22)}
#
#  Synthetic series 76/500 (index 225)
# {'AUC-PR': 0.78546215519791, 'Precision': 0.46099290780141844, 'Recall': 0.8552631578947368, 'F1': 0.5990783410138248, 'P-value': np.float64(0.22)}
#
#  Synthetic series 77/500 (index 228)
# {'AUC-PR': 0.7104468882632842, 'Precision': 0.41739130434782606, 'Recall': 0.6233766233766234, 'F1': 0.5, 'P-value': np.float64(0.22)}
#
#  Synthetic series 78/500 (index 231)
# {'AUC-PR': 0.899127697247599, 'Precision': 0.6186440677966102, 'Recall': 0.9240506329113924, 'F1': 0.7411167512690355, 'P-value': np.float64(0.22)}
#
#  Synthetic series 79/500 (index 234)
# {'AUC-PR': 0.7943161596109334, 'Precision': 0.4567901234567901, 'Recall': 0.925, 'F1': 0.6115702479338843, 'P-value': np.float64(0.22)}
#
#  Synthetic series 80/500 (index 237)
# {'AUC-PR': 0.642765356659325, 'Precision': 0.5666666666666667, 'Recall': 0.6296296296296297, 'F1': 0.5964912280701754, 'P-value': np.float64(0.22)}
#
#  Synthetic series 81/500 (index 240)
# {'AUC-PR': 0.6633831563058351, 'Precision': 0.684931506849315, 'Recall': 0.625, 'F1': 0.6535947712418301, 'P-value': np.float64(0.22)}
#
#  Synthetic series 82/500 (index 243)
# {'AUC-PR': 0.7388448431591387, 'Precision': 0.4818181818181818, 'Recall': 0.7066666666666667, 'F1': 0.572972972972973, 'P-value': np.float64(0.22)}
#
#  Synthetic series 83/500 (index 246)
# {'AUC-PR': 0.5592436545231227, 'Precision': 0.42063492063492064, 'Recall': 0.7066666666666667, 'F1': 0.527363184079602, 'P-value': np.float64(0.22)}
#
#  Synthetic series 84/500 (index 249)
# {'AUC-PR': 0.616281155377023, 'Precision': 0.5866666666666667, 'Recall': 0.5714285714285714, 'F1': 0.5789473684210527, 'P-value': np.float64(0.22)}
#
#  Synthetic series 85/500 (index 252)
# {'AUC-PR': 0.8081274169062905, 'Precision': 0.515625, 'Recall': 0.8354430379746836, 'F1': 0.6376811594202898, 'P-value': np.float64(0.22)}
#
#  Synthetic series 86/500 (index 255)
# {'AUC-PR': 0.7722270734286992, 'Precision': 0.5894736842105263, 'Recall': 0.6588235294117647, 'F1': 0.6222222222222222, 'P-value': np.float64(0.22)}
#
#  Synthetic series 87/500 (index 258)
# {'AUC-PR': 0.7838902652231972, 'Precision': 0.48, 'Recall': 0.9, 'F1': 0.6260869565217392, 'P-value': np.float64(0.22)}
#
#  Synthetic series 88/500 (index 261)
# {'AUC-PR': 0.685380959586735, 'Precision': 0.424, 'Recall': 0.6794871794871795, 'F1': 0.5221674876847291, 'P-value': np.float64(0.22)}
#
#  Synthetic series 89/500 (index 264)
# {'AUC-PR': 0.5976629732371904, 'Precision': 0.45132743362831856, 'Recall': 0.6986301369863014, 'F1': 0.5483870967741935, 'P-value': np.float64(0.22)}
#
#  Synthetic series 90/500 (index 267)
# {'AUC-PR': 0.7491625521232451, 'Precision': 0.5825242718446602, 'Recall': 0.75, 'F1': 0.6557377049180327, 'P-value': np.float64(0.22)}
#
#  Synthetic series 91/500 (index 270)
# {'AUC-PR': 0.7968595171174154, 'Precision': 0.40512820512820513, 'Recall': 1.0, 'F1': 0.5766423357664233, 'P-value': np.float64(0.22)}
#
#  Synthetic series 92/500 (index 273)
# {'AUC-PR': 0.8150142891666469, 'Precision': 0.48091603053435117, 'Recall': 0.863013698630137, 'F1': 0.6176470588235294, 'P-value': np.float64(0.22)}
#
#  Synthetic series 93/500 (index 276)
# {'AUC-PR': 0.7387519024474047, 'Precision': 0.6896551724137931, 'Recall': 0.759493670886076, 'F1': 0.7228915662650602, 'P-value': np.float64(0.22)}
#
#  Synthetic series 94/500 (index 279)
# {'AUC-PR': 0.7900674471273044, 'Precision': 0.7317073170731707, 'Recall': 0.7317073170731707, 'F1': 0.7317073170731707, 'P-value': np.float64(0.22)}
#
#  Synthetic series 95/500 (index 282)
# {'AUC-PR': 0.5803764029345455, 'Precision': 0.5042735042735043, 'Recall': 0.7564102564102564, 'F1': 0.6051282051282051, 'P-value': np.float64(0.23)}
#
#  Synthetic series 96/500 (index 285)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 21
#      14 df = test_series[i]
#      16 print(
#      17     f"\n Synthetic series {count + 1}/{len(indices)} "
#      18     f"(index {i})"
#      19 )
# ---> 21 metrics, ks, recalls = evaluate_and_plot_streaming(
#      22     model,
#      23     df,
#      24     device,
#      25     lookahead=config["data"]["lookahead"],
#      26     plot=False,
#      27     title="P-model time series with extreme event labels and LSTM prediction"
#      28 )
#      30 print(metrics)
#      32 all_metrics.append(metrics)
#
# Cell In[11], line 137, in evaluate_and_plot_streaming(model, df, device, lookahead, threshold, plot, box_cut, title)
#     135         x_t = torch.tensor([[[value]]], dtype=torch.float32).to(device)
#     136         y_hat, hidden = model.step(x_t, hidden)
# --> 137         predictions.append(y_hat.item())
#     139 predictions = np.array(predictions)
#     141 # Apply sigmoid if the model outputs logits
#
# KeyboardInterrupt:

# %%
all_metrics = pd.DataFrame(all_metrics)
all_metrics['P-value'] = all_metrics['P-value'].astype(float).round(2)

table = (
    all_metrics
    .groupby('P-value', as_index=False)
    .mean()
)

def highlight_best_worst(s):
    is_max = s == s.max()
    is_min = s == s.min()
    
    styles = []
    for max_v, min_v in zip(is_max, is_min):
        if max_v:
            styles.append('background-color: #b7f7c1; font-weight: bold')  # best (green)
        elif min_v:
            styles.append('background-color: #f7b7b7; font-weight: bold')  # worst (red)
        else:
            styles.append('')
    
    return styles

styled_table = (
    table
    .style
    .apply(highlight_best_worst, axis=0)  
    .format("{:.3f}")
)

styled_table
# Out:
# <style type="text/css">
# #T_d496b_row0_col0, #T_d496b_row2_col3, #T_d496b_row23_col1, #T_d496b_row23_col2, #T_d496b_row23_col4 {
#   background-color: #f7b7b7;
#   font-weight: bold;
# }
# #T_d496b_row11_col2, #T_d496b_row12_col1, #T_d496b_row12_col4, #T_d496b_row16_col3, #T_d496b_row24_col0 {
#   background-color: #b7f7c1;
#   font-weight: bold;
# }
# </style>
# <table id="T_d496b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d496b_level0_col0" class="col_heading level0 col0" >P-value</th>
#       <th id="T_d496b_level0_col1" class="col_heading level0 col1" >AUC-PR</th>
#       <th id="T_d496b_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_d496b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d496b_level0_col4" class="col_heading level0 col4" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d496b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d496b_row0_col0" class="data row0 col0" >0.180</td>
#       <td id="T_d496b_row0_col1" class="data row0 col1" >0.668</td>
#       <td id="T_d496b_row0_col2" class="data row0 col2" >0.477</td>
#       <td id="T_d496b_row0_col3" class="data row0 col3" >0.743</td>
#       <td id="T_d496b_row0_col4" class="data row0 col4" >0.580</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d496b_row1_col0" class="data row1 col0" >0.190</td>
#       <td id="T_d496b_row1_col1" class="data row1 col1" >0.691</td>
#       <td id="T_d496b_row1_col2" class="data row1 col2" >0.537</td>
#       <td id="T_d496b_row1_col3" class="data row1 col3" >0.717</td>
#       <td id="T_d496b_row1_col4" class="data row1 col4" >0.596</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d496b_row2_col0" class="data row2 col0" >0.200</td>
#       <td id="T_d496b_row2_col1" class="data row2 col1" >0.677</td>
#       <td id="T_d496b_row2_col2" class="data row2 col2" >0.505</td>
#       <td id="T_d496b_row2_col3" class="data row2 col3" >0.702</td>
#       <td id="T_d496b_row2_col4" class="data row2 col4" >0.580</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d496b_row3_col0" class="data row3 col0" >0.210</td>
#       <td id="T_d496b_row3_col1" class="data row3 col1" >0.678</td>
#       <td id="T_d496b_row3_col2" class="data row3 col2" >0.515</td>
#       <td id="T_d496b_row3_col3" class="data row3 col3" >0.704</td>
#       <td id="T_d496b_row3_col4" class="data row3 col4" >0.583</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d496b_row4_col0" class="data row4 col0" >0.220</td>
#       <td id="T_d496b_row4_col1" class="data row4 col1" >0.727</td>
#       <td id="T_d496b_row4_col2" class="data row4 col2" >0.521</td>
#       <td id="T_d496b_row4_col3" class="data row4 col3" >0.758</td>
#       <td id="T_d496b_row4_col4" class="data row4 col4" >0.608</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d496b_row5_col0" class="data row5 col0" >0.230</td>
#       <td id="T_d496b_row5_col1" class="data row5 col1" >0.678</td>
#       <td id="T_d496b_row5_col2" class="data row5 col2" >0.494</td>
#       <td id="T_d496b_row5_col3" class="data row5 col3" >0.728</td>
#       <td id="T_d496b_row5_col4" class="data row5 col4" >0.580</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d496b_row6_col0" class="data row6 col0" >0.240</td>
#       <td id="T_d496b_row6_col1" class="data row6 col1" >0.696</td>
#       <td id="T_d496b_row6_col2" class="data row6 col2" >0.507</td>
#       <td id="T_d496b_row6_col3" class="data row6 col3" >0.733</td>
#       <td id="T_d496b_row6_col4" class="data row6 col4" >0.591</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d496b_row7_col0" class="data row7 col0" >0.250</td>
#       <td id="T_d496b_row7_col1" class="data row7 col1" >0.705</td>
#       <td id="T_d496b_row7_col2" class="data row7 col2" >0.527</td>
#       <td id="T_d496b_row7_col3" class="data row7 col3" >0.728</td>
#       <td id="T_d496b_row7_col4" class="data row7 col4" >0.600</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d496b_row8_col0" class="data row8 col0" >0.260</td>
#       <td id="T_d496b_row8_col1" class="data row8 col1" >0.717</td>
#       <td id="T_d496b_row8_col2" class="data row8 col2" >0.545</td>
#       <td id="T_d496b_row8_col3" class="data row8 col3" >0.729</td>
#       <td id="T_d496b_row8_col4" class="data row8 col4" >0.614</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d496b_row9_col0" class="data row9 col0" >0.270</td>
#       <td id="T_d496b_row9_col1" class="data row9 col1" >0.751</td>
#       <td id="T_d496b_row9_col2" class="data row9 col2" >0.542</td>
#       <td id="T_d496b_row9_col3" class="data row9 col3" >0.783</td>
#       <td id="T_d496b_row9_col4" class="data row9 col4" >0.635</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d496b_row10_col0" class="data row10 col0" >0.280</td>
#       <td id="T_d496b_row10_col1" class="data row10 col1" >0.721</td>
#       <td id="T_d496b_row10_col2" class="data row10 col2" >0.508</td>
#       <td id="T_d496b_row10_col3" class="data row10 col3" >0.772</td>
#       <td id="T_d496b_row10_col4" class="data row10 col4" >0.607</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d496b_row11_col0" class="data row11 col0" >0.290</td>
#       <td id="T_d496b_row11_col1" class="data row11 col1" >0.748</td>
#       <td id="T_d496b_row11_col2" class="data row11 col2" >0.567</td>
#       <td id="T_d496b_row11_col3" class="data row11 col3" >0.758</td>
#       <td id="T_d496b_row11_col4" class="data row11 col4" >0.633</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d496b_row12_col0" class="data row12 col0" >0.300</td>
#       <td id="T_d496b_row12_col1" class="data row12 col1" >0.756</td>
#       <td id="T_d496b_row12_col2" class="data row12 col2" >0.548</td>
#       <td id="T_d496b_row12_col3" class="data row12 col3" >0.781</td>
#       <td id="T_d496b_row12_col4" class="data row12 col4" >0.638</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d496b_row13_col0" class="data row13 col0" >0.310</td>
#       <td id="T_d496b_row13_col1" class="data row13 col1" >0.748</td>
#       <td id="T_d496b_row13_col2" class="data row13 col2" >0.547</td>
#       <td id="T_d496b_row13_col3" class="data row13 col3" >0.772</td>
#       <td id="T_d496b_row13_col4" class="data row13 col4" >0.633</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d496b_row14_col0" class="data row14 col0" >0.320</td>
#       <td id="T_d496b_row14_col1" class="data row14 col1" >0.721</td>
#       <td id="T_d496b_row14_col2" class="data row14 col2" >0.466</td>
#       <td id="T_d496b_row14_col3" class="data row14 col3" >0.807</td>
#       <td id="T_d496b_row14_col4" class="data row14 col4" >0.585</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d496b_row15_col0" class="data row15 col0" >0.330</td>
#       <td id="T_d496b_row15_col1" class="data row15 col1" >0.698</td>
#       <td id="T_d496b_row15_col2" class="data row15 col2" >0.461</td>
#       <td id="T_d496b_row15_col3" class="data row15 col3" >0.783</td>
#       <td id="T_d496b_row15_col4" class="data row15 col4" >0.573</td>
#     </tr>
#     <tr>
#       <th id="T_d496b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d496b_row16_c

# %%
# Split by P-value ranges
exogenous = all_metrics[(all_metrics['P-value'] >= 0.18) & (all_metrics['P-value'] <= 0.28)]
transition = all_metrics[(all_metrics['P-value'] > 0.28) & (all_metrics['P-value'] < 0.32)]
endogenous = all_metrics[(all_metrics['P-value'] >= 0.32) & (all_metrics['P-value'] <= 0.42)]
mixed = all_metrics  

# Compute means
table = pd.DataFrame({
    'Exogenous': exogenous.mean(),
    'Transition': transition.mean(),
    'Endogenous': endogenous.mean(),
    'Mixed': mixed.mean()
}).T

# Drop P-value column (not meaningful to average)
table = table.drop(columns=['P-value'])

# Style table
styled_table = (
    table
    .style
    .apply(highlight_best_worst, axis=0)
    .format("{:.3f}")
)

table.to_csv("../paper/metrics_by_regime_exogenous.csv", float_format="%.3f")

styled_table
# Out:
# <style type="text/css">
# #T_91c1b_row0_col2, #T_91c1b_row2_col0, #T_91c1b_row2_col1, #T_91c1b_row2_col3 {
#   background-color: #f7b7b7;
#   font-weight: bold;
# }
# #T_91c1b_row1_col0, #T_91c1b_row1_col1, #T_91c1b_row1_col3, #T_91c1b_row2_col2 {
#   background-color: #b7f7c1;
#   font-weight: bold;
# }
# </style>
# <table id="T_91c1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91c1b_level0_col0" class="col_heading level0 col0" >AUC-PR</th>
#       <th id="T_91c1b_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_91c1b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_91c1b_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91c1b_level0_row0" class="row_heading level0 row0" >Exogenous</th>
#       <td id="T_91c1b_row0_col0" class="data row0 col0" >0.702</td>
#       <td id="T_91c1b_row0_col1" class="data row0 col1" >0.518</td>
#       <td id="T_91c1b_row0_col2" class="data row0 col2" >0.736</td>
#       <td id="T_91c1b_row0_col3" class="data row0 col3" >0.598</td>
#     </tr>
#     <tr>
#       <th id="T_91c1b_level0_row1" class="row_heading level0 row1" >Transition</th>
#       <td id="T_91c1b_row1_col0" class="data row1 col0" >0.751</td>
#       <td id="T_91c1b_row1_col1" class="data row1 col1" >0.554</td>
#       <td id="T_91c1b_row1_col2" class="data row1 col2" >0.770</td>
#       <td id="T_91c1b_row1_col3" class="data row1 col3" >0.634</td>
#     </tr>
#     <tr>
#       <th id="T_91c1b_level0_row2" class="row_heading level0 row2" >Endogenous</th>
#       <td id="T_91c1b_row2_col0" class="data row2 col0" >0.549</td>
#       <td id="T_91c1b_row2_col1" class="data row2 col1" >0.371</td>
#       <td id="T_91c1b_row2_col2" class="data row2 col2" >0.782</td>
#       <td id="T_91c1b_row2_col3" class="data row2 col3" >0.492</td>
#     </tr>
#     <tr>
#       <th id="T_91c1b_level0_row3" class="row_heading level0 row3" >Mixed</th>
#       <td id="T_91c1b_row3_col0" class="data row3 col0" >0.641</td>
#       <td id="T_91c1b_row3_col1" class="data row3 col1" >0.458</td>
#       <td id="T_91c1b_row3_col2" class="data row3 col2" >0.760</td>
#       <td id="T_91c1b_row3_col3" class="data row3 col3" >0.556</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(26)

test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=[0.25, 0.25],
    num_series=3,
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

df = test_series[1]



metrics, ks, recalls = evaluate_and_plot_streaming(
    model,
    df,
    device,
    lookahead=config["data"]["lookahead"],
    plot=True,
    box_cut=(600, 800),
    title="Exogenous time series (p = 0.25) with extreme event labels and LSTM prediction",
    path_ra = "../paper/images/exogenous_time_series_(p_=_0.25)_recall_vs_anticipacion.png",
    path_series = "../paper/images/exogenous_time_series_(p_=_0.25)_with_extreme_event_labels_and_lstm_prediction.png"
)

print(metrics)

all_metrics.append(metrics)
all_recalls.append(recalls)
# Out:
# [0.25, 0.25]
# /var/folders/25/4ts88tzd08500lbfck1y7nn40000gn/T/ipykernel_46647/1846533069.py:353: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'AUC-PR': 0.8161043686157854, 'Precision': 0.7021276595744681, 'Recall': 0.8148148148148148, 'F1': 0.7542857142857143, 'P-value': np.float64(0.25)}

# %%
np.random.seed(11)

test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=[0.30, 0.30],
    num_series=3,
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

df = test_series[1]

metrics, ks, recalls = evaluate_and_plot_streaming(
    model,
    df,
    device,
    lookahead=config["data"]["lookahead"],
    plot=True,
    box_cut=(800, 1024),
    title="Transition-regime time series (p = 0.30) with extreme event labels and LSTM prediction",
    path_ra="../paper/images/transition_time_series_(p_=_0.30)_recall_vs_anticipacion.png",
    path_series = "../paper/images/transition_time_series_(p_=_0.30)_with_extreme_event_labels_and_lstm_prediction.png"
)

print(metrics)

all_metrics.append(metrics)
all_recalls.append(recalls)
# Out:
# [0.3, 0.3]
# /var/folders/25/4ts88tzd08500lbfck1y7nn40000gn/T/ipykernel_46647/1846533069.py:353: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'AUC-PR': 0.8057844589003235, 'Precision': 0.5238095238095238, 'Recall': 0.9041095890410958, 'F1': 0.6633165829145728, 'P-value': np.float64(0.3)}
