# %%
import sys
from pathlib import Path

ROOT_DIR = Path().resolve().parents[0]
sys.path.append(str(ROOT_DIR))

# %%
import os
import torch
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams["figure.dpi"] = 300
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = ['Times New Roman']

plt.rcParams.update({
    "font.size": 15,       
    "axes.titlesize": 16,  
    "axes.labelsize": 15,  
    "xtick.labelsize": 14, 
    "ytick.labelsize": 14, 
    "legend.fontsize": 12  
})

import numpy as np
import json
import pandas as pd

from src.models.model import PeakPredictorLSTM
from src.data.pmodel_generation import (
    generate_multiple_series,
)


from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
)


def recall_vs_anticipation(
    predictions,
    true_peaks,
    lookahead,
    threshold,
    burn_in=100,
):
    """
    Computes recall as a function of minimum anticipation time,
    discarding early points without valid prediction context.

    Returns:
        ks: minimum anticipation (in time steps)
        recalls: fraction of peaks anticipated at least k steps ahead
    """

    # Positions of real peaks
    peak_positions = np.where(true_peaks == 1)[0]

    # Discard peaks too close to the beginning (no valid anticipation window)
    peak_positions = peak_positions[
        peak_positions >= burn_in + lookahead
    ]

    ks = np.arange(1, lookahead + 1)
    recalls = []

    if len(peak_positions) == 0:
        return ks, np.zeros_like(ks, dtype=float)

    for k in ks:
        detected = 0

        for t_peak in peak_positions:
            t_start = t_peak - lookahead

            window = predictions[t_start:t_peak]

            # Ignore windows with NaNs (extra safety)
            if np.isnan(window).any():
                continue

            alarm_idx = np.where(window >= threshold)[0]

            if len(alarm_idx) > 0:
                t_alarm = t_start + alarm_idx[0]
                if (t_peak - t_alarm) >= k:
                    detected += 1

        recalls.append(detected / len(peak_positions))

    return ks, np.array(recalls)

def build_anticipatory_labels(peaks, lookahead):
    """
    peaks: array binário (0/1) indicando pico instantâneo
    lookahead: horizonte de previsão

    Retorna:
    y_future[t] = 1 se existir pico em [t+1, t+lookahead]
    """
    y_future = np.zeros_like(peaks)

    for t in range(len(peaks)):
        end = min(t + lookahead + 1, len(peaks))
        if np.any(peaks[t + 1 : end]):
            y_future[t] = 1

    return y_future



def evaluate_and_plot_streaming(
    model,
    df,
    device,
    lookahead,
    threshold=0.6,
    plot=True,
    box_cut=None,
    title="P-model time series",
    path_ra=None,
    path_series=None
):
    """
    Evaluates a single time series in a streaming (causal) regime.
    """

    # Select appropriate signal column
    signal_col = (
        "normalized_amplitude"
        if "normalized_amplitude" in df.columns
        else "normalized"
    )

    series = df[signal_col].values
    true_peaks = df["peak"].values.astype(int)
    instant_peaks = df["peak"].values.astype(int)
    true_peaks_classic_metrics = build_anticipatory_labels(instant_peaks, lookahead)


    model.eval()
    hidden = model.init_hidden()
    predictions = []

    with torch.no_grad():
        for value in series:
            x_t = torch.tensor([[[value]]], dtype=torch.float32).to(device)
            y_hat, hidden = model.step(x_t, hidden)
            predictions.append(y_hat.item())

    predictions = np.array(predictions)

    # Apply sigmoid if the model outputs logits
    predictions = 1 / (1 + np.exp(-predictions))

    burn_in = 0  

    # Temporal adjustment (anticipatory prediction)
    predictions[:lookahead] = np.nan

    valid = ~np.isnan(predictions)

    # ignora também os primeiros burn_in pontos
    valid[:burn_in] = False

    y_true = true_peaks_classic_metrics[valid]
    y_score = predictions[valid]
    y_pred = (y_score >= threshold).astype(int)

    metrics = {
        # "AUC-ROC": roc_auc_score(y_true, y_score)
        # if len(np.unique(y_true)) > 1
        # else np.nan,
        "AUC-PR": average_precision_score(y_true, y_score)
        if len(np.unique(y_true)) > 1
        else np.nan,
        # "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred, zero_division=0),
        "Recall": recall_score(y_true, y_pred, zero_division=0),
        "F1": f1_score(y_true, y_pred, zero_division=0),
        "P-value": df["p_value"].iloc[0] if "p_value" in df.columns else np.nan
    }

    if plot:
        # Recall vs Anticipation Plot
        x_ini, x_fim = box_cut
        thresholds = [threshold, 0.7, 0.8, 0.9]

        colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]
        linestyles = ["-", "--", "-.", ":", (0, (3, 1, 1, 1))] 
        markers = ["o", "x", "^", "D"]

        plt.figure(figsize=(8, 3))

        ks = None
        recalls = None

        for th, c, ls, m in zip(thresholds, colors, linestyles, markers):
            ks_sub, recalls_sub = recall_vs_anticipation(
                predictions,
                true_peaks,
                lookahead,
                threshold=th,
            )

            if th == threshold:
                ks = ks_sub
                recalls = recalls_sub

            plt.plot(
                ks_sub,
                recalls_sub,
                color=c,
                linestyle=ls,
                marker=m,
                markersize=6,
                linewidth=1.2,
                label=f"threshold = {th}"
            )

        plt.xlabel("Anticipation (k)")
        plt.ylabel("Recall")
        plt.title("Recall vs Anticipation")
        plt.grid(alpha=0.3)
        plt.legend()

        plt.savefig(path_ra, dpi=300, bbox_inches='tight') 

        plt.show()

        # Full series  plots
        fig, ax = plt.subplots(figsize=(9, 2.5), dpi=300)

        peak_idx = np.where(true_peaks == 1)[0]

        # Full series
        ax.plot(
            series, 
            lw=0.6, 
            label="P-model time series",
            color="royalblue"
        )

        ax.plot(
            range(x_ini, x_fim),
            series[x_ini:x_fim],
            lw=0.9,
            color="blue"
        )

        ax.plot(
            peak_idx,
            series[peak_idx],
            "x",
            markersize=6,
            label="Extreme events (XE)",
            color="red"
        )

        ax.plot(
            predictions,
            "--",
            lw=1.2,
            label=f"Probability",
            color="orange"
        )
        ax.set_title(title)

        ax.axvspan(x_ini, x_fim, color="gray", alpha=0.15)

        # cria o inset (janela de zoom)
        axins = inset_axes(
            ax,
            width="90%",
            height="90%",
            loc="lower center",
            bbox_to_anchor=(0.05, -1.3, 0.9, 0.9),
            bbox_transform=ax.transAxes,
            borderpad=0
        )

        axins.plot(
            range(x_ini, x_fim),
            series[x_ini:x_fim],
            lw=0.9,
            color="blue"
        )

        mask_peaks_zoom = (peak_idx >= x_ini) & (peak_idx < x_fim)
        peak_idx_zoom = peak_idx[mask_peaks_zoom]

        axins.plot(
            peak_idx_zoom,
            series[peak_idx_zoom],
            "x",
            color="red",
            markersize=6,
            label="Extreme events (XE)"
        )

        axins.plot(
            range(x_ini, x_fim),
            predictions[x_ini:x_fim],
            "--",
            color="orange",
            lw=1.2
        )

        axins.set_xlim(x_ini, x_fim)
        # axins.set_ylim(
        #     series[x_ini:x_fim].min(),
        #     series[x_ini:x_fim].max()
        # )

        axins.grid(alpha=0.3)
        axins.tick_params(labelsize=12)

        from matplotlib.patches import ConnectionPatch

        # canto inferior esquerdo da região no gráfico principal
        con1 = ConnectionPatch(
            xyA=(x_ini, series[x_ini]),  # ponto no gráfico principal
            coordsA=ax.transData,
            xyB=(x_ini, axins.get_ylim()[1]),  # topo do inset
            coordsB=axins.transData,
            color="0.5",
            lw=0.8,
            linestyle="--"
        )

        # canto inferior esquerdo da outra borda
        con2 = ConnectionPatch(
            xyA=(x_fim, series[x_fim-1]),
            coordsA=ax.transData,
            xyB=(x_fim, axins.get_ylim()[1]),
            coordsB=axins.transData,
            color="0.5",
            lw=0.8,
            linestyle="--"
        )

        ax.add_artist(con1)
        ax.add_artist(con2)

        ax.legend(
            loc="upper left",
            frameon=True
        )
        ax.grid(alpha=0.3)
        ax.set_xlabel("Time steps")
        ax.set_ylabel("Normalized amplitude\nProbability")

        plt.tight_layout()
        plt.savefig(path_series, dpi=300, bbox_inches='tight') 
        plt.show()
    
    else: 
        ks, recalls = recall_vs_anticipation(
            predictions,
            true_peaks,
            lookahead,
            threshold=threshold,
        )

    return metrics, ks, recalls

def load_and_prepare_csv(file_path, peak_percentile):
    """
    Loads a real CSV time series and generates peak labels using a percentile.
    """
    print(f"\nLoading file: {os.path.basename(file_path)}")

    df = pd.read_csv(file_path)
    df.columns = ["time", "amplitude"]

    amp = df["amplitude"].values
    df["normalized_amplitude"] = (
        (amp - amp.min()) / (amp.max() - amp.min() + 1e-6)
        if amp.max() > amp.min()
        else np.zeros_like(amp)
    )

    threshold = np.percentile(
        df["normalized_amplitude"], peak_percentile
    )
    df["peak"] = (df["normalized_amplitude"] > threshold).astype(int)
    df["peak_threshold"] = threshold

    return df

# %%
np.random.seed(30)

with open("../config/config_exo_endo.json", "r") as f:
    config = json.load(f)

if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
# ---------- Model ----------
model = PeakPredictorLSTM(config["model"]).to(device)
model.load_state_dict(
    torch.load("../results/best_model_exo_endo.pth", map_location=device)
)
# Out:
# <All keys matched successfully>

# %%
test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=config["p_model"]["p_value"],
    num_series=config["data"]["num_series_test"],
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

indices = np.linspace(0, len(test_series) - 1, 1000, dtype=int)

for count, i in enumerate(indices):
    df = test_series[i]

    print(
        f"\n Synthetic series {count + 1}/{len(indices)} "
        f"(index {i})"
    )

    metrics, ks, recalls = evaluate_and_plot_streaming(
        model,
        df,
        device,
        lookahead=config["data"]["lookahead"],
        plot=False,
        title="P-model time series with extreme event labels and LSTM prediction"
    )

    print(metrics)

    all_metrics.append(metrics)
    all_recalls.append(recalls)


# ---------- Aggregate recalls ----------
all_recalls = np.array(all_recalls)  

mean_recall = np.nanmean(all_recalls, axis=0)
std_recall = np.nanstd(all_recalls, axis=0)

# Clip to valid recall range
lower = np.clip(mean_recall - std_recall, 0, 1)
upper = np.clip(mean_recall + std_recall, 0, 1)

# ---------- Recall vs Anticipation Plot ----------
plt.figure(figsize=(6, 4))

plt.plot(
    ks,
    mean_recall,
    marker="o",
    markersize=6,
    linewidth=1.2,
    label="threshold = 0.6"
)

plt.fill_between(
    ks,
    lower,
    upper,
    alpha=0.3,
    label="±1 std (threshold = 0.6)"
)

plt.xlabel("Minimum anticipation (time steps before the peak)")
plt.ylabel("Recall (fraction of anticipated peaks)")
plt.title("Extreme event anticipation capability (Recall vs Anticipation)")
plt.grid(alpha=0.3)
plt.legend()
plt.ylim(0.4, 1.05)

plt.show()
# Out:
# [0.18, 0.42]
#
#  Synthetic series 1/1000 (index 0)
# {'AUC-PR': 0.7314096438653028, 'Precision': 0.460431654676259, 'Recall': 0.810126582278481, 'F1': 0.5871559633027523, 'P-value': np.float64(0.18)}
#
#  Synthetic series 2/1000 (index 1)
# {'AUC-PR': 0.7584974361843457, 'Precision': 0.5585585585585585, 'Recall': 0.7948717948717948, 'F1': 0.656084656084656, 'P-value': np.float64(0.18)}
#
#  Synthetic series 3/1000 (index 3)
# {'AUC-PR': 0.6801879229089709, 'Precision': 0.4830508474576271, 'Recall': 0.7125, 'F1': 0.5757575757575758, 'P-value': np.float64(0.18)}
#
#  Synthetic series 4/1000 (index 4)
# {'AUC-PR': 0.5836064128960793, 'Precision': 0.47, 'Recall': 0.5949367088607594, 'F1': 0.5251396648044693, 'P-value': np.float64(0.18)}
#
#  Synthetic series 5/1000 (index 6)
# {'AUC-PR': 0.7426623660348997, 'Precision': 0.4266666666666667, 'Recall': 0.9014084507042254, 'F1': 0.579185520361991, 'P-value': np.float64(0.18)}
#
#  Synthetic series 6/1000 (index 7)
# {'AUC-PR': 0.8162441232298515, 'Precision': 0.4883720930232558, 'Recall': 0.8289473684210527, 'F1': 0.6146341463414634, 'P-value': np.float64(0.18)}
#
#  Synthetic series 7/1000 (index 9)
# {'AUC-PR': 0.7352725570468668, 'Precision': 0.6705882352941176, 'Recall': 0.7215189873417721, 'F1': 0.6951219512195121, 'P-value': np.float64(0.18)}
#
#  Synthetic series 8/1000 (index 10)
# {'AUC-PR': 0.6888737029188259, 'Precision': 0.4375, 'Recall': 0.717948717948718, 'F1': 0.5436893203883495, 'P-value': np.float64(0.18)}
#
#  Synthetic series 9/1000 (index 12)
# {'AUC-PR': 0.7452308307102337, 'Precision': 0.5, 'Recall': 0.7380952380952381, 'F1': 0.5961538461538461, 'P-value': np.float64(0.18)}
#
#  Synthetic series 10/1000 (index 13)
# {'AUC-PR': 0.7317840945830454, 'Precision': 0.4236111111111111, 'Recall': 0.8133333333333334, 'F1': 0.5570776255707762, 'P-value': np.float64(0.18)}
#
#  Synthetic series 11/1000 (index 15)
# {'AUC-PR': 0.6102945364505773, 'Precision': 0.4318181818181818, 'Recall': 0.7307692307692307, 'F1': 0.5428571428571428, 'P-value': np.float64(0.18)}
#
#  Synthetic series 12/1000 (index 16)
# {'AUC-PR': 0.8022746410377841, 'Precision': 0.4722222222222222, 'Recall': 0.8292682926829268, 'F1': 0.6017699115044248, 'P-value': np.float64(0.18)}
#
#  Synthetic series 13/1000 (index 18)
# {'AUC-PR': 0.7355436072526769, 'Precision': 0.5223880597014925, 'Recall': 0.9090909090909091, 'F1': 0.6635071090047393, 'P-value': np.float64(0.18)}
#
#  Synthetic series 14/1000 (index 19)
# {'AUC-PR': 0.751312312628862, 'Precision': 0.43478260869565216, 'Recall': 0.8235294117647058, 'F1': 0.5691056910569106, 'P-value': np.float64(0.18)}
#
#  Synthetic series 15/1000 (index 21)
# {'AUC-PR': 0.795748709908038, 'Precision': 0.41975308641975306, 'Recall': 0.8831168831168831, 'F1': 0.5690376569037657, 'P-value': np.float64(0.18)}
#
#  Synthetic series 16/1000 (index 22)
# {'AUC-PR': 0.7802182308941834, 'Precision': 0.453416149068323, 'Recall': 0.8690476190476191, 'F1': 0.5959183673469388, 'P-value': np.float64(0.18)}
#
#  Synthetic series 17/1000 (index 24)
# {'AUC-PR': 0.649340120656668, 'Precision': 0.3897058823529412, 'Recall': 0.7464788732394366, 'F1': 0.5120772946859904, 'P-value': np.float64(0.18)}
#
#  Synthetic series 18/1000 (index 25)
# {'AUC-PR': 0.7102432590057854, 'Precision': 0.49166666666666664, 'Recall': 0.7564102564102564, 'F1': 0.5959595959595959, 'P-value': np.float64(0.18)}
#
#  Synthetic series 19/1000 (index 27)
# {'AUC-PR': 0.748724489441293, 'Precision': 0.5865384615384616, 'Recall': 0.7922077922077922, 'F1': 0.6740331491712708, 'P-value': np.float64(0.18)}
#
#  Synthetic series 20/1000 (index 28)
# {'AUC-PR': 0.7170636871941491, 'Precision': 0.5675675675675675, 'Recall': 0.75, 'F1': 0.6461538461538462, 'P-value': np.float64(0.18)}
#
#  Synthetic series 21/1000 (index 30)
# {'AUC-PR': 0.7026579360777765, 'Precision': 0.4491525423728814, 'Recall': 0.654320987654321, 'F1': 0.5326633165829145, 'P-value': np.float64(0.18)}
#
#  Synthetic series 22/1000 (index 31)
# {'AUC-PR': 0.7017635935329788, 'Precision': 0.6266666666666667, 'Recall': 0.6103896103896104, 'F1': 0.618421052631579, 'P-value': np.float64(0.18)}
#
#  Synthetic series 23/1000 (index 33)
# {'AUC-PR': 0.7625412723308118, 'Precision': 0.5714285714285714, 'Recall': 0.7710843373493976, 'F1': 0.6564102564102564, 'P-value': np.float64(0.19)}
#
#  Synthetic series 24/1000 (index 34)
# {'AUC-PR': 0.7561022682247527, 'Precision': 0.6119402985074627, 'Recall': 0.5774647887323944, 'F1': 0.5942028985507246, 'P-value': np.float64(0.19)}
#
#  Synthetic series 25/1000 (index 36)
# {'AUC-PR': 0.6136034350329634, 'Precision': 0.4423076923076923, 'Recall': 0.6052631578947368, 'F1': 0.5111111111111111, 'P-value': np.float64(0.19)}
#
#  Synthetic series 26/1000 (index 37)
# {'AUC-PR': 0.5932496837573218, 'Precision': 0.36220472440944884, 'Recall': 0.6216216216216216, 'F1': 0.4577114427860697, 'P-value': np.float64(0.19)}
#
#  Synthetic series 27/1000 (index 39)
# {'AUC-PR': 0.9062813363258017, 'Precision': 0.6972477064220184, 'Recall': 0.987012987012987, 'F1': 0.8172043010752689, 'P-value': np.float64(0.19)}
#
#  Synthetic series 28/1000 (index 40)
# {'AUC-PR': 0.6345330591403444, 'Precision': 0.47191011235955055, 'Recall': 0.5454545454545454, 'F1': 0.5060240963855421, 'P-value': np.float64(0.19)}
#
#  Synthetic series 29/1000 (index 42)
# {'AUC-PR': 0.8002734170747278, 'Precision': 0.5104895104895105, 'Recall': 0.9358974358974359, 'F1': 0.6606334841628959, 'P-value': np.float64(0.19)}
#
#  Synthetic series 30/1000 (index 43)
# {'AUC-PR': 0.606292734768887, 'Precision': 0.53125, 'Recall': 0.6375, 'F1': 0.5795454545454546, 'P-value': np.float64(0.19)}
#
#  Synthetic series 31/1000 (index 45)
# {'AUC-PR': 0.7171514326241318, 'Precision': 0.472, 'Recall': 0.7195121951219512, 'F1': 0.5700483091787439, 'P-value': np.float64(0.19)}
#
#  Synthetic series 32/1000 (index 46)
# {'AUC-PR': 0.3884921111525308, 'Precision': 0.32575757575757575, 'Recall': 0.5512820512820513, 'F1': 0.4095238095238095, 'P-value': np.float64(0.19)}
#
#  Synthetic series 33/1000 (index 48)
# {'AUC-PR': 0.7691765180925603, 'Precision': 0.3783783783783784, 'Recall': 0.8860759493670886, 'F1': 0.5303030303030303, 'P-value': np.float64(0.19)}
#
#  Synthetic series 34/1000 (index 49)
# {'AUC-PR': 0.6309655948272508, 'Precision': 0.4594594594594595, 'Recall': 0.6623376623376623, 'F1': 0.5425531914893617, 'P-value': np.float64(0.19)}
#
#  Synthetic series 35/1000 (index 51)
# {'AUC-PR': 0.7053452430207156, 'Precision': 0.4296875, 'Recall': 0.7432432432432432, 'F1': 0.5445544554455446, 'P-value': np.float64(0.19)}
#
#  Synthetic series 36/1000 (index 52)
# {'AUC-PR': 0.7122240993437772, 'Precision': 0.5151515151515151, 'Recall': 0.6, 'F1': 0.5543478260869565, 'P-value': np.float64(0.19)}
#
#  Synthetic series 37/1000 (index 54)
# {'AUC-PR': 0.8329265733029916, 'Precision': 0.44886363636363635, 'Recall': 1.0, 'F1': 0.6196078431372549, 'P-value': np.float64(0.19)}
#
#  Synthetic series 38/1000 (index 55)
# {'AUC-PR': 0.7683063835878856, 'Precision': 0.4782608695652174, 'Recall': 0.8048780487804879, 'F1': 0.6, 'P-value': np.float64(0.19)}
#
#  Synthetic series 39/1000 (index 57)
# {'AUC-PR': 0.8190003593476649, 'Precision': 0.5357142857142857, 'Recall': 0.8928571428571429, 'F1': 0.6696428571428571, 'P-value': np.float64(0.19)}
#
#  Synthetic series 40/1000 (index 58)
# {'AUC-PR': 0.5985846734241469, 'Precision': 0.4634146341463415, 'Recall': 0.7307692307692307, 'F1': 0.5671641791044776, 'P-value': np.float64(0.19)}
#
#  Synthetic series 41/1000 (index 60)
# {'AUC-PR': 0.7040575511111127, 'Precision': 0.43448275862068964, 'Recall': 0.7875, 'F1': 0.56, 'P-value': np.float64(0.19)}
#
#  Synthetic series 42/1000 (index 61)
# {'AUC-PR': 0.7555670377472667, 'Precision': 0.4700854700854701, 'Recall': 0.7236842105263158, 'F1': 0.5699481865284974, 'P-value': np.float64(0.19)}
#
#  Synthetic series 43/1000 (index 63)
# {'AUC-PR': 0.4196714426451987, 'Precision': 0.34513274336283184, 'Recall': 0.52, 'F1': 0.4148936170212766, 'P-value': np.float64(0.19)}
#
#  Synthetic series 44/1000 (index 64)
# {'AUC-PR': 0.7298179185116463, 'Precision': 0.4672131147540984, 'Recall': 0.76, 'F1': 0.5786802030456852, 'P-value': np.float64(0.19)}
#
#  Synthetic series 45/1000 (index 66)
# {'AUC-PR': 0.5923434227217347, 'Precision': 0.3546099290780142, 'Recall': 0.625, 'F1': 0.45248868778280543, 'P-value': np.float64(0.19)}
#
#  Synthetic series 46/1000 (index 67)
# {'AUC-PR': 0.6922028342045821, 'Precision': 0.6875, 'Recall': 0.5432098765432098, 'F1': 0.6068965517241379, 'P-value': np.float64(0.19)}
#
#  Synthetic series 47/1000 (index 69)
# {'AUC-PR': 0.6336362278782415, 'Precision': 0.3925925925925926, 'Recall': 0.6883116883116883, 'F1': 0.5, 'P-value': np.float64(0.19)}
#
#  Synthetic series 48/1000 (index 70)
# {'AUC-PR': 0.5665053228998143, 'Precision': 0.3313953488372093, 'Recall': 0.7307692307692307, 'F1': 0.456, 'P-value': np.float64(0.19)}
#
#  Synthetic series 49/1000 (index 72)
# {'AUC-PR': 0.7870354828160396, 'Precision': 0.6203703703703703, 'Recall': 0.7976190476190477, 'F1': 0.6979166666666666, 'P-value': np.float64(0.19)}
#
#  Synthetic series 50/1000 (index 73)
# {'AUC-PR': 0.7071421221602308, 'Precision': 0.4628099173553719, 'Recall': 0.7368421052631579, 'F1': 0.5685279187817259, 'P-value': np.float64(0.19)}
#
#  Synthetic series 51/1000 (index 75)
# {'AUC-PR': 0.8182543948164973, 'Precision': 0.4934210526315789, 'Recall': 0.9259259259259259, 'F1': 0.6437768240343348, 'P-value': np.float64(0.19)}
#
#  Synthetic series 52/1000 (index 76)
# {'AUC-PR': 0.639124004032372, 'Precision': 0.4027777777777778, 'Recall': 0.7631578947368421, 'F1': 0.5272727272727272, 'P-value': np.float64(0.19)}
#
#  Synthetic series 53/1000 (index 78)
# {'AUC-PR': 0.7249815755559791, 'Precision': 0.41721854304635764, 'Recall': 0.8289473684210527, 'F1': 0.5550660792951542, 'P-value': np.float64(0.19)}
#
#  Synthetic series 54/1000 (index 79)
# {'AUC-PR': 0.6412390174972876, 'Precision': 0.42735042735042733, 'Recall': 0.6329113924050633, 'F1': 0.5102040816326531, 'P-value': np.float64(0.19)}
#
#  Synthetic series 55/1000 (index 81)
# {'AUC-PR': 0.6842921655980876, 'Precision': 0.6136363636363636, 'Recall': 0.6428571428571429, 'F1': 0.627906976744186, 'P-value': np.float64(0.19)}
#
#  Synthetic series 56/1000 (index 82)
# {'AUC-PR': 0.8201060393106614, 'Precision': 0.6, 'Recall': 0.7974683544303798, 'F1': 0.6847826086956522, 'P-value': np.float64(0.19)}
#
#  Synthetic series 57/1000 (index 84)
# {'AUC-PR': 0.7510817984678576, 'Precision': 0.69, 'Recall': 0.8518518518518519, 'F1': 0.7624309392265194, 'P-value': np.float64(0.19)}
#
#  Synthetic series 58/1000 (index 85)
# {'AUC-PR': 0.7686763291858079, 'Precision': 0.6288659793814433, 'Recall': 0.7261904761904762, 'F1': 0.6740331491712708, 'P-value': np.float64(0.19)}
#
#  Synthetic series 59/1000 (index 87)
# {'AUC-PR': 0.815393084417501, 'Precision': 0.6052631578947368, 'Recall': 0.8313253012048193, 'F1': 0.700507614213198, 'P-value': np.float64(0.19)}
#
#  Synthetic series 60/1000 (index 88)
# {'AUC-PR': 0.8006557261039475, 'Precision': 0.4825174825174825, 'Recall': 0.8846153846153846, 'F1': 0.6244343891402715, 'P-value': np.float64(0.19)}
#
#  Synthetic series 61/1000 (index 90)
# {'AUC-PR': 0.7294677510471216, 'Precision': 0.42953020134228187, 'Recall': 0.8205128205128205, 'F1': 0.5638766519823789, 'P-value': np.float64(0.19)}
#
#  Synthetic series 62/1000 (index 91)
# {'AUC-PR': 0.7574444550650977, 'Precision': 0.5, 'Recall': 0.7341772151898734, 'F1': 0.5948717948717949, 'P-value': np.float64(0.19)}
#
#  Synthetic series 63/1000 (index 93)
# {'AUC-PR': 0.7098022891326283, 'Precision': 0.64, 'Recall': 0.5853658536585366, 'F1': 0.6114649681528662, 'P-value': np.float64(0.19)}
#
#  Synthetic series 64/1000 (index 94)
# {'AUC-PR': 0.8145228808551972, 'Precision': 0.6186440677966102, 'Recall': 0.8902439024390244, 'F1': 0.73, 'P-value': np.float64(0.2)}
#
#  Synthetic series 65/1000 (index 96)
# {'AUC-PR': 0.7352302106285883, 'Precision': 0.5818181818181818, 'Recall': 0.8533333333333334, 'F1': 0.6918918918918919, 'P-value': np.float64(0.2)}
#
#  Synthetic series 66/1000 (index 97)
# {'AUC-PR': 0.699615902436376, 'Precision': 0.3619631901840491, 'Recall': 0.8194444444444444, 'F1': 0.502127659574468, 'P-value': np.float64(0.2)}
#
#  Synthetic series 67/1000 (index 99)
# {'AUC-PR': 0.6404459339081119, 'Precision': 0.39864864864864863, 'Recall': 0.7972972972972973, 'F1': 0.5315315315315315, 'P-value': np.float64(0.2)}
#
#  Synthetic series 68/1000 (index 100)
# {'AUC-PR': 0.7009124497900138, 'Precision': 0.4155844155844156, 'Recall': 0.7619047619047619, 'F1': 0.5378151260504201, 'P-value': np.float64(0.2)}
#
#  Synthetic series 69/1000 (index 102)
# {'AUC-PR': 0.8367730271138142, 'Precision': 0.5454545454545454, 'Recall': 0.9113924050632911, 'F1': 0.6824644549763034, 'P-value': np.float64(0.2)}
#
#  Synthetic series 70/1000 (index 103)
# {'AUC-PR': 0.7663647499386703, 'Precision': 0.7471264367816092, 'Recall': 0.8024691358024691, 'F1': 0.7738095238095238, 'P-value': np.float64(0.2)}
#
#  Synthetic series 71/1000 (index 105)
# {'AUC-PR': 0.7243919812999193, 'Precision': 0.6153846153846154, 'Recall': 0.6, 'F1': 0.6075949367088608, 'P-value': np.float64(0.2)}
#
#  Synthetic series 72/1000 (index 106)
# {'AUC-PR': 0.45511550083596847, 'Precision': 0.4186046511627907, 'Recall': 0.46153846153846156, 'F1': 0.43902439024390244, 'P-value': np.float64(0.2)}
#
#  Synthetic series 73/1000 (index 108)
# {'AUC-PR': 0.6233603141771477, 'Precision': 0.5304347826086957, 'Recall': 0.7530864197530864, 'F1': 0.6224489795918368, 'P-value': np.float64(0.2)}
#
#  Synthetic series 74/1000 (index 109)
# {'AUC-PR': 0.731278345553664, 'Precision': 0.4463276836158192, 'Recall': 0.9294117647058824, 'F1': 0.6030534351145038, 'P-value': np.float64(0.2)}
#
#  Synthetic series 75/1000 (index 111)
# {'AUC-PR': 0.6691212275761432, 'Precision': 0.4298245614035088, 'Recall': 0.6805555555555556, 'F1': 0.5268817204301075, 'P-value': np.float64(0.2)}
#
#  Synthetic series 76/1000 (index 112)
# {'AUC-PR': 0.7462396228813439, 'Precision': 0.46616541353383456, 'Recall': 0.8157894736842105, 'F1': 0.5933014354066986, 'P-value': np.float64(0.2)}
#
#  Synthetic series 77/1000 (index 114)
# {'AUC-PR': 0.7557308233337308, 'Precision': 0.7011494252873564, 'Recall': 0.7625, 'F1': 0.7305389221556886, 'P-value': np.float64(0.2)}
#
#  Synthetic series 78/1000 (index 115)
# {'AUC-PR': 0.8144093136298809, 'Precision': 0.7432432432432432, 'Recall': 0.7236842105263158, 'F1': 0.7333333333333333, 'P-value': np.float64(0.2)}
#
#  Synthetic series 79/1000 (index 117)
# {'AUC-PR': 0.8235685321836531, 'Precision': 0.45695364238410596, 'Recall': 0.8734177215189873, 'F1': 0.6, 'P-value': np.float64(0.2)}
#
#  Synthetic series 80/1000 (index 118)
# {'AUC-PR': 0.6223127773347807, 'Precision': 0.46564885496183206, 'Recall': 0.7922077922077922, 'F1': 0.5865384615384616, 'P-value': np.float64(0.2)}
#
#  Synthetic series 81/1000 (index 120)
# {'AUC-PR': 0.5305217964139255, 'Precision': 0.45918367346938777, 'Recall': 0.6, 'F1': 0.5202312138728323, 'P-value': np.float64(0.2)}
#
#  Synthetic series 82/1000 (index 121)
# {'AUC-PR': 0.6821436672581536, 'Precision': 0.42038216560509556, 'Recall': 0.8048780487804879, 'F1': 0.5523012552301255, 'P-value': np.float64(0.2)}
#
#  Synthetic series 83/1000 (index 123)
# {'AUC-PR': 0.7909615205534187, 'Precision': 0.4827586206896552, 'Recall': 0.9333333333333333, 'F1': 0.6363636363636364, 'P-value': np.float64(0.2)}
#
#  Synthetic series 84/1000 (index 124)
# {'AUC-PR': 0.7292469073986351, 'Precision': 0.5075757575757576, 'Recall': 0.8072289156626506, 'F1': 0.6232558139534884, 'P-value': np.float64(0.2)}
#
#  Synthetic series 85/1000 (index 126)
# {'AUC-PR': 0.5969607817334758, 'Precision': 0.3897058823529412, 'Recall': 0.6708860759493671, 'F1': 0.4930232558139535, 'P-value': np.float64(0.2)}
#
#  Synthetic series 86/1000 (index 127)
# {'AUC-PR': 0.828170742669023, 'Precision': 0.5887850467289719, 'Recall': 0.75, 'F1': 0.6596858638743456, 'P-value': np.float64(0.2)}
#
#  Synthetic series 87/1000 (index 129)
# {'AUC-PR': 0.7340929146958507, 'Precision': 0.504, 'Recall': 0.863013698630137, 'F1': 0.6363636363636364, 'P-value': np.float64(0.2)}
#
#  Synthetic series 88/1000 (index 130)
# {'AUC-PR': 0.6350631215516568, 'Precision': 0.4307692307692308, 'Recall': 0.717948717948718, 'F1': 0.5384615384615384, 'P-value': np.float64(0.2)}
#
#  Synthetic series 89/1000 (index 132)
# {'AUC-PR': 0.6633674050301898, 'Precision': 0.4022346368715084, 'Recall': 0.8674698795180723, 'F1': 0.549618320610687, 'P-value': np.float64(0.2)}
#
#  Synthetic series 90/1000 (index 133)
# {'AUC-PR': 0.8633261077648046, 'Precision': 0.5, 'Recall': 0.9041095890410958, 'F1': 0.6439024390243903, 'P-value': np.float64(0.2)}
#
#  Synthetic series 91/1000 (index 135)
# {'AUC-PR': 0.6046196893189721, 'Precision': 0.38562091503267976, 'Recall': 0.7023809523809523, 'F1': 0.4978902953586498, 'P-value': np.float64(0.2)}
#
#  Synthetic series 92/1000 (index 136)
# {'AUC-PR': 0.7718942465837797, 'Precision': 0.42, 'Recall': 0.84, 'F1': 0.56, 'P-value': np.float64(0.2)}
#
#  Synthetic series 93/1000 (index 138)
# {'AUC-PR': 0.6270821203101208, 'Precision': 0.4154929577464789, 'Recall': 0.7662337662337663, 'F1': 0.5388127853881278, 'P-value': np.float64(0.2)}
#
#  Synthetic series 94/1000 (index 139)
# {'AUC-PR': 0.6355189016277958, 'Precision': 0.3419354838709677, 'Recall': 0.6883116883116883, 'F1': 0.45689655172413796, 'P-value': np.float64(0.2)}
#
#  Synthetic series 95/1000 (index 141)
# {'AUC-PR': 0.8358459231958523, 'Precision': 0.4716981132075472, 'Recall': 0.9615384615384616, 'F1': 0.6329113924050633, 'P-value': np.float64(0.2)}
#
#  Synthetic series 96/1000 (index 142)
# {'AUC-PR': 0.6311625091529939, 'Precision': 0.4144736842105263, 'Recall': 0.8289473684210527, 'F1': 0.5526315789473685, 'P-value': np.float64(0.2)}
#
#  Synthetic series 97/1000 (index 144)
# {'AUC-PR': 0.8127284631185777, 'Precision': 0.45222929936305734, 'Recall': 0.8765432098765432, 'F1': 0.5966386554621849, 'P-value': np.float64(0.2)}
#
#  Synthetic series 98/1000 (index 145)
# {'AUC-PR': 0.6012028024761416, 'Precision': 0.421875, 'Recall': 0.6666666666666666, 'F1': 0.5167464114832536, 'P-value': np.float64(0.2)}
#
#  Synthetic series 99/1000 (index 147)
# {'AUC-PR': 0.8606828954660277, 'Precision': 0.5658914728682171, 'Recall': 0.8795180722891566, 'F1': 0.6886792452830188, 'P-value': np.float64(0.2)}
#
#  Synthetic series 100/1000 (index 148)
# {'AUC-PR': 0.5968660152877711, 'Precision': 0.40236686390532544, 'Recall': 0.8607594936708861, 'F1': 0.5483870967741935, 'P-value': np.float64(0.2)}
#
#  Synthetic series 101/1000 (index 150)
# {'AUC-PR': 0.7642826080638576, 'Precision': 0.4748201438848921, 'Recall': 0.825, 'F1': 0.6027397260273972, 'P-value': np.float64(0.2)}
#
#  Synthetic series 102/1000 (index 151)
# {'AUC-PR': 0.6232245220301698, 'Precision': 0.3588235294117647, 'Recall': 0.7922077922077922, 'F1': 0.4939271255060729, 'P-value': np.float64(0.2)}
#
#  Synthetic series 103/1000 (index 153)
# {'AUC-PR': 0.6499516947871015, 'Precision': 0.46153846153846156, 'Recall': 0.6923076923076923, 'F1': 0.5538461538461539, 'P-value': np.float64(0.2)}
#
#  Synthetic series 104/1000 (index 154)
# {'AUC-PR': 0.7120823178428153, 'Precision': 0.40131578947368424, 'Recall': 0.8356164383561644, 'F1': 0.5422222222222223, 'P-value': np.float64(0.2)}
#
#  Synthetic series 105/1000 (index 156)
# {'AUC-PR': 0.7029639801230659, 'Precision': 0.4370860927152318, 'Recall': 0.8571428571428571, 'F1': 0.5789473684210527, 'P-value': np.float64(0.2)}
#
#  Synthetic series 106/1000 (index 157)
# {'AUC-PR': 0.8091280974083124, 'Precision': 0.5959595959595959, 'Recall': 0.8082191780821918, 'F1': 0.686046511627907, 'P-value': np.float64(0.21)}
#
#  Synthetic series 107/1000 (index 159)
# {'AUC-PR': 0.6635307891406852, 'Precision': 0.4778761061946903, 'Recall': 0.6923076923076923, 'F1': 0.5654450261780105, 'P-value': np.float64(0.21)}
#
#  Synthetic series 108/1000 (index 160)
# {'AUC-PR': 0.5542666539941552, 'Precision': 0.45217391304347826, 'Recall': 0.6190476190476191, 'F1': 0.5226130653266332, 'P-value': np.float64(0.21)}
#
#  Synthetic series 109/1000 (index 162)
# {'AUC-PR': 0.6569502710391917, 'Precision': 0.39864864864864863, 'Recall': 0.7564102564102564, 'F1': 0.5221238938053098, 'P-value': np.float64(0.21)}
#
#  Synthetic series 110/1000 (index 163)
# {'AUC-PR': 0.49729596553015754, 'Precision': 0.3888888888888889, 'Recall': 0.6363636363636364, 'F1': 0.4827586206896552, 'P-value': np.float64(0.21)}
#
#  Synthetic series 111/1000 (index 165)
# {'AUC-PR': 0.6668093644597914, 'Precision': 0.453781512605042, 'Recall': 0.7297297297297297, 'F1': 0.5595854922279793, 'P-value': np.float64(0.21)}
#
#  Synthetic series 112/1000 (index 166)
# {'AUC-PR': 0.7032500854800442, 'Precision': 0.4068965517241379, 'Recall': 0.8428571428571429, 'F1': 0.5488372093023256, 'P-value': np.float64(0.21)}
#
#  Synthetic series 113/1000 (index 168)
# {'AUC-PR': 0.7051647899146692, 'Precision': 0.4626865671641791, 'Recall': 0.8378378378378378, 'F1': 0.5961538461538461, 'P-value': np.float64(0.21)}
#
#  Synthetic series 114/1000 (index 169)
# {'AUC-PR': 0.7325692908260327, 'Precision': 0.3958333333333333, 'Recall': 0.75, 'F1': 0.5181818181818182, 'P-value': np.float64(0.21)}
#
#  Synthetic series 115/1000 (index 171)
# {'AUC-PR': 0.7395870063228009, 'Precision': 0.6265060240963856, 'Recall': 0.6933333333333334, 'F1': 0.6582278481012658, 'P-value': np.float64(0.21)}
#
#  Synthetic series 116/1000 (index 172)
# {'AUC-PR': 0.6500479568567794, 'Precision': 0.40993788819875776, 'Recall': 0.8148148148148148, 'F1': 0.5454545454545454, 'P-value': np.float64(0.21)}
#
#  Synthetic series 117/1000 (index 174)
# {'AUC-PR': 0.8125138114963351, 'Precision': 0.5158730158730159, 'Recall': 0.8333333333333334, 'F1': 0.6372549019607843, 'P-value': np.float64(0.21)}
#
#  Synthetic series 118/1000 (index 175)
# {'AUC-PR': 0.5752212593358572, 'Precision': 0.35766423357664234, 'Recall': 0.6533333333333333, 'F1': 0.46226415094339623, 'P-value': np.float64(0.21)}
#
#  Synthetic series 119/1000 (index 177)
# {'AUC-PR': 0.7455112145651448, 'Precision': 0.5, 'Recall': 0.821917808219178, 'F1': 0.6217616580310881, 'P-value': np.float64(0.21)}
#
#  Synthetic series 120/1000 (index 178)
# {'AUC-PR': 0.716673587176988, 'Precision': 0.43312101910828027, 'Recall': 0.8947368421052632, 'F1': 0.5836909871244635, 'P-value': np.float64(0.21)}
#
#  Synthetic series 121/1000 (index 180)
# {'AUC-PR': 0.711837721132859, 'Precision': 0.4915254237288136, 'Recall': 0.7341772151898734, 'F1': 0.5888324873096447, 'P-value': np.float64(0.21)}
#
#  Synthetic series 122/1000 (index 181)
# {'AUC-PR': 0.7669403099643446, 'Precision': 0.4825174825174825, 'Recall': 0.8846153846153846, 'F1': 0.6244343891402715, 'P-value': np.float64(0.21)}
#
#  Synthetic series 123/1000 (index 183)
# {'AUC-PR': 0.7876291682536137, 'Precision': 0.45864661654135336, 'Recall': 0.8840579710144928, 'F1': 0.6039603960396039, 'P-value': np.float64(0.21)}
#
#  Synthetic series 124/1000 (index 184)
# {'AUC-PR': 0.6648108327262086, 'Precision': 0.4566929133858268, 'Recall': 0.7532467532467533, 'F1': 0.5686274509803921, 'P-value': np.float64(0.21)}
#
#  Synthetic series 125/1000 (index 186)
# {'AUC-PR': 0.538473714749486, 'Precision': 0.3219178082191781, 'Recall': 0.5949367088607594, 'F1': 0.4177777777777778, 'P-value': np.float64(0.21)}
#
#  Synthetic series 126/1000 (index 187)
# {'AUC-PR': 0.6065187754087835, 'Precision': 0.38095238095238093, 'Recall': 0.691358024691358, 'F1': 0.49122807017543857, 'P-value': np.float64(0.21)}
#
#  Synthetic series 127/1000 (index 189)
# {'AUC-PR': 0.6867390143219064, 'Precision': 0.33658536585365856, 'Recall': 0.8625, 'F1': 0.4842105263157895, 'P-value': np.float64(0.21)}
#
#  Synthetic series 128/1000 (index 190)
# {'AUC-PR': 0.6974560908178424, 'Precision': 0.5436893203883495, 'Recall': 0.7466666666666667, 'F1': 0.6292134831460674, 'P-value': np.float64(0.21)}
#
#  Synthetic series 129/1000 (index 192)
# {'AUC-PR': 0.6481761103938418, 'Precision': 0.4491525423728814, 'Recall': 0.6883116883116883, 'F1': 0.5435897435897435, 'P-value': np.float64(0.21)}
#
#  Synthetic series 130/1000 (index 193)
# {'AUC-PR': 0.7004365656084782, 'Precision': 0.38650306748466257, 'Recall': 0.8181818181818182, 'F1': 0.525, 'P-value': np.float64(0.21)}
#
#  Synthetic series 131/1000 (index 195)
# {'AUC-PR': 0.8059567853212057, 'Precision': 0.6534653465346535, 'Recall': 0.7857142857142857, 'F1': 0.7135135135135136, 'P-value': np.float64(0.21)}
#
#  Synthetic series 132/1000 (index 196)
# {'AUC-PR': 0.561346958329064, 'Precision': 0.43333333333333335, 'Recall': 0.7323943661971831, 'F1': 0.5445026178010471, 'P-value': np.float64(0.21)}
#
#  Synthetic series 133/1000 (index 198)
# {'AUC-PR': 0.8086526399884278, 'Precision': 0.4195804195804196, 'Recall': 0.8333333333333334, 'F1': 0.5581395348837209, 'P-value': np.float64(0.21)}
#
#  Synthetic series 134/1000 (index 199)
# {'AUC-PR': 0.742098736797715, 'Precision': 0.5526315789473685, 'Recall': 0.7777777777777778, 'F1': 0.6461538461538462, 'P-value': np.float64(0.21)}
#
#  Synthetic series 135/1000 (index 201)
# {'AUC-PR': 0.7520943048575395, 'Precision': 0.461038961038961, 'Recall': 0.8987341772151899, 'F1': 0.6094420600858369, 'P-value': np.float64(0.21)}
#
#  Synthetic series 136/1000 (index 202)
# {'AUC-PR': 0.7499988923223846, 'Precision': 0.55, 'Recall': 0.7142857142857143, 'F1': 0.6214689265536724, 'P-value': np.float64(0.21)}
#
#  Synthetic series 137/1000 (index 204)
# {'AUC-PR': 0.6131390581078432, 'Precision': 0.45132743362831856, 'Recall': 0.6071428571428571, 'F1': 0.5177664974619289, 'P-value': np.float64(0.21)}
#
#  Synthetic series 138/1000 (index 205)
# {'AUC-PR': 0.7312595787450478, 'Precision': 0.4397163120567376, 'Recall': 0.8051948051948052, 'F1': 0.5688073394495413, 'P-value': np.float64(0.21)}
#
#  Synthetic series 139/1000 (index 207)
# {'AUC-PR': 0.6998687944575309, 'Precision': 0.49514563106796117, 'Recall': 0.6710526315789473, 'F1': 0.5698324022346368, 'P-value': np.float64(0.21)}
#
#  Synthetic series 140/1000 (index 208)
# {'AUC-PR': 0.6130942347911708, 'Precision': 0.4891304347826087, 'Recall': 0.6, 'F1': 0.5389221556886228, 'P-value': np.float64(0.21)}
#
#  Synthetic series 141/1000 (index 210)
# {'AUC-PR': 0.858588257528501, 'Precision': 0.5634920634920635, 'Recall': 0.8987341772151899, 'F1': 0.6926829268292682, 'P-value': np.float64(0.21)}
#
#  Synthetic series 142/1000 (index 211)
# {'AUC-PR': 0.6723564361939713, 'Precision': 0.43506493506493504, 'Recall': 0.8933333333333333, 'F1': 0.5851528384279476, 'P-value': np.float64(0.21)}
#
#  Synthetic series 143/1000 (index 213)
# {'AUC-PR': 0.7687245301777514, 'Precision': 0.48031496062992124, 'Recall': 0.782051282051282, 'F1': 0.5951219512195122, 'P-value': np.float64(0.21)}
#
#  Synthetic series 144/1000 (index 214)
# {'AUC-PR': 0.6754443838615123, 'Precision': 0.5545454545454546, 'Recall': 0.7439024390243902, 'F1': 0.6354166666666666, 'P-value': np.float64(0.21)}
#
#  Synthetic series 145/1000 (index 216)
# {'AUC-PR': 0.6889757709184259, 'Precision': 0.2804878048780488, 'Recall': 0.8846153846153846, 'F1': 0.42592592592592593, 'P-value': np.float64(0.21)}
#
#  Synthetic series 146/1000 (index 217)
# {'AUC-PR': 0.8576402497395625, 'Precision': 0.5, 'Recall': 1.0, 'F1': 0.6666666666666666, 'P-value': np.float64(0.21)}
#
#  Synthetic series 147/1000 (index 219)
# {'AUC-PR': 0.5536343745550875, 'Precision': 0.5616438356164384, 'Recall': 0.5125, 'F1': 0.5359477124183006, 'P-value': np.float64(0.22)}
#
#  Synthetic series 148/1000 (index 220)
# {'AUC-PR': 0.5398135747159533, 'Precision': 0.31693989071038253, 'Recall': 0.7160493827160493, 'F1': 0.4393939393939394, 'P-value': np.float64(0.22)}
#
#  Synthetic series 149/1000 (index 222)
# {'AUC-PR': 0.6680048174407982, 'Precision': 0.4146341463414634, 'Recall': 0.6986301369863014, 'F1': 0.5204081632653061, 'P-value': np.float64(0.22)}
#
#  Synthetic series 150/1000 (index 223)
# {'AUC-PR': 0.6454778853326333, 'Precision': 0.41216216216216217, 'Recall': 0.7261904761904762, 'F1': 0.5258620689655172, 'P-value': np.float64(0.22)}
#
#  Synthetic series 151/1000 (index 225)
# {'AUC-PR': 0.8181032498391844, 'Precision': 0.6633663366336634, 'Recall': 0.8072289156626506, 'F1': 0.7282608695652174, 'P-value': np.float64(0.22)}
#
#  Synthetic series 152/1000 (index 226)
# {'AUC-PR': 0.566617831586401, 'Precision': 0.3698630136986301, 'Recall': 0.675, 'F1': 0.4778761061946903, 'P-value': np.float64(0.22)}
#
#  Synthetic series 153/1000 (index 228)
# {'AUC-PR': 0.7789078145059564, 'Precision': 0.5789473684210527, 'Recall': 0.7746478873239436, 'F1': 0.6626506024096386, 'P-value': np.float64(0.22)}
#
#  Synthetic series 154/1000 (index 229)
# {'AUC-PR': 0.7065618937027982, 'Precision': 0.34972677595628415, 'Recall': 0.810126582278481, 'F1': 0.48854961832061067, 'P-value': np.float64(0.22)}
#
#  Synthetic series 155/1000 (index 231)
# {'AUC-PR': 0.6318256681881002, 'Precision': 0.36942675159235666, 'Recall': 0.7435897435897436, 'F1': 0.49361702127659574, 'P-value': np.float64(0.22)}
#
#  Synthetic series 156/1000 (index 232)
# {'AUC-PR': 0.777429704699902, 'Precision': 0.5773195876288659, 'Recall': 0.7567567567567568, 'F1': 0.6549707602339181, 'P-value': np.float64(0.22)}
#
#  Synthetic series 157/1000 (index 234)
# {'AUC-PR': 0.6831150964445859, 'Precision': 0.5111111111111111, 'Recall': 0.6301369863013698, 'F1': 0.5644171779141104, 'P-value': np.float64(0.22)}
#
#  Synthetic series 158/1000 (index 235)
# {'AUC-PR': 0.7096631698776472, 'Precision': 0.5858585858585859, 'Recall': 0.7160493827160493, 'F1': 0.6444444444444445, 'P-value': np.float64(0.22)}
#
#  Synthetic series 159/1000 (index 237)
# {'AUC-PR': 0.755510380974994, 'Precision': 0.40522875816993464, 'Recall': 0.8157894736842105, 'F1': 0.5414847161572053, 'P-value': np.float64(0.22)}
#
#  Synthetic series 160/1000 (index 238)
# {'AUC-PR': 0.8258010762204577, 'Precision': 0.6666666666666666, 'Recall': 0.8674698795180723, 'F1': 0.7539267015706806, 'P-value': np.float64(0.22)}
#
#  Synthetic series 161/1000 (index 240)
# {'AUC-PR': 0.7189292825959854, 'Precision': 0.4566929133858268, 'Recall': 0.7435897435897436, 'F1': 0.5658536585365853, 'P-value': np.float64(0.22)}
#
#  Synthetic series 162/1000 (index 241)
# {'AUC-PR': 0.746689699645083, 'Precision': 0.3989071038251366, 'Recall': 0.9012345679012346, 'F1': 0.553030303030303, 'P-value': np.float64(0.22)}
#
#  Synthetic series 163/1000 (index 243)
# {'AUC-PR': 0.779771667291878, 'Precision': 0.4810126582278481, 'Recall': 0.926829268292683, 'F1': 0.6333333333333333, 'P-value': np.float64(0.22)}
#
#  Synthetic series 164/1000 (index 244)
# {'AUC-PR': 0.5832298237675392, 'Precision': 0.33816425120772947, 'Recall': 0.875, 'F1': 0.4878048780487805, 'P-value': np.float64(0.22)}
#
#  Synthetic series 165/1000 (index 246)
# {'AUC-PR': 0.6972056996027127, 'Precision': 0.391025641025641, 'Recall': 0.7922077922077922, 'F1': 0.5236051502145923, 'P-value': np.float64(0.22)}
#
#  Synthetic series 166/1000 (index 247)
# {'AUC-PR': 0.7701312989256595, 'Precision': 0.35609756097560974, 'Recall': 0.9605263157894737, 'F1': 0.5195729537366548, 'P-value': np.float64(0.22)}
#
#  Synthetic series 167/1000 (index 249)
# {'AUC-PR': 0.6658255358214616, 'Precision': 0.34269662921348315, 'Recall': 0.7261904761904762, 'F1': 0.46564885496183206, 'P-value': np.float64(0.22)}
#
#  Synthetic series 168/1000 (index 250)
# {'AUC-PR': 0.7149543186350762, 'Precision': 0.49137931034482757, 'Recall': 0.76, 'F1': 0.5968586387434555, 'P-value': np.float64(0.22)}
#
#  Synthetic series 169/1000 (index 252)
# {'AUC-PR': 0.7428099802755739, 'Precision': 0.5619834710743802, 'Recall': 0.8292682926829268, 'F1': 0.6699507389162561, 'P-value': np.float64(0.22)}
#
#  Synthetic series 170/1000 (index 253)
# {'AUC-PR': 0.7067127618455855, 'Precision': 0.4266666666666667, 'Recall': 0.7901234567901234, 'F1': 0.5541125541125541, 'P-value': np.float64(0.22)}
#
#  Synthetic series 171/1000 (index 255)
# {'AUC-PR': 0.5135103757263686, 'Precision': 0.3157894736842105, 'Recall': 0.675, 'F1': 0.4302788844621514, 'P-value': np.float64(0.22)}
#
#  Synthetic series 172/1000 (index 256)
# {'AUC-PR': 0.6583140960089294, 'Precision': 0.5949367088607594, 'Recall': 0.573170731707317, 'F1': 0.5838509316770186, 'P-value': np.float64(0.22)}
#
#  Synthetic series 173/1000 (index 258)
# {'AUC-PR': 0.7360947937140251, 'Precision': 0.47540983606557374, 'Recall': 0.7435897435897436, 'F1': 0.58, 'P-value': np.float64(0.22)}
#
#  Synthetic series 174/1000 (index 259)
# {'AUC-PR': 0.7390177834894526, 'Precision': 0.43529411764705883, 'Recall': 0.925, 'F1': 0.592, 'P-value': np.float64(0.22)}
#
#  Synthetic series 175/1000 (index 261)
# {'AUC-PR': 0.5523240447807815, 'Precision': 0.3953488372093023, 'Recall': 0.7183098591549296, 'F1': 0.51, 'P-value': np.float64(0.22)}
#
#  Synthetic series 176/1000 (index 262)
# {'AUC-PR': 0.5859039511817583, 'Precision': 0.32653061224489793, 'Recall': 0.8, 'F1': 0.463768115942029, 'P-value': np.float64(0.22)}
#
#  Synthetic series 177/1000 (index 264)
# {'AUC-PR': 0.8935953262324091, 'Precision': 0.46153846153846156, 'Recall': 0.9295774647887324, 'F1': 0.616822429906542, 'P-value': np.float64(0.22)}
#
#  Synthetic series 178/1000 (index 265)
# {'AUC-PR': 0.680235718067448, 'Precision': 0.4316546762589928, 'Recall': 0.821917808219178, 'F1': 0.5660377358490566, 'P-value': np.float64(0.22)}
#
#  Synthetic series 179/1000 (index 267)
# {'AUC-PR': 0.6057119752496148, 'Precision': 0.3870967741935484, 'Recall': 0.64, 'F1': 0.4824120603015075, 'P-value': np.float64(0.22)}
#
#  Synthetic series 180/1000 (index 268)
# {'AUC-PR': 0.6844366266228517, 'Precision': 0.4206896551724138, 'Recall': 0.7625, 'F1': 0.5422222222222223, 'P-value': np.float64(0.22)}
#
#  Synthetic series 181/1000 (index 270)
# {'AUC-PR': 0.6090667114188423, 'Precision': 0.35119047619047616, 'Recall': 0.7866666666666666, 'F1': 0.48559670781893005, 'P-value': np.float64(0.22)}
#
#  Synthetic series 182/1000 (index 271)
# {'AUC-PR': 0.6570948862239014, 'Precision': 0.5271317829457365, 'Recall': 0.8607594936708861, 'F1': 0.6538461538461539, 'P-value': np.float64(0.22)}
#
#  Synthetic series 183/1000 (index 273)
# {'AUC-PR': 0.742940211993414, 'Precision': 0.4423076923076923, 'Recall': 0.8734177215189873, 'F1': 0.5872340425531914, 'P-value': np.float64(0.22)}
#
#  Synthetic series 184/1000 (index 274)
# {'AUC-PR': 0.620176366113141, 'Precision': 0.35526315789473684, 'Recall': 0.6923076923076923, 'F1': 0.46956521739130436, 'P-value': np.float64(0.22)}
#
#  Synthetic series 185/1000 (index 276)
# {'AUC-PR': 0.54963334826157, 'Precision': 0.3551912568306011, 'Recall': 0.8666666666666667, 'F1': 0.5038759689922481, 'P-value': np.float64(0.22)}
#
#  Synthetic series 186/1000 (index 277)
# {'AUC-PR': 0.6578140606823755, 'Precision': 0.4672897196261682, 'Recall': 0.6329113924050633, 'F1': 0.5376344086021505, 'P-value': np.float64(0.22)}
#
#  Synthetic series 187/1000 (index 279)
# {'AUC-PR': 0.6543189493543564, 'Precision': 0.46788990825688076, 'Recall': 0.6296296296296297, 'F1': 0.5368421052631579, 'P-value': np.float64(0.22)}
#
#  Synthetic series 188/1000 (index 280)
# {'AUC-PR': 0.6227806650870933, 'Precision': 0.4172661870503597, 'Recall': 0.7160493827160493, 'F1': 0.5272727272727272, 'P-value': np.float64(0.22)}
#
#  Synthetic series 189/1000 (index 282)
# {'AUC-PR': 0.5487510424067812, 'Precision': 0.3609467455621302, 'Recall': 0.7721518987341772, 'F1': 0.49193548387096775, 'P-value': np.float64(0.23)}
#
#  Synthetic series 190/1000 (index 283)
# {'AUC-PR': 0.5337683539408172, 'Precision': 0.39705882352941174, 'Recall': 0.6835443037974683, 'F1': 0.5023255813953489, 'P-value': np.float64(0.23)}
#
#  Synthetic series 191/1000 (index 285)
# {'AUC-PR': 0.7045924886307648, 'Precision': 0.3624161073825503, 'Recall': 0.7397260273972602, 'F1': 0.4864864864864865, 'P-value': np.float64(0.23)}
#
#  Synthetic series 192/1000 (index 286)
# {'AUC-PR': 0.7861715966973881, 'Precision': 0.4303030303030303, 'Recall': 0.9342105263157895, 'F1': 0.5892116182572614, 'P-value': np.float64(0.23)}
#
#  Synthetic series 193/1000 (index 288)
# {'AUC-PR': 0.6045783178379256, 'Precision': 0.3469387755102041, 'Recall': 0.6623376623376623, 'F1': 0.45535714285714285, 'P-value': np.float64(0.23)}
#
#  Synthetic series 194/1000 (index 289)
# {'AUC-PR': 0.550181045699711, 'Precision': 0.3798449612403101, 'Recall': 0.6363636363636364, 'F1': 0.47572815533980584, 'P-value': np.float64(0.23)}
#
#  Synthetic series 195/1000 (index 291)
# {'AUC-PR': 0.8766050927552187, 'Precision': 0.4642857142857143, 'Recall': 0.9873417721518988, 'F1': 0.631578947368421, 'P-value': np.float64(0.23)}
#
#  Synthetic series 196/1000 (index 292)
# {'AUC-PR': 0.7021759197856451, 'Precision': 0.4305555555555556, 'Recall': 0.7654320987654321, 'F1': 0.5511111111111111, 'P-value': np.float64(0.23)}
#
#  Synthetic series 197/1000 (index 294)
# {'AUC-PR': 0.7528021060404805, 'Precision': 0.5348837209302325, 'Recall': 0.8846153846153846, 'F1': 0.6666666666666666, 'P-value': np.float64(0.23)}
#
#  Synthetic series 198/1000 (index 295)
# {'AUC-PR': 0.7668766425370713, 'Precision': 0.5043478260869565, 'Recall': 0.7733333333333333, 'F1': 0.6105263157894737, 'P-value': np.float64(0.23)}
#
#  Synthetic series 199/1000 (index 297)
# {'AUC-PR': 0.7008091447929735, 'Precision': 0.34523809523809523, 'Recall': 0.7945205479452054, 'F1': 0.48132780082987553, 'P-value': np.float64(0.23)}
#
#  Synthetic series 200/1000 (index 298)
# {'AUC-PR': 0.838409545671016, 'Precision': 0.32075471698113206, 'Recall': 1.0, 'F1': 0.4857142857142857, 'P-value': np.float64(0.23)}
#
#  Synthetic series 201/1000 (index 300)
# {'AUC-PR': 0.7719049667272678, 'Precision': 0.546875, 'Recall': 0.8433734939759037, 'F1': 0.6635071090047393, 'P-value': np.float64(0.23)}
#
#  Synthetic series 202/1000 (index 301)
# {'AUC-PR': 0.48900319430063277, 'Precision': 0.3333333333333333, 'Recall': 0.5844155844155844, 'F1': 0.42452830188679247, 'P-value': np.float64(0.23)}
#
#  Synthetic series 203/1000 (index 303)
# {'AUC-PR': 0.505557133859047, 'Precision': 0.3776223776223776, 'Recall': 0.7297297297297297, 'F1': 0.4976958525345622, 'P-value': np.float64(0.23)}
#
#  Synthetic series 204/1000 (index 304)
# {'AUC-PR': 0.7671877703669856, 'Precision': 0.3888888888888889, 'Recall': 0.8513513513513513, 'F1': 0.5338983050847458, 'P-value': np.float64(0.23)}
#
#  Synthetic series 205/1000 (index 306)
# {'AUC-PR': 0.6129505783867413, 'Precision': 0.4594594594594595, 'Recall': 0.6710526315789473, 'F1': 0.5454545454545454, 'P-value': np.float64(0.23)}
#
#  Synthetic series 206/1000 (index 307)
# {'AUC-PR': 0.6764633047348275, 'Precision': 0.49137931034482757, 'Recall': 0.7307692307692307, 'F1': 0.5876288659793815, 'P-value': np.float64(0.23)}
#
#  Synthetic series 207/1000 (index 309)
# {'AUC-PR': 0.755384527691251, 'Precision': 0.4305555555555556, 'Recall': 0.8378378378378378, 'F1': 0.5688073394495413, 'P-value': np.float64(0.23)}
#
#  Synthetic series 208/1000 (index 310)
# {'AUC-PR': 0.5684217434234642, 'Precision': 0.4140625, 'Recall': 0.6883116883116883, 'F1': 0.5170731707317073, 'P-value': np.float64(0.23)}
#
#  Synthetic series 209/1000 (index 312)
# {'AUC-PR': 0.7424582232678716, 'Precision': 0.5255474452554745, 'Recall': 0.8571428571428571, 'F1': 0.6515837104072398, 'P-value': np.float64(0.23)}
#
#  Synthetic series 210/1000 (index 313)
# {'AUC-PR': 0.706710335689772, 'Precision': 0.46153846153846156, 'Recall': 0.7857142857142857, 'F1': 0.5814977973568282, 'P-value': np.float64(0.23)}
#
#  Synthetic series 211/1000 (index 315)
# {'AUC-PR': 0.6935095060114221, 'Precision': 0.43312101910828027, 'Recall': 0.8831168831168831, 'F1': 0.5811965811965812, 'P-value': np.float64(0.23)}
#
#  Synthetic series 212/1000 (index 316)
# {'AUC-PR': 0.6928828393289841, 'Precision': 0.4233128834355828, 'Recall': 0.8313253012048193, 'F1': 0.5609756097560976, 'P-value': np.float64(0.23)}
#
#  Synthetic series 213/1000 (index 318)
# {'AUC-PR': 0.7150449495487268, 'Precision': 0.33653846153846156, 'Recall': 0.9210526315789473, 'F1': 0.49295774647887325, 'P-value': np.float64(0.23)}
#
#  Synthetic series 214/1000 (index 319)
# {'AUC-PR': 0.8036315892932286, 'Precision': 0.46, 'Recall': 0.8734177215189873, 'F1': 0.6026200873362445, 'P-value': np.float64(0.23)}
#
#  Synthetic series 215/1000 (index 321)
# {'AUC-PR': 0.7626583674466405, 'Precision': 0.4316546762589928, 'Recall': 0.8, 'F1': 0.5607476635514018, 'P-value': np.float64(0.23)}
#
#  Synthetic series 216/1000 (index 322)
# {'AUC-PR': 0.5503357518461776, 'Precision': 0.38271604938271603, 'Recall': 0.8051948051948052, 'F1': 0.5188284518828452, 'P-value': np.float64(0.23)}
#
#  Synthetic series 217/1000 (index 324)
# {'AUC-PR': 0.5711170651812886, 'Precision': 0.3090909090909091, 'Recall': 0.68, 'F1': 0.425, 'P-value': np.float64(0.23)}
#
#  Synthetic series 218/1000 (index 325)
# {'AUC-PR': 0.6597317436106273, 'Precision': 0.49, 'Recall': 0.6533333333333333, 'F1': 0.56, 'P-value': np.float64(0.23)}
#
#  Synthetic series 219/1000 (index 327)
# {'AUC-PR': 0.7108107669698885, 'Precision': 0.4326241134751773, 'Recall': 0.782051282051282, 'F1': 0.5570776255707762, 'P-value': np.float64(0.23)}
#
#  Synthetic series 220/1000 (index 328)
# {'AUC-PR': 0.7516180746155605, 'Precision': 0.4, 'Recall': 0.9090909090909091, 'F1': 0.5555555555555556, 'P-value': np.float64(0.23)}
#
#  Synthetic series 221/1000 (index 330)
# {'AUC-PR': 0.7569588910709001, 'Precision': 0.4025974025974026, 'Recall': 0.8266666666666667, 'F1': 0.5414847161572053, 'P-value': np.float64(0.23)}
#
#  Synthetic series 222/1000 (index 331)
# {'AUC-PR': 0.5674831822840253, 'Precision': 0.4125, 'Recall': 0.825, 'F1': 0.55, 'P-value': np.float64(0.23)}
#
#  Synthetic series 223/1000 (index 333)
# {'AUC-PR': 0.5199925791265679, 'Precision': 0.3548387096774194, 'Recall': 0.55, 'F1': 0.43137254901960786, 'P-value': np.float64(0.23)}
#
#  Synthetic series 224/1000 (index 334)
# {'AUC-PR': 0.7399487559951019, 'Precision': 0.36774193548387096, 'Recall': 0.7916666666666666, 'F1': 0.5022026431718062, 'P-value': np.float64(0.23)}
#
#  Synthetic series 225/1000 (index 336)
# {'AUC-PR': 0.8091928366370402, 'Precision': 0.5116279069767442, 'Recall': 0.8461538461538461, 'F1': 0.6376811594202898, 'P-value': np.float64(0.23)}
#
#  Synthetic series 226/1000 (index 337)
# {'AUC-PR': 0.6655115688788035, 'Precision': 0.48148148148148145, 'Recall': 0.6933333333333334, 'F1': 0.5683060109289617, 'P-value': np.float64(0.23)}
#
#  Synthetic series 227/1000 (index 339)
# {'AUC-PR': 0.6098256069478779, 'Precision': 0.45, 'Recall': 0.6666666666666666, 'F1': 0.5373134328358209, 'P-value': np.float64(0.23)}
#
#  Synthetic series 228/1000 (index 340)
# {'AUC-PR': 0.41426803973141924, 'Precision': 0.375, 'Recall': 0.4875, 'F1': 0.42391304347826086, 'P-value': np.float64(0.23)}
#
#  Synthetic series 229/1000 (index 342)
# {'AUC-PR': 0.7563714304547405, 'Precision': 0.6179775280898876, 'Recall': 0.6707317073170732, 'F1': 0.6432748538011696, 'P-value': np.float64(0.23)}
#
#  Synthetic series 230/1000 (index 343)
# {'AUC-PR': 0.6871731845197129, 'Precision': 0.5233644859813084, 'Recall': 0.6746987951807228, 'F1': 0.5894736842105263, 'P-value': np.float64(0.23)}
#
#  Synthetic series 231/1000 (index 345)
# {'AUC-PR': 0.740762883871085, 'Precision': 0.3968253968253968, 'Recall': 0.9493670886075949, 'F1': 0.5597014925373134, 'P-value': np.float64(0.24)}
#
#  Synthetic series 232/1000 (index 346)
# {'AUC-PR': 0.6747504364110198, 'Precision': 0.36363636363636365, 'Recall': 0.8607594936708861, 'F1': 0.5112781954887218, 'P-value': np.float64(0.24)}
#
#  Synthetic series 233/1000 (index 348)
# {'AUC-PR': 0.6321569910725866, 'Precision': 0.3695652173913043, 'Recall': 0.8831168831168831, 'F1': 0.5210727969348659, 'P-value': np.float64(0.24)}
#
#  Synthetic series 234/1000 (index 349)
# {'AUC-PR': 0.6111723777286964, 'Precision': 0.3541666666666667, 'Recall': 0.7285714285714285, 'F1': 0.4766355140186916, 'P-value': np.float64(0.24)}
#
#  Synthetic series 235/1000 (index 351)
# {'AUC-PR': 0.6433849219030636, 'Precision': 0.36363636363636365, 'Recall': 0.759493670886076, 'F1': 0.4918032786885246, 'P-value': np.float64(0.24)}
#
#  Synthetic series 236/1000 (index 352)
# {'AUC-PR': 0.8000482117573795, 'Precision': 0.45, 'Recall': 0.8780487804878049, 'F1': 0.5950413223140496, 'P-value': np.float64(0.24)}
#
#  Synthetic series 237/1000 (index 354)
# {'AUC-PR': 0.6351693284550617, 'Precision': 0.43859649122807015, 'Recall': 0.625, 'F1': 0.5154639175257731, 'P-value': np.float64(0.24)}
#
#  Synthetic series 238/1000 (index 355)
# {'AUC-PR': 0.6995304542180009, 'Precision': 0.46875, 'Recall': 0.8955223880597015, 'F1': 0.6153846153846154, 'P-value': np.float64(0.24)}
#
#  Synthetic series 239/1000 (index 357)
# {'AUC-PR': 0.6953186435282892, 'Precision': 0.47368421052631576, 'Recall': 0.7974683544303798, 'F1': 0.5943396226415094, 'P-value': np.float64(0.24)}
#
#  Synthetic series 240/1000 (index 358)
# {'AUC-PR': 0.6916488255360361, 'Precision': 0.3743016759776536, 'Recall': 0.9305555555555556, 'F1': 0.5338645418326693, 'P-value': np.float64(0.24)}
#
#  Synthetic series 241/1000 (index 360)
# {'AUC-PR': 0.622518249442434, 'Precision': 0.3448275862068966, 'Recall': 0.821917808219178, 'F1': 0.48582995951417, 'P-value': np.float64(0.24)}
#
#  Synthetic series 242/1000 (index 361)
# {'AUC-PR': 0.6930680542489857, 'Precision': 0.37572254335260113, 'Recall': 0.8024691358024691, 'F1': 0.5118110236220472, 'P-value': np.float64(0.24)}
#
#  Synthetic series 243/1000 (index 363)
# {'AUC-PR': 0.7079878452745116, 'Precision': 0.45714285714285713, 'Recall': 0.8205128205128205, 'F1': 0.5871559633027523, 'P-value': np.float64(0.24)}
#
#  Synthetic series 244/1000 (index 364)
# {'AUC-PR': 0.7049421574639806, 'Precision': 0.41358024691358025, 'Recall': 0.8933333333333333, 'F1': 0.5654008438818565, 'P-value': np.float64(0.24)}
#
#  Synthetic series 245/1000 (index 366)
# {'AUC-PR': 0.6448395456863608, 'Precision': 0.36813186813186816, 'Recall': 0.788235294117647, 'F1': 0.50187265917603, 'P-value': np.float64(0.24)}
#
#  Synthetic series 246/1000 (index 367)
# {'AUC-PR': 0.6271415647097188, 'Precision': 0.3147208121827411, 'Recall': 0.7654320987654321, 'F1': 0.4460431654676259, 'P-value': np.float64(0.24)}
#
#  Synthetic series 247/1000 (index 369)
# {'AUC-PR': 0.5647470748704116, 'Precision': 0.375886524822695, 'Recall': 0.6794871794871795, 'F1': 0.4840182648401826, 'P-value': np.float64(0.24)}
#
#  Synthetic series 248/1000 (index 370)
# {'AUC-PR': 0.765767081802601, 'Precision': 0.39473684210526316, 'Recall': 0.8695652173913043, 'F1': 0.5429864253393665, 'P-value': np.float64(0.24)}
#
#  Synthetic series 249/1000 (index 372)
# {'AUC-PR': 0.682903673733955, 'Precision': 0.2831858407079646, 'Recall': 0.8421052631578947, 'F1': 0.423841059602649, 'P-value': np.float64(0.24)}
#
#  Synthetic series 250/1000 (index 373)
# {'AUC-PR': 0.6041477683618155, 'Precision': 0.3958333333333333, 'Recall': 0.7702702702702703, 'F1': 0.5229357798165137, 'P-value': np.float64(0.24)}
#
#  Synthetic series 251/1000 (index 375)
# {'AUC-PR': 0.5050006401102742, 'Precision': 0.3333333333333333, 'Recall': 0.6538461538461539, 'F1': 0.44155844155844154, 'P-value': np.float64(0.24)}
#
#  Synthetic series 252/1000 (index 376)
# {'AUC-PR': 0.6342712767961848, 'Precision': 0.32786885245901637, 'Recall': 0.7317073170731707, 'F1': 0.4528301886792453, 'P-value': np.float64(0.24)}
#
#  Synthetic series 253/1000 (index 378)
# {'AUC-PR': 0.6357471639828053, 'Precision': 0.3622448979591837, 'Recall': 0.8875, 'F1': 0.5144927536231884, 'P-value': np.float64(0.24)}
#
#  Synthetic series 254/1000 (index 379)
# {'AUC-PR': 0.7111649547001289, 'Precision': 0.5645161290322581, 'Recall': 0.8235294117647058, 'F1': 0.6698564593301436, 'P-value': np.float64(0.24)}
#
#  Synthetic series 255/1000 (index 381)
# {'AUC-PR': 0.8289751611780042, 'Precision': 0.6037735849056604, 'Recall': 0.8205128205128205, 'F1': 0.6956521739130435, 'P-value': np.float64(0.24)}
#
#  Synthetic series 256/1000 (index 382)
# {'AUC-PR': 0.423459568097158, 'Precision': 0.3511450381679389, 'Recall': 0.5822784810126582, 'F1': 0.4380952380952381, 'P-value': np.float64(0.24)}
#
#  Synthetic series 257/1000 (index 384)
# {'AUC-PR': 0.6442003310300533, 'Precision': 0.42962962962962964, 'Recall': 0.6904761904761905, 'F1': 0.5296803652968036, 'P-value': np.float64(0.24)}
#
#  Synthetic series 258/1000 (index 385)
# {'AUC-PR': 0.5795345265693852, 'Precision': 0.4180327868852459, 'Recall': 0.6144578313253012, 'F1': 0.4975609756097561, 'P-value': np.float64(0.24)}
#
#  Synthetic series 259/1000 (index 387)
# {'AUC-PR': 0.700286751003761, 'Precision': 0.3595505617977528, 'Recall': 0.9014084507042254, 'F1': 0.5140562248995983, 'P-value': np.float64(0.24)}
#
#  Synthetic series 260/1000 (index 388)
# {'AUC-PR': 0.4724164701021739, 'Precision': 0.38095238095238093, 'Recall': 0.6, 'F1': 0.46601941747572817, 'P-value': np.float64(0.24)}
#
#  Synthetic series 261/1000 (index 390)
# ...
#
#  Synthetic series 916/1000 (index 1372)
# {'AUC-PR': 0.36102240553623816, 'Precision': 0.3015075376884422, 'Recall': 0.8, 'F1': 0.43795620437956206, 'P-value': np.float64(0.4)}
#
#  Synthetic series 917/1000 (index 1374)
# {'AUC-PR': 0.3206022122648061, 'Precision': 0.28205128205128205, 'Recall': 0.7534246575342466, 'F1': 0.41044776119402987, 'P-value': np.float64(0.4)}
#
#  Synthetic series 918/1000 (index 1375)
# {'AUC-PR': 0.7583123471095984, 'Precision': 0.48484848484848486, 'Recall': 0.8421052631578947, 'F1': 0.6153846153846154, 'P-value': np.float64(0.4)}
#
#  Synthetic series 919/1000 (index 1377)
# {'AUC-PR': 0.4087222125321056, 'Precision': 0.4589041095890411, 'Recall': 0.8589743589743589, 'F1': 0.5982142857142857, 'P-value': np.float64(0.4)}
#
#  Synthetic series 920/1000 (index 1378)
# {'AUC-PR': 0.4673835915106021, 'Precision': 0.29017857142857145, 'Recall': 0.8227848101265823, 'F1': 0.429042904290429, 'P-value': np.float64(0.4)}
#
#  Synthetic series 921/1000 (index 1380)
# {'AUC-PR': 0.435102782175404, 'Precision': 0.26334519572953735, 'Recall': 0.9736842105263158, 'F1': 0.41456582633053224, 'P-value': np.float64(0.4)}
#
#  Synthetic series 922/1000 (index 1381)
# {'AUC-PR': 0.3496107724748915, 'Precision': 0.33714285714285713, 'Recall': 0.7972972972972973, 'F1': 0.4738955823293173, 'P-value': np.float64(0.4)}
#
#  Synthetic series 923/1000 (index 1383)
# {'AUC-PR': 0.5570461597566219, 'Precision': 0.38857142857142857, 'Recall': 0.8292682926829268, 'F1': 0.5291828793774319, 'P-value': np.float64(0.4)}
#
#  Synthetic series 924/1000 (index 1384)
# {'AUC-PR': 0.3566021830869539, 'Precision': 0.35602094240837695, 'Recall': 0.8947368421052632, 'F1': 0.5093632958801498, 'P-value': np.float64(0.4)}
#
#  Synthetic series 925/1000 (index 1386)
# {'AUC-PR': 0.3613176358366513, 'Precision': 0.3282051282051282, 'Recall': 0.8205128205128205, 'F1': 0.46886446886446886, 'P-value': np.float64(0.4)}
#
#  Synthetic series 926/1000 (index 1387)
# {'AUC-PR': 0.35320262966089083, 'Precision': 0.32044198895027626, 'Recall': 0.7435897435897436, 'F1': 0.44787644787644787, 'P-value': np.float64(0.4)}
#
#  Synthetic series 927/1000 (index 1389)
# {'AUC-PR': 0.3375960188377077, 'Precision': 0.2675438596491228, 'Recall': 0.7922077922077922, 'F1': 0.4, 'P-value': np.float64(0.4)}
#
#  Synthetic series 928/1000 (index 1390)
# {'AUC-PR': 0.3866237795985584, 'Precision': 0.2736842105263158, 'Recall': 0.6933333333333334, 'F1': 0.39245283018867927, 'P-value': np.float64(0.4)}
#
#  Synthetic series 929/1000 (index 1392)
# {'AUC-PR': 0.3829004153870992, 'Precision': 0.31736526946107785, 'Recall': 0.7571428571428571, 'F1': 0.4472573839662447, 'P-value': np.float64(0.4)}
#
#  Synthetic series 930/1000 (index 1393)
# {'AUC-PR': 0.34342613787329357, 'Precision': 0.2863636363636364, 'Recall': 0.9130434782608695, 'F1': 0.4359861591695502, 'P-value': np.float64(0.4)}
#
#  Synthetic series 931/1000 (index 1395)
# {'AUC-PR': 0.4804666660095965, 'Precision': 0.3096446700507614, 'Recall': 0.7625, 'F1': 0.4404332129963899, 'P-value': np.float64(0.4)}
#
#  Synthetic series 932/1000 (index 1396)
# {'AUC-PR': 0.47831735433256967, 'Precision': 0.26548672566371684, 'Recall': 0.8450704225352113, 'F1': 0.40404040404040403, 'P-value': np.float64(0.4)}
#
#  Synthetic series 933/1000 (index 1398)
# {'AUC-PR': 0.4999806584673404, 'Precision': 0.3670886075949367, 'Recall': 0.7837837837837838, 'F1': 0.5, 'P-value': np.float64(0.4)}
#
#  Synthetic series 934/1000 (index 1399)
# {'AUC-PR': 0.2571480209095483, 'Precision': 0.26406926406926406, 'Recall': 0.7625, 'F1': 0.39228295819935693, 'P-value': np.float64(0.4)}
#
#  Synthetic series 935/1000 (index 1401)
# {'AUC-PR': 0.45752257667625573, 'Precision': 0.3269230769230769, 'Recall': 0.8292682926829268, 'F1': 0.4689655172413793, 'P-value': np.float64(0.4)}
#
#  Synthetic series 936/1000 (index 1402)
# {'AUC-PR': 0.39001127921247575, 'Precision': 0.33181818181818185, 'Recall': 0.9240506329113924, 'F1': 0.4882943143812709, 'P-value': np.float64(0.4)}
#
#  Synthetic series 937/1000 (index 1404)
# {'AUC-PR': 0.45332594696687245, 'Precision': 0.29714285714285715, 'Recall': 0.7027027027027027, 'F1': 0.41767068273092367, 'P-value': np.float64(0.4)}
#
#  Synthetic series 938/1000 (index 1405)
# {'AUC-PR': 0.322671957232218, 'Precision': 0.3103448275862069, 'Recall': 0.6666666666666666, 'F1': 0.4235294117647059, 'P-value': np.float64(0.4)}
#
#  Synthetic series 939/1000 (index 1407)
# {'AUC-PR': 0.460258725495687, 'Precision': 0.3597560975609756, 'Recall': 0.7468354430379747, 'F1': 0.48559670781893005, 'P-value': np.float64(0.41)}
#
#  Synthetic series 940/1000 (index 1408)
# {'AUC-PR': 0.4309335576063103, 'Precision': 0.29591836734693877, 'Recall': 0.7341772151898734, 'F1': 0.4218181818181818, 'P-value': np.float64(0.41)}
#
#  Synthetic series 941/1000 (index 1410)
# {'AUC-PR': 0.4807707059624205, 'Precision': 0.39864864864864863, 'Recall': 0.7283950617283951, 'F1': 0.5152838427947598, 'P-value': np.float64(0.41)}
#
#  Synthetic series 942/1000 (index 1411)
# {'AUC-PR': 0.5058971642749934, 'Precision': 0.2857142857142857, 'Recall': 0.8857142857142857, 'F1': 0.43205574912891986, 'P-value': np.float64(0.41)}
#
#  Synthetic series 943/1000 (index 1413)
# {'AUC-PR': 0.6068978549047447, 'Precision': 0.4370860927152318, 'Recall': 0.8461538461538461, 'F1': 0.5764192139737991, 'P-value': np.float64(0.41)}
#
#  Synthetic series 944/1000 (index 1414)
# {'AUC-PR': 0.45993369624645647, 'Precision': 0.3253012048192771, 'Recall': 0.6923076923076923, 'F1': 0.4426229508196721, 'P-value': np.float64(0.41)}
#
#  Synthetic series 945/1000 (index 1416)
# {'AUC-PR': 0.41921786884956536, 'Precision': 0.4539877300613497, 'Recall': 0.8705882352941177, 'F1': 0.5967741935483871, 'P-value': np.float64(0.41)}
#
#  Synthetic series 946/1000 (index 1417)
# {'AUC-PR': 0.3983637411798221, 'Precision': 0.3532934131736527, 'Recall': 0.7375, 'F1': 0.4777327935222672, 'P-value': np.float64(0.41)}
#
#  Synthetic series 947/1000 (index 1419)
# {'AUC-PR': 0.3131908086952797, 'Precision': 0.2764976958525346, 'Recall': 0.8450704225352113, 'F1': 0.4166666666666667, 'P-value': np.float64(0.41)}
#
#  Synthetic series 948/1000 (index 1420)
# {'AUC-PR': 0.49556431841498766, 'Precision': 0.4690265486725664, 'Recall': 0.6708860759493671, 'F1': 0.5520833333333334, 'P-value': np.float64(0.41)}
#
#  Synthetic series 949/1000 (index 1422)
# {'AUC-PR': 0.33553196784338835, 'Precision': 0.3409090909090909, 'Recall': 0.7317073170731707, 'F1': 0.46511627906976744, 'P-value': np.float64(0.41)}
#
#  Synthetic series 950/1000 (index 1423)
# {'AUC-PR': 0.6555881725948406, 'Precision': 0.49032258064516127, 'Recall': 0.9743589743589743, 'F1': 0.6523605150214592, 'P-value': np.float64(0.41)}
#
#  Synthetic series 951/1000 (index 1425)
# {'AUC-PR': 0.3456373446741365, 'Precision': 0.3333333333333333, 'Recall': 0.8987341772151899, 'F1': 0.4863013698630137, 'P-value': np.float64(0.41)}
#
#  Synthetic series 952/1000 (index 1426)
# {'AUC-PR': 0.4529596623097816, 'Precision': 0.3641304347826087, 'Recall': 0.8701298701298701, 'F1': 0.5134099616858238, 'P-value': np.float64(0.41)}
#
#  Synthetic series 953/1000 (index 1428)
# {'AUC-PR': 0.45947138037622953, 'Precision': 0.5294117647058824, 'Recall': 0.6585365853658537, 'F1': 0.5869565217391305, 'P-value': np.float64(0.41)}
#
#  Synthetic series 954/1000 (index 1429)
# {'AUC-PR': 0.30823314170970423, 'Precision': 0.28, 'Recall': 0.7875, 'F1': 0.4131147540983607, 'P-value': np.float64(0.41)}
#
#  Synthetic series 955/1000 (index 1431)
# {'AUC-PR': 0.43010236099720217, 'Precision': 0.372972972972973, 'Recall': 0.8313253012048193, 'F1': 0.5149253731343284, 'P-value': np.float64(0.41)}
#
#  Synthetic series 956/1000 (index 1432)
# {'AUC-PR': 0.3326405230004725, 'Precision': 0.31555555555555553, 'Recall': 0.8987341772151899, 'F1': 0.46710526315789475, 'P-value': np.float64(0.41)}
#
#  Synthetic series 957/1000 (index 1434)
# {'AUC-PR': 0.33781727421340146, 'Precision': 0.2845528455284553, 'Recall': 0.8641975308641975, 'F1': 0.42813455657492355, 'P-value': np.float64(0.41)}
#
#  Synthetic series 958/1000 (index 1435)
# {'AUC-PR': 0.3420615667151164, 'Precision': 0.2608695652173913, 'Recall': 0.8571428571428571, 'F1': 0.4, 'P-value': np.float64(0.41)}
#
#  Synthetic series 959/1000 (index 1437)
# {'AUC-PR': 0.4876726267539947, 'Precision': 0.375, 'Recall': 0.9, 'F1': 0.5294117647058824, 'P-value': np.float64(0.41)}
#
#  Synthetic series 960/1000 (index 1438)
# {'AUC-PR': 0.42229312040534533, 'Precision': 0.2849462365591398, 'Recall': 0.6463414634146342, 'F1': 0.39552238805970147, 'P-value': np.float64(0.41)}
#
#  Synthetic series 961/1000 (index 1440)
# {'AUC-PR': 0.5896311718917916, 'Precision': 0.3317307692307692, 'Recall': 1.0, 'F1': 0.4981949458483754, 'P-value': np.float64(0.41)}
#
#  Synthetic series 962/1000 (index 1441)
# {'AUC-PR': 0.34053691438667116, 'Precision': 0.34911242603550297, 'Recall': 0.7283950617283951, 'F1': 0.472, 'P-value': np.float64(0.41)}
#
#  Synthetic series 963/1000 (index 1443)
# {'AUC-PR': 0.4277509513645862, 'Precision': 0.30092592592592593, 'Recall': 0.9027777777777778, 'F1': 0.4513888888888889, 'P-value': np.float64(0.41)}
#
#  Synthetic series 964/1000 (index 1444)
# {'AUC-PR': 0.41087816905966174, 'Precision': 0.3407821229050279, 'Recall': 0.782051282051282, 'F1': 0.47470817120622566, 'P-value': np.float64(0.41)}
#
#  Synthetic series 965/1000 (index 1446)
# {'AUC-PR': 0.46947101785313056, 'Precision': 0.2608695652173913, 'Recall': 0.75, 'F1': 0.3870967741935484, 'P-value': np.float64(0.41)}
#
#  Synthetic series 966/1000 (index 1447)
# {'AUC-PR': 0.6249098455025869, 'Precision': 0.40119760479041916, 'Recall': 0.8170731707317073, 'F1': 0.5381526104417671, 'P-value': np.float64(0.41)}
#
#  Synthetic series 967/1000 (index 1449)
# {'AUC-PR': 0.7175407676242352, 'Precision': 0.33014354066985646, 'Recall': 0.8961038961038961, 'F1': 0.4825174825174825, 'P-value': np.float64(0.41)}
#
#  Synthetic series 968/1000 (index 1450)
# {'AUC-PR': 0.4538052614110414, 'Precision': 0.3620689655172414, 'Recall': 0.9130434782608695, 'F1': 0.5185185185185185, 'P-value': np.float64(0.41)}
#
#  Synthetic series 969/1000 (index 1452)
# {'AUC-PR': 0.48526102407751937, 'Precision': 0.2413793103448276, 'Recall': 0.8181818181818182, 'F1': 0.3727810650887574, 'P-value': np.float64(0.41)}
#
#  Synthetic series 970/1000 (index 1453)
# {'AUC-PR': 0.2723822712258751, 'Precision': 0.20948616600790515, 'Recall': 0.6794871794871795, 'F1': 0.3202416918429003, 'P-value': np.float64(0.41)}
#
#  Synthetic series 971/1000 (index 1455)
# {'AUC-PR': 0.3625614276714094, 'Precision': 0.37423312883435583, 'Recall': 0.7439024390243902, 'F1': 0.49795918367346936, 'P-value': np.float64(0.41)}
#
#  Synthetic series 972/1000 (index 1456)
# {'AUC-PR': 0.2590587180489371, 'Precision': 0.2777777777777778, 'Recall': 0.7638888888888888, 'F1': 0.4074074074074074, 'P-value': np.float64(0.41)}
#
#  Synthetic series 973/1000 (index 1458)
# {'AUC-PR': 0.5196543310188381, 'Precision': 0.43448275862068964, 'Recall': 0.8076923076923077, 'F1': 0.5650224215246636, 'P-value': np.float64(0.41)}
#
#  Synthetic series 974/1000 (index 1459)
# {'AUC-PR': 0.451645085756271, 'Precision': 0.3131868131868132, 'Recall': 0.75, 'F1': 0.4418604651162791, 'P-value': np.float64(0.41)}
#
#  Synthetic series 975/1000 (index 1461)
# {'AUC-PR': 0.28331607372894696, 'Precision': 0.25311203319502074, 'Recall': 0.7721518987341772, 'F1': 0.38125, 'P-value': np.float64(0.41)}
#
#  Synthetic series 976/1000 (index 1462)
# {'AUC-PR': 0.4299856704998077, 'Precision': 0.3567567567567568, 'Recall': 0.7951807228915663, 'F1': 0.4925373134328358, 'P-value': np.float64(0.41)}
#
#  Synthetic series 977/1000 (index 1464)
# {'AUC-PR': 0.29978937492601454, 'Precision': 0.3209302325581395, 'Recall': 0.8734177215189873, 'F1': 0.46938775510204084, 'P-value': np.float64(0.41)}
#
#  Synthetic series 978/1000 (index 1465)
# {'AUC-PR': 0.7089394416429301, 'Precision': 0.3865979381443299, 'Recall': 0.974025974025974, 'F1': 0.5535055350553506, 'P-value': np.float64(0.41)}
#
#  Synthetic series 979/1000 (index 1467)
# {'AUC-PR': 0.5714891703201467, 'Precision': 0.30701754385964913, 'Recall': 0.9210526315789473, 'F1': 0.4605263157894737, 'P-value': np.float64(0.41)}
#
#  Synthetic series 980/1000 (index 1468)
# {'AUC-PR': 0.4473983181970789, 'Precision': 0.40804597701149425, 'Recall': 0.8987341772151899, 'F1': 0.5612648221343873, 'P-value': np.float64(0.42)}
#
#  Synthetic series 981/1000 (index 1470)
# {'AUC-PR': 0.33039971273414226, 'Precision': 0.296875, 'Recall': 0.9156626506024096, 'F1': 0.44837758112094395, 'P-value': np.float64(0.42)}
#
#  Synthetic series 982/1000 (index 1471)
# {'AUC-PR': 0.3407749002514937, 'Precision': 0.33, 'Recall': 0.8048780487804879, 'F1': 0.46808510638297873, 'P-value': np.float64(0.42)}
#
#  Synthetic series 983/1000 (index 1473)
# {'AUC-PR': 0.31628365263633407, 'Precision': 0.2935323383084577, 'Recall': 0.7564102564102564, 'F1': 0.4229390681003584, 'P-value': np.float64(0.42)}
#
#  Synthetic series 984/1000 (index 1474)
# {'AUC-PR': 0.39117242700041926, 'Precision': 0.2869198312236287, 'Recall': 0.8607594936708861, 'F1': 0.43037974683544306, 'P-value': np.float64(0.42)}
#
#  Synthetic series 985/1000 (index 1476)
# {'AUC-PR': 0.5534588061795372, 'Precision': 0.4084507042253521, 'Recall': 0.7837837837837838, 'F1': 0.5370370370370371, 'P-value': np.float64(0.42)}
#
#  Synthetic series 986/1000 (index 1477)
# {'AUC-PR': 0.25649314080350194, 'Precision': 0.2661290322580645, 'Recall': 0.8354430379746836, 'F1': 0.4036697247706422, 'P-value': np.float64(0.42)}
#
#  Synthetic series 987/1000 (index 1479)
# {'AUC-PR': 0.5471034673301225, 'Precision': 0.2926829268292683, 'Recall': 0.972972972972973, 'F1': 0.45, 'P-value': np.float64(0.42)}
#
#  Synthetic series 988/1000 (index 1480)
# {'AUC-PR': 0.3654906703060128, 'Precision': 0.36645962732919257, 'Recall': 0.7375, 'F1': 0.4896265560165975, 'P-value': np.float64(0.42)}
#
#  Synthetic series 989/1000 (index 1482)
# {'AUC-PR': 0.3352592751693177, 'Precision': 0.33519553072625696, 'Recall': 0.7317073170731707, 'F1': 0.45977011494252873, 'P-value': np.float64(0.42)}
#
#  Synthetic series 990/1000 (index 1483)
# {'AUC-PR': 0.33372181457108696, 'Precision': 0.2911392405063291, 'Recall': 0.8734177215189873, 'F1': 0.43670886075949367, 'P-value': np.float64(0.42)}
#
#  Synthetic series 991/1000 (index 1485)
# {'AUC-PR': 0.2845400452069335, 'Precision': 0.2909090909090909, 'Recall': 0.8205128205128205, 'F1': 0.42953020134228187, 'P-value': np.float64(0.42)}
#
#  Synthetic series 992/1000 (index 1486)
# {'AUC-PR': 0.24067498638733417, 'Precision': 0.21888412017167383, 'Recall': 0.6710526315789473, 'F1': 0.3300970873786408, 'P-value': np.float64(0.42)}
#
#  Synthetic series 993/1000 (index 1488)
# {'AUC-PR': 0.33629921994210266, 'Precision': 0.36024844720496896, 'Recall': 0.7435897435897436, 'F1': 0.48535564853556484, 'P-value': np.float64(0.42)}
#
#  Synthetic series 994/1000 (index 1489)
# {'AUC-PR': 0.4469441289291389, 'Precision': 0.39473684210526316, 'Recall': 0.7407407407407407, 'F1': 0.5150214592274678, 'P-value': np.float64(0.42)}
#
#  Synthetic series 995/1000 (index 1491)
# {'AUC-PR': 0.3160222597518679, 'Precision': 0.32432432432432434, 'Recall': 0.8571428571428571, 'F1': 0.47058823529411764, 'P-value': np.float64(0.42)}
#
#  Synthetic series 996/1000 (index 1492)
# {'AUC-PR': 0.28927998795040877, 'Precision': 0.3004694835680751, 'Recall': 0.810126582278481, 'F1': 0.4383561643835616, 'P-value': np.float64(0.42)}
#
#  Synthetic series 997/1000 (index 1494)
# {'AUC-PR': 0.41860603626961773, 'Precision': 0.36024844720496896, 'Recall': 0.6904761904761905, 'F1': 0.47346938775510206, 'P-value': np.float64(0.42)}
#
#  Synthetic series 998/1000 (index 1495)
# {'AUC-PR': 0.35350198910711994, 'Precision': 0.34375, 'Recall': 0.6790123456790124, 'F1': 0.45643153526970953, 'P-value': np.float64(0.42)}
#
#  Synthetic series 999/1000 (index 1497)
# {'AUC-PR': 0.37559920641198796, 'Precision': 0.26976744186046514, 'Recall': 0.7631578947368421, 'F1': 0.39862542955326463, 'P-value': np.float64(0.42)}
#
#  Synthetic series 1000/1000 (index 1499)
# {'AUC-PR': 0.29098905320790913, 'Precision': 0.30434782608695654, 'Recall': 0.7777777777777778, 'F1': 0.4375, 'P-value': np.float64(0.42)}

# %%
plt.figure(figsize=(7, 3), dpi=300)

plt.plot(
    ks,
    mean_recall,
    marker="o",
    markersize=6,
    linewidth=1.2,
    label="threshold = 0.6"
)

plt.fill_between(
    ks,
    lower,
    upper,
    alpha=0.3,
    label="±1 std (threshold = 0.6)"
)

plt.xlabel("Minimum anticipation (time steps before the peak)")
plt.ylabel("Recall (fraction of anticipated peaks)")
plt.title(
    "(c) LSTM trained on mixed data"
)
plt.grid(alpha=0.3)
plt.legend()
plt.ylim(0.45, 1.05)

plt.show()

# %%
plt.figure(figsize=(5, 3))

plt.plot(
    ks,
    mean_recall,
    marker="o",
    markersize=5,
    label="threshold = 0.6"
)

plt.fill_between(
    ks,
    lower,
    upper,
    alpha=0.3,
    label="±1 std (threshold = 0.6)"
)

plt.ylabel("Recall")
plt.title(
    "(c) LSTM trained on mixed data"
)
plt.grid(alpha=0.3)
plt.legend()
plt.xlabel("Anticipation (k)")
# plt.tick_params(axis='x', labelbottom=False)
plt.ylim(0.45, 1.05)

plt.savefig("../paper/images/recall_vs_anticipation_mixed_data_h.png", dpi=300, bbox_inches='tight')  

plt.show()

# %%
all_metrics = pd.DataFrame(all_metrics)
all_metrics['P-value'] = all_metrics['P-value'].astype(float).round(2)

table = (
    all_metrics
    .groupby('P-value', as_index=False)
    .mean()
)

def highlight_best_worst(s):
    is_max = s == s.max()
    is_min = s == s.min()
    
    styles = []
    for max_v, min_v in zip(is_max, is_min):
        if max_v:
            styles.append('background-color: #b7f7c1; font-weight: bold')  # best (green)
        elif min_v:
            styles.append('background-color: #f7b7b7; font-weight: bold')  # worst (red)
        else:
            styles.append('')
    
    return styles

styled_table = (
    table
    .style
    .apply(highlight_best_worst, axis=0)  
    .format("{:.3f}")
)

styled_table
# Out:
# <style type="text/css">
# #T_cffc8_row0_col0, #T_cffc8_row1_col3, #T_cffc8_row17_col4, #T_cffc8_row22_col2, #T_cffc8_row24_col1 {
#   background-color: #f7b7b7;
#   font-weight: bold;
# }
# #T_cffc8_row13_col4, #T_cffc8_row14_col2, #T_cffc8_row23_col1, #T_cffc8_row23_col3, #T_cffc8_row24_col0 {
#   background-color: #b7f7c1;
#   font-weight: bold;
# }
# </style>
# <table id="T_cffc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cffc8_level0_col0" class="col_heading level0 col0" >P-value</th>
#       <th id="T_cffc8_level0_col1" class="col_heading level0 col1" >AUC-PR</th>
#       <th id="T_cffc8_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_cffc8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cffc8_level0_col4" class="col_heading level0 col4" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cffc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cffc8_row0_col0" class="data row0 col0" >0.180</td>
#       <td id="T_cffc8_row0_col1" class="data row0 col1" >0.734</td>
#       <td id="T_cffc8_row0_col2" class="data row0 col2" >0.554</td>
#       <td id="T_cffc8_row0_col3" class="data row0 col3" >0.734</td>
#       <td id="T_cffc8_row0_col4" class="data row0 col4" >0.606</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cffc8_row1_col0" class="data row1 col0" >0.190</td>
#       <td id="T_cffc8_row1_col1" class="data row1 col1" >0.727</td>
#       <td id="T_cffc8_row1_col2" class="data row1 col2" >0.554</td>
#       <td id="T_cffc8_row1_col3" class="data row1 col3" >0.716</td>
#       <td id="T_cffc8_row1_col4" class="data row1 col4" >0.606</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cffc8_row2_col0" class="data row2 col0" >0.200</td>
#       <td id="T_cffc8_row2_col1" class="data row2 col1" >0.738</td>
#       <td id="T_cffc8_row2_col2" class="data row2 col2" >0.557</td>
#       <td id="T_cffc8_row2_col3" class="data row2 col3" >0.772</td>
#       <td id="T_cffc8_row2_col4" class="data row2 col4" >0.616</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cffc8_row3_col0" class="data row3 col0" >0.210</td>
#       <td id="T_cffc8_row3_col1" class="data row3 col1" >0.762</td>
#       <td id="T_cffc8_row3_col2" class="data row3 col2" >0.582</td>
#       <td id="T_cffc8_row3_col3" class="data row3 col3" >0.748</td>
#       <td id="T_cffc8_row3_col4" class="data row3 col4" >0.624</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cffc8_row4_col0" class="data row4 col0" >0.220</td>
#       <td id="T_cffc8_row4_col1" class="data row4 col1" >0.744</td>
#       <td id="T_cffc8_row4_col2" class="data row4 col2" >0.572</td>
#       <td id="T_cffc8_row4_col3" class="data row4 col3" >0.759</td>
#       <td id="T_cffc8_row4_col4" class="data row4 col4" >0.629</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cffc8_row5_col0" class="data row5 col0" >0.230</td>
#       <td id="T_cffc8_row5_col1" class="data row5 col1" >0.772</td>
#       <td id="T_cffc8_row5_col2" class="data row5 col2" >0.560</td>
#       <td id="T_cffc8_row5_col3" class="data row5 col3" >0.778</td>
#       <td id="T_cffc8_row5_col4" class="data row5 col4" >0.639</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cffc8_row6_col0" class="data row6 col0" >0.240</td>
#       <td id="T_cffc8_row6_col1" class="data row6 col1" >0.762</td>
#       <td id="T_cffc8_row6_col2" class="data row6 col2" >0.554</td>
#       <td id="T_cffc8_row6_col3" class="data row6 col3" >0.784</td>
#       <td id="T_cffc8_row6_col4" class="data row6 col4" >0.627</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cffc8_row7_col0" class="data row7 col0" >0.250</td>
#       <td id="T_cffc8_row7_col1" class="data row7 col1" >0.751</td>
#       <td id="T_cffc8_row7_col2" class="data row7 col2" >0.550</td>
#       <td id="T_cffc8_row7_col3" class="data row7 col3" >0.776</td>
#       <td id="T_cffc8_row7_col4" class="data row7 col4" >0.620</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cffc8_row8_col0" class="data row8 col0" >0.260</td>
#       <td id="T_cffc8_row8_col1" class="data row8 col1" >0.749</td>
#       <td id="T_cffc8_row8_col2" class="data row8 col2" >0.570</td>
#       <td id="T_cffc8_row8_col3" class="data row8 col3" >0.745</td>
#       <td id="T_cffc8_row8_col4" class="data row8 col4" >0.615</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cffc8_row9_col0" class="data row9 col0" >0.270</td>
#       <td id="T_cffc8_row9_col1" class="data row9 col1" >0.750</td>
#       <td id="T_cffc8_row9_col2" class="data row9 col2" >0.531</td>
#       <td id="T_cffc8_row9_col3" class="data row9 col3" >0.776</td>
#       <td id="T_cffc8_row9_col4" class="data row9 col4" >0.600</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cffc8_row10_col0" class="data row10 col0" >0.280</td>
#       <td id="T_cffc8_row10_col1" class="data row10 col1" >0.731</td>
#       <td id="T_cffc8_row10_col2" class="data row10 col2" >0.519</td>
#       <td id="T_cffc8_row10_col3" class="data row10 col3" >0.759</td>
#       <td id="T_cffc8_row10_col4" class="data row10 col4" >0.602</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cffc8_row11_col0" class="data row11 col0" >0.290</td>
#       <td id="T_cffc8_row11_col1" class="data row11 col1" >0.757</td>
#       <td id="T_cffc8_row11_col2" class="data row11 col2" >0.537</td>
#       <td id="T_cffc8_row11_col3" class="data row11 col3" >0.773</td>
#       <td id="T_cffc8_row11_col4" class="data row11 col4" >0.617</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cffc8_row12_col0" class="data row12 col0" >0.300</td>
#       <td id="T_cffc8_row12_col1" class="data row12 col1" >0.768</td>
#       <td id="T_cffc8_row12_col2" class="data row12 col2" >0.582</td>
#       <td id="T_cffc8_row12_col3" class="data row12 col3" >0.757</td>
#       <td id="T_cffc8_row12_col4" class="data row12 col4" >0.633</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cffc8_row13_col0" class="data row13 col0" >0.310</td>
#       <td id="T_cffc8_row13_col1" class="data row13 col1" >0.787</td>
#       <td id="T_cffc8_row13_col2" class="data row13 col2" >0.592</td>
#       <td id="T_cffc8_row13_col3" class="data row13 col3" >0.773</td>
#       <td id="T_cffc8_row13_col4" class="data row13 col4" >0.650</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cffc8_row14_col0" class="data row14 col0" >0.320</td>
#       <td id="T_cffc8_row14_col1" class="data row14 col1" >0.773</td>
#       <td id="T_cffc8_row14_col2" class="data row14 col2" >0.606</td>
#       <td id="T_cffc8_row14_col3" class="data row14 col3" >0.747</td>
#       <td id="T_cffc8_row14_col4" class="data row14 col4" >0.649</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cffc8_row15_col0" class="data row15 col0" >0.330</td>
#       <td id="T_cffc8_row15_col1" class="data row15 col1" >0.744</td>
#       <td id="T_cffc8_row15_col2" class="data row15 col2" >0.557</td>
#       <td id="T_cffc8_row15_col3" class="data row15 col3" >0.755</td>
#       <td id="T_cffc8_row15_col4" class="data row15 col4" >0.627</td>
#     </tr>
#     <tr>
#       <th id="T_cffc8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cffc8_row16_c

# %%
all_metrics = pd.DataFrame(all_metrics)
all_metrics['P-value'] = all_metrics['P-value'].astype(float).round(2)

# métricas (exclui P-value)
metrics_cols = all_metrics.columns.drop('P-value')

# agrupa por p para evitar repetição
table = (
    all_metrics
    .groupby('P-value', as_index=False)[metrics_cols]
    .mean()
)

# média global das métricas
table['Média'] = table[metrics_cols].mean(axis=1)

def highlight_best_worst(s):
    is_max = s == s.max()
    is_min = s == s.min()
    
    return [
        'background-color: #b7f7c1; font-weight: bold' if max_v
        else 'background-color: #f7b7b7; font-weight: bold' if min_v
        else ''
        for max_v, min_v in zip(is_max, is_min)
    ]

styled_table = (
    table
    .style
    .apply(highlight_best_worst, axis=0)
    .format({c: "{:.3f}" for c in metrics_cols})
)

styled_table
# Out:
# <style type="text/css">
# #T_03378_row0_col0, #T_03378_row1_col3, #T_03378_row17_col4, #T_03378_row17_col5, #T_03378_row22_col2, #T_03378_row24_col1 {
#   background-color: #f7b7b7;
#   font-weight: bold;
# }
# #T_03378_row13_col4, #T_03378_row14_col2, #T_03378_row23_col1, #T_03378_row23_col3, #T_03378_row23_col5, #T_03378_row24_col0 {
#   background-color: #b7f7c1;
#   font-weight: bold;
# }
# </style>
# <table id="T_03378">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03378_level0_col0" class="col_heading level0 col0" >P-value</th>
#       <th id="T_03378_level0_col1" class="col_heading level0 col1" >AUC-PR</th>
#       <th id="T_03378_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_03378_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_03378_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_03378_level0_col5" class="col_heading level0 col5" >Média</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03378_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03378_row0_col0" class="data row0 col0" >0.180000</td>
#       <td id="T_03378_row0_col1" class="data row0 col1" >0.734</td>
#       <td id="T_03378_row0_col2" class="data row0 col2" >0.554</td>
#       <td id="T_03378_row0_col3" class="data row0 col3" >0.734</td>
#       <td id="T_03378_row0_col4" class="data row0 col4" >0.606</td>
#       <td id="T_03378_row0_col5" class="data row0 col5" >0.657014</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03378_row1_col0" class="data row1 col0" >0.190000</td>
#       <td id="T_03378_row1_col1" class="data row1 col1" >0.727</td>
#       <td id="T_03378_row1_col2" class="data row1 col2" >0.554</td>
#       <td id="T_03378_row1_col3" class="data row1 col3" >0.716</td>
#       <td id="T_03378_row1_col4" class="data row1 col4" >0.606</td>
#       <td id="T_03378_row1_col5" class="data row1 col5" >0.650918</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03378_row2_col0" class="data row2 col0" >0.200000</td>
#       <td id="T_03378_row2_col1" class="data row2 col1" >0.738</td>
#       <td id="T_03378_row2_col2" class="data row2 col2" >0.557</td>
#       <td id="T_03378_row2_col3" class="data row2 col3" >0.772</td>
#       <td id="T_03378_row2_col4" class="data row2 col4" >0.616</td>
#       <td id="T_03378_row2_col5" class="data row2 col5" >0.670832</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03378_row3_col0" class="data row3 col0" >0.210000</td>
#       <td id="T_03378_row3_col1" class="data row3 col1" >0.762</td>
#       <td id="T_03378_row3_col2" class="data row3 col2" >0.582</td>
#       <td id="T_03378_row3_col3" class="data row3 col3" >0.748</td>
#       <td id="T_03378_row3_col4" class="data row3 col4" >0.624</td>
#       <td id="T_03378_row3_col5" class="data row3 col5" >0.679009</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03378_row4_col0" class="data row4 col0" >0.220000</td>
#       <td id="T_03378_row4_col1" class="data row4 col1" >0.744</td>
#       <td id="T_03378_row4_col2" class="data row4 col2" >0.572</td>
#       <td id="T_03378_row4_col3" class="data row4 col3" >0.759</td>
#       <td id="T_03378_row4_col4" class="data row4 col4" >0.629</td>
#       <td id="T_03378_row4_col5" class="data row4 col5" >0.676022</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03378_row5_col0" class="data row5 col0" >0.230000</td>
#       <td id="T_03378_row5_col1" class="data row5 col1" >0.772</td>
#       <td id="T_03378_row5_col2" class="data row5 col2" >0.560</td>
#       <td id="T_03378_row5_col3" class="data row5 col3" >0.778</td>
#       <td id="T_03378_row5_col4" class="data row5 col4" >0.639</td>
#       <td id="T_03378_row5_col5" class="data row5 col5" >0.687371</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03378_row6_col0" class="data row6 col0" >0.240000</td>
#       <td id="T_03378_row6_col1" class="data row6 col1" >0.762</td>
#       <td id="T_03378_row6_col2" class="data row6 col2" >0.554</td>
#       <td id="T_03378_row6_col3" class="data row6 col3" >0.784</td>
#       <td id="T_03378_row6_col4" class="data row6 col4" >0.627</td>
#       <td id="T_03378_row6_col5" class="data row6 col5" >0.681882</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03378_row7_col0" class="data row7 col0" >0.250000</td>
#       <td id="T_03378_row7_col1" class="data row7 col1" >0.751</td>
#       <td id="T_03378_row7_col2" class="data row7 col2" >0.550</td>
#       <td id="T_03378_row7_col3" class="data row7 col3" >0.776</td>
#       <td id="T_03378_row7_col4" class="data row7 col4" >0.620</td>
#       <td id="T_03378_row7_col5" class="data row7 col5" >0.674224</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03378_row8_col0" class="data row8 col0" >0.260000</td>
#       <td id="T_03378_row8_col1" class="data row8 col1" >0.749</td>
#       <td id="T_03378_row8_col2" class="data row8 col2" >0.570</td>
#       <td id="T_03378_row8_col3" class="data row8 col3" >0.745</td>
#       <td id="T_03378_row8_col4" class="data row8 col4" >0.615</td>
#       <td id="T_03378_row8_col5" class="data row8 col5" >0.669855</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03378_row9_col0" class="data row9 col0" >0.270000</td>
#       <td id="T_03378_row9_col1" class="data row9 col1" >0.750</td>
#       <td id="T_03378_row9_col2" class="data row9 col2" >0.531</td>
#       <td id="T_03378_row9_col3" class="data row9 col3" >0.776</td>
#       <td id="T_03378_row9_col4" class="data row9 col4" >0.600</td>
#       <td id="T_03378_row9_col5" class="data row9 col5" >0.664373</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_03378_row10_col0" class="data row10 col0" >0.280000</td>
#       <td id="T_03378_row10_col1" class="data row10 col1" >0.731</td>
#       <td id="T_03378_row10_col2" class="data row10 col2" >0.519</td>
#       <td id="T_03378_row10_col3" class="data row10 col3" >0.759</td>
#       <td id="T_03378_row10_col4" class="data row10 col4" >0.602</td>
#       <td id="T_03378_row10_col5" class="data row10 col5" >0.652657</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_03378_row11_col0" class="data row11 col0" >0.290000</td>
#       <td id="T_03378_row11_col1" class="data row11 col1" >0.757</td>
#       <td id="T_03378_row11_col2" class="data row11 col2" >0.537</td>
#       <td id="T_03378_row11_col3" class="data row11 col3" >0.773</td>
#       <td id="T_03378_row11_col4" class="data row11 col4" >0.617</td>
#       <td id="T_03378_row11_col5" class="data row11 col5" >0.671110</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_03378_row12_col0" class="data row12 col0" >0.300000</td>
#       <td id="T_03378_row12_col1" class="data row12 col1" >0.768</td>
#       <td id="T_03378_row12_col2" class="data row12 col2" >0.582</td>
#       <td id="T_03378_row12_col3" class="data row12 col3" >0.757</td>
#       <td id="T_03378_row12_col4" class="data row12 col4" >0.633</td>
#       <td id="T_03378_row12_col5" class="data row12 col5" >0.685279</td>
#     </tr>
#     <tr>
#       <th id="T_03378_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_03378_row13_col0" class="data row13 col0" >0.310000</td>
#       <td id="T_03378_row13_col1" class="data row13 col1" >0.787</td>
#       <td id="T_03378_row13_col2" class="data row13 col2" >0.592</td>
#       <td id="T_03378_row13_col3" class="data row13 col3" >0.773</td

# %%
# Split by P-value ranges
exogenous = all_metrics[(all_metrics['P-value'] >= 0.18) & (all_metrics['P-value'] <= 0.28)]
transition = all_metrics[(all_metrics['P-value'] > 0.28) & (all_metrics['P-value'] < 0.32)]
endogenous = all_metrics[(all_metrics['P-value'] >= 0.32) & (all_metrics['P-value'] <= 0.42)]
mixed = all_metrics  

# Compute means
table = pd.DataFrame({
    'Exogenous': exogenous.mean(),
    'Transition': transition.mean(),
    'Endogenous': endogenous.mean(),
    'Mixed': mixed.mean()
}).T

# Drop P-value column (not meaningful to average)
table = table.drop(columns=['P-value'])

# Style table
styled_table = (
    table
    .style
    .apply(highlight_best_worst, axis=0)
    .format("{:.3f}")
)

table.to_csv("../paper/metrics_by_regime_mixed.csv", float_format="%.3f")

styled_table
# Out:
# <style type="text/css">
# #T_c83cc_row0_col0, #T_c83cc_row0_col1, #T_c83cc_row0_col2, #T_c83cc_row0_col3 {
#   background-color: #f7b7b7;
#   font-weight: bold;
# }
# #T_c83cc_row1_col0, #T_c83cc_row1_col1, #T_c83cc_row1_col3, #T_c83cc_row2_col2 {
#   background-color: #b7f7c1;
#   font-weight: bold;
# }
# </style>
# <table id="T_c83cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c83cc_level0_col0" class="col_heading level0 col0" >AUC-PR</th>
#       <th id="T_c83cc_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_c83cc_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c83cc_level0_col3" class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c83cc_level0_row0" class="row_heading level0 row0" >Exogenous</th>
#       <td id="T_c83cc_row0_col0" class="data row0 col0" >0.748</td>
#       <td id="T_c83cc_row0_col1" class="data row0 col1" >0.555</td>
#       <td id="T_c83cc_row0_col2" class="data row0 col2" >0.760</td>
#       <td id="T_c83cc_row0_col3" class="data row0 col3" >0.617</td>
#     </tr>
#     <tr>
#       <th id="T_c83cc_level0_row1" class="row_heading level0 row1" >Transition</th>
#       <td id="T_c83cc_row1_col0" class="data row1 col0" >0.771</td>
#       <td id="T_c83cc_row1_col1" class="data row1 col1" >0.570</td>
#       <td id="T_c83cc_row1_col2" class="data row1 col2" >0.768</td>
#       <td id="T_c83cc_row1_col3" class="data row1 col3" >0.633</td>
#     </tr>
#     <tr>
#       <th id="T_c83cc_level0_row2" class="row_heading level0 row2" >Endogenous</th>
#       <td id="T_c83cc_row2_col0" class="data row2 col0" >0.759</td>
#       <td id="T_c83cc_row2_col1" class="data row2 col1" >0.566</td>
#       <td id="T_c83cc_row2_col2" class="data row2 col2" >0.770</td>
#       <td id="T_c83cc_row2_col3" class="data row2 col3" >0.631</td>
#     </tr>
#     <tr>
#       <th id="T_c83cc_level0_row3" class="row_heading level0 row3" >Mixed</th>
#       <td id="T_c83cc_row3_col0" class="data row3 col0" >0.756</td>
#       <td id="T_c83cc_row3_col1" class="data row3 col1" >0.561</td>
#       <td id="T_c83cc_row3_col2" class="data row3 col2" >0.766</td>
#       <td id="T_c83cc_row3_col3" class="data row3 col3" >0.625</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.random.seed(103)

test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=[0.38, 0.38],
    num_series=3,
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

df = test_series[1]

metrics, ks, recalls = evaluate_and_plot_streaming(
    model,
    df,
    device,
    lookahead=config["data"]["lookahead"],
    plot=True,
    box_cut=(600, 800),
    title= "(b) Endogenous time series (p = 0.38) with extreme event labels and LSTM prediction",
    path_ra = "../paper/images/exogenous_endogenou_time_series_recall_vs_anticipacion_b.png",
    path_series = "../paper/images/exogenous_endogenou-time_series_with_extreme_event_labels_and_lstm_prediction_mixed_b.png"
)

print(metrics)

all_metrics.append(metrics)
all_recalls.append(recalls)
# Out:
# [0.38, 0.38]
# /var/folders/25/4ts88tzd08500lbfck1y7nn40000gn/T/ipykernel_38647/1846533069.py:353: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'AUC-PR': 0.27262365422550305, 'Precision': 0.3036649214659686, 'Recall': 0.7945205479452054, 'F1': 0.4393939393939394, 'P-value': np.float64(0.38)}

# %%
np.random.seed(113)

test_series = generate_multiple_series(
    length=config["p_model"]["series_length"],
    p_value=[0.25, 0.25],
    num_series=3,
    peak_percentile=config["data"]["peak_percentile"],
)

all_metrics = []
all_recalls = []

df = test_series[2]

metrics, ks, recalls = evaluate_and_plot_streaming(
    model,
    df,
    device,
    lookahead=config["data"]["lookahead"],
    plot=True,
    box_cut=(800, 1000),
    title="(a) Exogenous time series (p = 0.25) with extreme event labels and LSTM prediction",
    path_ra = "../paper/images/exogenous_endogenou_time_series_recall_vs_anticipacion_a.png",
    path_series = "../paper/images/exogenous_endogenou-time_series_with_extreme_event_labels_and_lstm_prediction_mixed_a.png"
)

print(metrics)

all_metrics.append(metrics)
all_recalls.append(recalls)
# Out:
# [0.25, 0.25]
# /var/folders/25/4ts88tzd08500lbfck1y7nn40000gn/T/ipykernel_38647/1846533069.py:353: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'AUC-PR': 0.7273105907312384, 'Precision': 0.5588235294117647, 'Recall': 0.7808219178082192, 'F1': 0.6514285714285715, 'P-value': np.float64(0.25)}
